# %%
pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
sp_clave = os.getenv("irene_id_sp")
sp_contraseña = os.getenv("irene_secret_sp")

# %%
import json
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Autentificación:
auth_manager = sp = SpotifyClientCredentials(client_id=sp_clave,
                                             client_secret=sp_contraseña)

sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
datos_techno = sp.search(q="genre:techno, year:2019", type="track", limit=50, offset=0)

# %%
print(len(datos_techno["tracks"]))
print(len(datos_techno["tracks"]["items"]))
print(type(datos_techno["tracks"]["items"]))
# Out:
# 7
# 50
# <class 'list'>

# %%
print(type(datos_techno["tracks"]["items"][0]))
# Out:
# <class 'dict'>

# %%
print(datos_techno["tracks"]["items"][0].keys())
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
print(datos_techno["tracks"]["items"][0]["album"].keys())
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'is_playable', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
print(json.dumps(datos_techno, indent=2))
# Out:
# {
#   "tracks": {
#     "href": "https://api.spotify.com/v1/search?offset=0&limit=50&query=genre%3Atechno%2C%20year%3A2019&type=track",
#     "limit": 50,
#     "next": "https://api.spotify.com/v1/search?offset=50&limit=50&query=genre%3Atechno%2C%20year%3A2019&type=track",
#     "offset": 0,
#     "previous": null,
#     "total": 100,
#     "items": [
#       {
#         "album": {
#           "album_type": "single",
#           "artists": [
#             {
#               "external_urls": {
#                 "spotify": "https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of"
#               },
#               "href": "https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of",
#               "id": "0LyfQWJT6nXafLPZqxe9Of",
#               "name": "Various Artists",
#               "type": "artist",
#               "uri": "spotify:artist:0LyfQWJT6nXafLPZqxe9Of"
#             }
#           ],
#           "available_markets": [
#             "AR",
#             "AU",
# ...

# %%
# queremos preparar los datos qnos interesan, por ejemplo sacar el personaje con su "name", "id", "house" y "yearOfBirth":
personajes = {"nombre": [], "id": [], "casa": [], "año_nacimiento":[]}
for personaje in datos:
    personajes["nombre"].append(personaje["name"])
    personajes["id"].append(personaje["id"])
    personajes["casa"].append(personaje["house"])
    personajes["año_nacimiento"].append(personaje["yearOfBirth"])
    break
personajes
# si quitaramos el break nos saldrían todos los personajes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 # queremos preparar los datos qnos interesan, por ejemplo sacar el personaje con su "name", "id", "house" y "yearOfBirth":
#       2 personajes = {"nombre": [], "id": [], "casa": [], "año_nacimiento":[]}
# ----> 3 for personaje in datos:
#       4     personajes["nombre"].append(personaje["name"])
#       5     personajes["id"].append(personaje["id"])
#
# NameError: name 'datos' is not defined

# %%
canciones_techno = {"nombre_artista": [], "nombre_cancion": [], "año_lanzamiento": []}
for datos in datos_techno["tracks"]["items"]:
    canciones_techno["nombre_artista"].append(datos["album"]["artists"][0]["name"])
    canciones_techno["nombre_cancion"].append(datos["name"])
    canciones_techno["año_lanzamiento"].append(datos["album"]["release_date"])

# %%
print(canciones_techno)
print(len(canciones_techno["nombre_cancion"]))
# Out:
# {'nombre_artista': ['Various Artists', 'David Moleon', 'Vendex', 'Various Artists', 'Various Artists', 'Disco Van', 'Dizharmonia', 'Niño Árbol', 'BLEID', 'Various Artists', 'Peter Van Hoesen', 'Markus Schulz', 'Sisko Electrofanatik', 'Klanglos', 'Roza Terenzi', 'DJ Link', 'Charlie Thorstenson', 'Smash TV', 'Superstrobe', 'Mr. Bizz', 'Cari Lekebusch', 'AnGy KoRe', 'Dirty Doering', 'Niño Árbol', 'Edanticonf', 'Re:Axis', 'Yost Koen', 'Dok & Martin', 'El Choop', 'Various Artists', 'Various Artists', 'Various Artists', 'David Meiser', 'Various Artists', 'Nineteen Sines', 'Solee', 'Droneghost', 'Various Artists', 'Prosdo', 'Various Artists', 'Wade Watts', 'Various Artists', 'Various Artists', 'Various Artists', 'Various Artists', 'Markus Schulz - Global DJ Broadcast', 'Pappenheimer', 'La Fraicheur', 'Various Artists', 'Magnus Larsson'], 'nombre_cancion': ['Killer Queen', 'Doctor Groove', 'Cocytus', 'Cool Cat - Julio Leal & Daniel Aguayo Remix', 'Margrats', 'Missing', 'Kyveli - Artaria Remi
# ...

# %%
print(json.dumps(canciones_techno))
# Out:
# {"nombre_artista": ["Various Artists", "David Moleon", "Vendex", "Various Artists", "Various Artists", "Disco Van", "Dizharmonia", "Ni\u00f1o \u00c1rbol", "BLEID", "Various Artists", "Peter Van Hoesen", "Markus Schulz", "Sisko Electrofanatik", "Klanglos", "Roza Terenzi", "DJ Link", "Charlie Thorstenson", "Smash TV", "Superstrobe", "Mr. Bizz", "Cari Lekebusch", "AnGy KoRe", "Dirty Doering", "Ni\u00f1o \u00c1rbol", "Edanticonf", "Re:Axis", "Yost Koen", "Dok & Martin", "El Choop", "Various Artists", "Various Artists", "Various Artists", "David Meiser", "Various Artists", "Nineteen Sines", "Solee", "Droneghost", "Various Artists", "Prosdo", "Various Artists", "Wade Watts", "Various Artists", "Various Artists", "Various Artists", "Various Artists", "Markus Schulz - Global DJ Broadcast", "Pappenheimer", "La Fraicheur", "Various Artists", "Magnus Larsson"], "nombre_cancion": ["Killer Queen", "Doctor Groove", "Cocytus", "Cool Cat - Julio Leal & Daniel Aguayo Remix", "Margrats", "Missing", "K
# ...

# %%
df_techno = pd.DataFrame(canciones_techno)
df_techno
# Out:
#                          nombre_artista  \
# 0                       Various Artists
# 1                          David Moleon
# 2                                Vendex
# 3                       Various Artists
# 4                       Various Artists
# 5                             Disco Van
# 6                           Dizharmonia
# 7                            Niño Árbol
# 8                                 BLEID
# 9                       Various Artists
# 10                     Peter Van Hoesen
# 11                        Markus Schulz
# 12                 Sisko Electrofanatik
# 13                             Klanglos
# 14                         Roza Terenzi
# 15                              DJ Link
# 16                  Charlie Thorstenson
# 17                             Smash TV
# 18                          Superstrobe
# 19                             Mr. Bizz
# 20                       Cari Lekebusch
# 21                            AnGy KoRe
# ...

# %%
canciones_techno = {"nombre_artista": [], "nombre_cancion": [], "año_lanzamiento": []}

for offset in range(0, 250, 50):
    datos_techno = sp.search(q="genre:techno, year:2019", type="track", limit=50, offset=offset)
    
    for cancion in datos_techno["tracks"]["items"]:
        canciones_techno["nombre_artista"].append(cancion["album"]["artists"][0]["name"])
        canciones_techno["nombre_cancion"].append(cancion["name"])
        canciones_techno["año_lanzamiento"].append(cancion["album"]["release_date"])
df_techno = pd.DataFrame(canciones_techno)
df_techno
# Out:
#       nombre_artista                               nombre_cancion  \
# 0    Various Artists                                 Killer Queen
# 1       David Moleon                                Doctor Groove
# 2             Vendex                                      Cocytus
# 3    Various Artists  Cool Cat - Julio Leal & Daniel Aguayo Remix
# 4    Various Artists                                     Margrats
# ..               ...                                          ...
# 245  Various Artists                                Law of Motion
# 246  Various Artists                                    Resilente
# 247  Various Artists                           Nimbus (WpX Remix)
# 248    Duck Sandoval           Oscura Resurrection - Original Mix
# 249  Various Artists                                      Diagram
#
#     año_lanzamiento
# 0        2019-04-05
# 1        2019-09-26
# 2        2019-11-24
# 3        2019-01-04
# 4        2019-05-31
# ..              ...
# 245      2019-06-02
# ...

# %%
canciones_techno = {"nombre_artista": [], "nombre_cancion": [], "año_lanzamiento": []}
anios = [2019, 2020, 2021, 2022, 2023]
for anio in anios:
    for offset in range(0, 250, 50):
        datos_techno = sp.search(q="genre:techno, year:2019", type="track", limit=50, offset=offset)
        
        for cancion in datos_techno["tracks"]["items"]:
            canciones_techno["nombre_artista"].append(cancion["album"]["artists"][0]["name"])
            canciones_techno["nombre_cancion"].append(cancion["name"])
            canciones_techno["año_lanzamiento"].append(cancion["album"]["release_date"])
df_techno = pd.DataFrame(canciones_techno)
df_techno
# Out:
#        nombre_artista                               nombre_cancion  \
# 0     Various Artists                                 Killer Queen
# 1        David Moleon                                Doctor Groove
# 2              Vendex                                      Cocytus
# 3     Various Artists  Cool Cat - Julio Leal & Daniel Aguayo Remix
# 4     Various Artists                                     Margrats
# ...               ...                                          ...
# 1245  Various Artists                                Law of Motion
# 1246  Various Artists                                    Resilente
# 1247  Various Artists                           Nimbus (WpX Remix)
# 1248    Duck Sandoval           Oscura Resurrection - Original Mix
# 1249  Various Artists                                      Diagram
#
#      año_lanzamiento
# 0         2019-04-05
# 1         2019-09-26
# 2         2019-11-24
# 3         2019-01-04
# 4         2019-05-31
# ...              ...
# ...

# %%
canciones_techno = {"nombre_artista": [], "nombre_cancion": [], "año_lanzamiento": []}

for anio in range(2019,2024):
    for offset in range(0, 250, 50):
        datos_techno = sp.search(q=f"genre:techno, year:{anio}", type="track", limit=50, offset=offset)
        
        for cancion in datos_techno["tracks"]["items"]:
            canciones_techno["nombre_artista"].append(cancion["album"]["artists"][0]["name"])
            canciones_techno["nombre_cancion"].append(cancion["name"])
            canciones_techno["año_lanzamiento"].append(cancion["album"]["release_date"])
df_techno = pd.DataFrame(canciones_techno)
df_techno
# Out:
#        nombre_artista                                     nombre_cancion  \
# 0     Various Artists                                       Killer Queen
# 1        David Moleon                                      Doctor Groove
# 2              Vendex                                            Cocytus
# 3     Various Artists        Cool Cat - Julio Leal & Daniel Aguayo Remix
# 4     Various Artists                                           Margrats
# ...               ...                                                ...
# 1245           Traful                                Perspective - Mixed
# 1246  Various Artists                             Hematom - Original Mix
# 1247  Various Artists  World Of Deep - Jesse Rose Respect To Detroit ...
# 1248  Various Artists                                            Balenoo
# 1249           Carara                                       Dark and Raw
#
#      año_lanzamiento
# 0         2019-04-05
# 1         2019-09-26
# 2         2019-11-24
# ...

# %%
canciones_techno = {"nombre_artista": [], "nombre_cancion": [], "año_lanzamiento": [], "género_musical": [], "tipo": []}

for anio in range(2019,2024):
    for offset in range(0, 250, 50):
        datos_techno = sp.search(q=f"genre:techno, year:{anio}", type="track", limit=50, offset=offset)
        
        for cancion in datos_techno["tracks"]["items"]:
            canciones_techno["nombre_artista"].append(cancion["album"]["artists"][0]["name"])
            canciones_techno["nombre_cancion"].append(cancion["name"])
            canciones_techno["año_lanzamiento"].append(cancion["album"]["release_date"])
            canciones_techno["género_musical"].append("techno")
            canciones_techno["tipo"].append(cancion["type"])
df_techno = pd.DataFrame(canciones_techno)
df_techno
# Out:
#        nombre_artista                                     nombre_cancion  \
# 0     Various Artists                                       Killer Queen
# 1        David Moleon                                      Doctor Groove
# 2              Vendex                                            Cocytus
# 3     Various Artists        Cool Cat - Julio Leal & Daniel Aguayo Remix
# 4     Various Artists                                           Margrats
# ...               ...                                                ...
# 1245           Traful                                Perspective - Mixed
# 1246  Various Artists                             Hematom - Original Mix
# 1247  Various Artists  World Of Deep - Jesse Rose Respect To Detroit ...
# 1248  Various Artists                                            Balenoo
# 1249           Carara                                       Dark and Raw
#
#      año_lanzamiento género_musical   tipo
# 0         2019-04-05         techno  track
# ...
