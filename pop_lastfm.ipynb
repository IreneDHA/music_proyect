# %%
import requests
import json
import pandas as pd

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("miriam_lastfm_id")

# %%
pd.read_csv("pop_spotifydatabase.csv", index_col=0)
# Out:
#                  nombre_artista  \
# 0               Various Artists
# 1                  Los Rebeldes
# 2               Various Artists
# 3                      Da Igual
# 4               Various Artists
# ...                         ...
# 1245                    Skd Raj
# 1246            Various Artists
# 1247              Panini Brunch
# 1248                Kinjal Dave
# 1249  Sumit Singh Chandravanshi
#
#                                         nombre_cancion año_lanzamiento  \
# 0                                         Un boomerang      2019-11-22
# 1              Land of Thousand Dances - Remasterizado      2019-11-15
# 2                                       No te enamores      2019-07-05
# 3                  Ojos Que No Ven Hostia Que Te Pegas      2019-04-12
# 4                                         Walk Me Home      2019-06-07
# ...                                                ...             ...
# 1245                  Iyarwe Ke Den Ha Kahat Bada Papa      2023-03-11
# 1246  Irgendwann irgendwo irgendwie - Stereoact #Remix      2023-01-07
# 1247                                       Tell me why      2023-01-05
# 1248                                      Dj Cheharmaa      2023-03-20
# 1249                                     Patna Me Ghar      2023-08-28
#
#      género_musical   tipo
# 0               pop  track
# 1               pop  track
# 2               pop  track
# 3               pop  track
# 4               pop  track
# ...             ...    ...
# 1245            pop  track
# 1246            pop  track
# 1247            pop  track
# 1248            pop  track
# 1249            pop  track
#
# [1250 rows x 5 columns]

# %%
cosaslista = pd.read_csv("pop_spotifydatabase.csv")

# %%
columnanombreartista = cosaslista["nombre_artista"].tolist()

# %%
def llamar_api(url):
    llamada = requests.get(url)
    
    if llamada.status_code != 200:
        print(llamada.reason)
    else:
        return llamada.json()

# %%
infoartistas={"nombre_artista":[],"bio":[],"listeners":[],"playcount":[],"similar":[]}

for nombreartista in columnanombreartista:
    
    if nombreartista == "Various Artists":  # elimiamos Various artists para q no salgan datos erróneos en las bio
        continue

    elif nombreartista in infoartistas["nombre_artista"]: 
        continue  # Skip this iteration if the artist is a duplicate 

    else:    
        try: 
            url = f"http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist={nombreartista}&api_key={api_key}&format=json"
            respuesta = llamar_api(url)

            #Para hacer esto: infoartistas["similar"].append(respuesta["artist"]["similar"]["artist"][0]['name'])
            similares=[]
            for artistaejemplo in respuesta["artist"]["similar"]["artist"]:
                similares.append(artistaejemplo['name'])

            infoartistas["similar"].append(similares)
            infoartistas["nombre_artista"].append(nombreartista)
            infoartistas["bio"].append(respuesta["artist"]["bio"]["summary"])
            infoartistas["listeners"].append(respuesta["artist"]["stats"]["listeners"])
            infoartistas["playcount"].append(respuesta["artist"]["stats"]["playcount"])

            

        except KeyError:
            continue 

print(infoartistas)
# Out:
# {'nombre_artista': ['Los Rebeldes', 'Da Igual', 'No Me Pises Que Llevo Chanclas', 'VINAI', 'Chaqueta de Chándal', 'Marisol', 'Nada Surf', 'Carlos Berlanga', 'Diego Martín', 'Cristian Guerrero', 'MARÍA TOLEDO', 'Rayo', 'Belen Arjona', 'Eladio y Los Seres Queridos', 'Los Directivos', 'Atencion Tsunami', 'Grupo Macarena', 'Nena Daconte', 'The New Raemon', 'Duo Dinamico', 'Emilia, Pardo y Bazán', 'Kañasur', 'Son Del Barrio', 'Maria Carrasco', 'Neleonard', 'Ketito', 'El Grajo', 'Roberto Casalino', 'Gabriel Arriaga', 'Luisa Lacerda', 'Aries', 'Joan As Police Woman', 'Al Rangone', 'MINOS', "Los Ayer's", 'Roto', 'Franktony', 'WHY@DOLL', 'Hermanas Villareal', 'Ciudadano Toto', 'Insomniac Records', 'Gildardo Montoya', 'Banda Warilou', 'Los Relicarios', 'Bowen y Villafuerte', 'Luciano y Concholon', 'Nicola Arigliano', 'Nelson Henriquez', 'Nechivile', 'Kayla Diamond', 'Sofiano', 'Fresno', 'Flor de Mururé', 'Bouba Menguè', 'Darío Gómez', 'Andro Skrt', 'Elymar Santos', 'Surma Chanu', 'Martin Mkrtchyan', 'Kalpana Hansda', 'Abhijit Majumdar', 'Bhakta Prasad Barik', 'Raju Rawal', 'Devi', 'Zubeen Garg', 'Mousam Gogoi', 'Dikshu', 'Sound Of Monkey', 'Renan e Rafael', 'Dreamhunter', 'Mithu Marshal', 'Kaboy Kamakili', 'Chorus', 'Celso Adolfo', 'Lucie', 'Alok Kumar', 'Trina', 'Rajender Singh Kharkiya', 'Akshaya Mohanty', 'Prakash Jal', 'Jignesh Barot', 'Aakangkhya Das', 'Ritesh Pandey', 'The John Dank Show', 'Rohit Thakor', 'Seguimos Perdiendo', 'Havelocke', 'Indra Dhavsi', 'Dr JB', 'Arvind Akela Kallu Ji', 'Oli Big', 'TOTALFAT', 'BATTLE BOYS', 'Gopal Gurjar', 'Bianka', 'Farrux Xamrayev', 'Vlado Kreslin', 'Pawan Singh', 'Davi e Fernando', 'Jendral Kantjil', 'Joe Brown', 'Domenico Modugno', 'Baidyanath Dash', 'Nataliya Vlasova', 'Legendboy', 'Amar Devarakonda', 'Justin Tweito', 'Ramesh Roshan', 'Bubblegum Lemonade', 'Ernest Ashworth', 'Jike Junyi', 'Stella Mengele', 'Lee ALeum', 'Румиса Никаева', 'Ahmad Solo', 'Mario Battaini', 'KIM of Diamonds', 'Yma Sumac', 'Playground Circus', 'Walter Wanderley', 'Sarat Nayak', 'Odair Jose', 'Airbag', 'Nueva Vulcano', 'Diamante Negro', 'Pablo Prisma y las Pirámides', 'Melenas', 'Nolasco', 'Grises', 'from', 'Alexie Divello', 'Barroso', 'Joe Crepúsculo', 'Detergente Líquido', 'Bravo Fisher!', 'Pitovnis', 'The Reflectors', 'Autoescuela', 'Chucho', 'Las Ruinas', 'Dharmacide', 'De Kermisklanten', 'Leroy Van Dyke', 'Belako', 'David Otero', 'Los Raros', 'Luigi Tenco', 'Fausto', 'Uriel Henao', 'Sekouba Kandia Kouyaté', 'Javiera Mena', 'JACK BORIS', 'Rahima', 'Claudio Villa', 'V Grooves', 'Aminu Ladan Alan Waka', 'Samsaruh', 'Ryuichi Kawamura', 'Czecho No Republic', 'ALMAR', 'Jose Miguel Class', 'Riccobellis', 'Kate Miller-Heidke', 'Manezinho Do Sax', 'OP Dewangan', 'Jignesh Kaviraj', 'Sarbeswar Kardong', 'Waldo Cesar', 'Inder Jeet', 'Johnny Sablan', 'Fruto Sensual', 'Ankush Raja', 'Ramkumar Maluni', 'Khesari Lal Yadav', 'Labh Heera', 'Titãs', 'Bivolt', 'Nilakshi Neog', 'Moacyr Franco', 'Hugo & Tiago', 'Shilpa Bidawat', 'Dj Kuchi', 'Sannidhya Bhuyan', 'Hugo Matta', 'Somos 3', 'Endank Soekamti', 'Ki Jlawdohtir', 'Gazza', 'Rama Aiphama', 'Jiya Negi, Akshay Negi', 'Lavan Abhishek', 'Nunes Filho', 'Vaibhav Londhe', 'Luiz Guilherme', 'Veer Davinder', 'Acústicos & Valvulados', 'B Maisnam', 'Revolución Total', 'Gunz', 'Rahul Puthi', 'Amit Thapliyal', 'Jitrz', 'Poba Gourab', 'Exit', 'MynameiS', 'Earl Thomas Conley', 'Ovhi Firsty', 'Petra Sihombing', 'Subhan Negi', 'Walter Manglona', 'Chandra Kr. Patgiri', 'Marileyda', 'Reverie', 'Dharampreet', 'Erol Şahin', 'Faron Young', 'Raquel Rastenni', 'Max Merritt', 'Nippu Nepewala', 'Roopa Kotwal', 'Ric Manrique Jr.', 'ShiningStars', 'No Matinho', 'Armin van Buuren ASOT Radio', 'Jacob Latimore', 'Bappa Mazumder', 'Dois na Janela', 'Rabo de Vaca', 'Staatsoper Stuttgart', 'Mekan Atayev', 'Twinkle Vaishnav', 'King James', "elfin'", 'Neelkamal Singh', 'Geeta Goswami', 'Turkmen Mukamlary', 'Mahmud Nagudu', 'Gopi Sundar', 'Koolade', 'Rohana Weerasinghe', 'Danyel Gerard', 'Henrique & Diego', 'Durg ...

# %%
df=pd.DataFrame(infoartistas)
df
# Out:
#                      nombre_artista  \
# 0                      Los Rebeldes
# 1                          Da Igual
# 2    No Me Pises Que Llevo Chanclas
# 3                             VINAI
# 4               Chaqueta de Chándal
# ..                              ...
# 622                   Naeem Hazarvi
# 623                   Zinti Panging
# 624                         Skd Raj
# 625                   Panini Brunch
# 626                     Kinjal Dave
#
#                                                    bio listeners playcount  \
# 0    Los Rebeldes is a Spanish Rock and Roll / Rock...     23197    160254
# 1    Wences Sánchez empieza a despuntar desde bien ...       715      8825
# 2    No me pises que llevo chanclas is a spanish po...     12086    111012
# 3    VINAI is an electronic music group formed in 2...    226679   2506968
# 4     <a href="https://www.last.fm/music/Chaqueta+d...      2808     22926
# ..                                                 ...       ...       ...
# 622   <a href="https://www.last.fm/music/Naeem+Haza...       438      3083
# 623   <a href="https://www.last.fm/music/Zinti+Pang...         1         1
# 624   <a href="https://www.last.fm/music/Skd+Raj">R...        22        82
# 625   <a href="https://www.last.fm/music/Panini+Bru...       810      3391
# 626   <a href="https://www.last.fm/music/Kinjal+Dav...      1318     10788
#
#                                                similar
# 0    [Gatos Locos, Loquillo y Trogloditas, Loquillo...
# 1    [nada que decir, Doctor Pitangú, Barrio Sur, E...
# 2    [Los Inhumanos, Los Sencillos, Manolo Tena, Un...
# 3        [Klaas, lunax, Tungevaag, R3hab, Mike Candys]
# 4    [Camellos, Pantocrator, Parquesvr, Los Estanqu...
# ..                                                 ...
# 622  [Zeeshan Khan Rokhri, Abrar-Ul-Haq, Naseebo La...
# 623                                                 []
# 624  [Tuntun Yadav, Chandan Chanchal, Neelkamal Sin...
# 625  [Shin Hyun Woo, Norwegian Wood, Sweden Laundry...
# 626  [Geeta Rabari, Kirtidan Ghadhavi, Aishwarya Ma...
#
# [627 rows x 5 columns]

# %%
df.to_csv("pop_lastfmdatabase.csv")

# %%
df_values=pd.read_csv("pop_lastfmdatabase.csv",index_col=0)

# %%
list(df_values.itertuples(index=False, name=None))
# Out:
# [('Los Rebeldes',
#   'Los Rebeldes is a Spanish Rock and Roll / Rockabilly band from Barcelona formed in 1979 by Carlos Segarra (vocals & guitar), Aurelio Morata (bass) & Moises Sorolla (drums). They recorded his first album in 1981, tittled "Cerveza, chicas y... Rockabilly" (Beers, girls and... Rockabilly). <a href="https://www.last.fm/music/Los+Rebeldes">Read more on Last.fm</a>',
#   23197,
#   160254,
#   "['Gatos Locos', 'Loquillo y Trogloditas', 'Loquillo Y Los Intocables', 'Rey Lui', 'Los Coyotes']"),
#  ('Da Igual',
#   'Wences Sánchez empieza a despuntar desde bien pequeño como cantante y compositor. Su aire juvenil y desenfadado, junto a un estilo muy peculiar, le dan a sus canciones un toque muy personal que lo diferencian del resto. Su proyecto musical va gestándose poco a poco hasta que, en 2005, nace DA=. \n\nTras mucho trabajo y largas horas de ensayo, DA= sale al mercado de forma independiente y autoproduce su primer disco, INJUSTIFICABLE. Sin apenas promoción <a href="https://www.last.fm/music/da+igual">Read more on Last.fm</a>',
#   715,
#   8825,
#   "['nada que decir', 'Doctor Pitangú', 'Barrio Sur', 'EXCESO', 'Lagarto Amarillo']"),
#  ('No Me Pises Que Llevo Chanclas',
#   'No me pises que llevo chanclas is a spanish pop band formed in 1986 in Los Palacios (Seville province). Their musical style is known as "agropop" (rural pop), humoristical pop sung in western andalusian dialect.\n\nWhen the band was dissolved, its vocalist, Pepe Begines, started his solo career, as TV presenter and singer. He released two albums: "Gira Mundial" (2002) and "Mi Propia Pelicula" (2004).\n\n- Members\n*Pepe Begines, singer\n*Alvaro Begines, guitar <a href="https://www.last.fm/music/No+Me+Pises+Que+Llevo+Chanclas">Read more on Last.fm</a>',
#   12086,
#   111012,
#   "['Los Inhumanos', 'Los Sencillos', 'Manolo Tena', 'Un Pingüino En Mi Ascensor', 'Tam Tam Go!']"),
#  ('VINAI',
#   'VINAI is an electronic music group formed in 2011 by Italian producers Alessandro Vinai (Brescia, 25 January 1990) and Andrea Vinai (Brescia 10 January 1994). As a duo, they have produced EDM songs. The success started with the publication of the single "Raveology" in January 2014 with DVBBS on Spinnin\' Records.\n <a href="https://www.last.fm/music/Vinai">Read more on Last.fm</a>',
#   226679,
#   2506968,
#   "['Klaas', 'lunax', 'Tungevaag', 'R3hab', 'Mike Candys']"),
#  ('Chaqueta de Chándal',
#   ' <a href="https://www.last.fm/music/Chaqueta+de+Ch%C3%A1ndal">Read more on Last.fm</a>',
#   2808,
#   22926,
#   "['Camellos', 'Pantocrator', 'Parquesvr', 'Los Estanques', 'Alavedra']"),
#  ('Marisol',
#   'Marisol (o Pepa Flores, su nombre real) es una gran artista del cine y la música española y aunque esté retirada desde hace muchos años eso no hace más que aumentar su popularidad, entre sus seguidores y entre los que la recuerdan en las películas de su infancia.\n\nInició su carrera en 1960, a los 12 años, en la película "Un rayo de luz", con un enorme éxito, no sólo en España sino a nivel internacional incluso en Japón. De ahí en adelante filmó alrededor de 15 películas <a href="https://www.last.fm/music/Marisol">Read more on Last.fm</a>',
#   46496,
#   292382,
#   "['Los Secretos', 'Massiel', 'Los Bravos', 'Lola Flores', 'Mocedades']"),
#  ('Nada Surf',
#   'Nada Surf is an American alternative rock group that was formed in 1992. The New York band consists of Matthew Caws (guitar, vocals), Ira Elliot (drums, vocals) and Daniel Lorca (bass, vocals). Their debut album, titled \'High/Low\', came out on June 18, 1996 and featured production work from Ric Ocasek of The Cars\n\nThe band is best known for the song "Popular", released as a single from their aformentioned debut. The song reached #11 on the US Billboard Alternative Songs chart and propelled the album itself to #63 on the Billboard 200. <a href="https://www.last.fm/music/Nada+Surf">Read more on Last.fm</a>',
#   1081867,
#   24118755,
#   "['The Lemonheads', 'Rogue Wave', 'Buffalo Tom', 'Superdrag', 'The Long Winters']"),
#  ('Carlos Berlanga',
#   'Carlos Berlanga was an important Spanish painter, singer, and composer who was most often associated with Alaska y Dinarama, and Alaska y Los Pegamoides, having penned such classic songs as "Bailando," "Ni tú ni nadie" and "A quién le importa." He had a successful solo music career as well as a career in art, having painted the poster for Almodovar\'s film Matador. He passed away on June 05, 2002 but he will live on forever in our hearts. <a href="https://www.last.fm/music/Carlos+Berlanga">Read more on Last.fm</a>',
#   15437,
#   252501,
#   "['Algora', 'Mano De Santo', 'Single', 'La Monja Enana', 'Ellos']"),
#  ('Diego Martín',
#   'http://www.diego-martin.es/ <a href="https://www.last.fm/music/+noredirect/Diego+Mart%C3%ADn">Read more on Last.fm</a>',
#   16808,
#   138138,
#   "['David DeMaría', 'Efecto Mariposa', 'La Caja De Pandora', 'Belén Arjona', 'Melocos']"),
#  ('Cristian Guerrero',
#   ' <a href="https://www.last.fm/music/Cristian+Guerrero">Read more on Last.fm</a>',
#   245,
#   912,
#   "['Ginera Ortega', 'Israel Paz', 'Enrique Morente con La Barberia del Sur', 'Potito con Estrella Morente', 'Rafa Serna con Sandra Carrasco']"),
#  ('MARÍA TOLEDO',
#   ' <a href="https://www.last.fm/music/Mar%C3%ADa+Toledo">Read more on Last.fm</a>',
#   847,
#   4320,
#   "['Kiki Morente', 'Parrita', 'Israel Fernández', 'El Pele', 'Sarayma']"),
#  ('Rayo',
#   ' <a href="https://www.last.fm/music/Rayo">Read more on Last.fm</a>',
#   11730,
#   59771,
#   "['Lasitud', 'Vaya Futuro', 'Cora Yako', 'coloreSantos', 'Adelaida']"),
#  ('Belen Arjona',
#   'The name of the artist is wrong - the right name is Belén Arjona\n\nPlease update your tags, using musicbrainz may help. <a href="https://www.last.fm/music/+noredirect/Belen+Arjona">Read more on Last.fm</a>',
#   524,
#   8576,
#   '[]'),
#  ('Eladio y Los Seres Queridos',
#   ' <a href="https://www.last.fm/music/Eladio+y+Los+Seres+Queridos">Read more on Last.fm</a>',
#   4239,
#   59218,
#   "['elodio y los seres queridos', 'Grises', 'Lovely Luna', 'Egon Soda', 'Ruidoblanco']"),
#  ('Los Directivos',
#   ' <a href="https://www.last.fm/music/Los+Directivos">Read more on Last.fm</a>',
#   881,
#   31465,
#   "['Anntona', 'Los lagos de Hinault', 'Espanto', 'La estrella de David', 'Klaus & Kinski']"),
#  ('Atencion Tsunami',
#   ' <a href="https://www.last.fm/music/atencion+tsunami">Read more on Last.fm</a>',
#   1177,
#   17622,
#   "['Incendios', 'Autumn Comets', 'Modelo de respuesta polar', 'Perro', 'Rusos Blancos']"),
#  ('Grupo Macarena',
#   ' <a href="https://www.last.fm/music/Grupo+Macarena">Read more on Last.fm</a>',
#   7292,
#   25661,
#   "['Vasco Hernandez', 'La jose', 'Rafa El Tachuela', 'Danza Fuego', 'Alhama, Los']"),
#  ('Nena Daconte',
#   'Nena Daconte (name taken from a Gabriel García Márquez\'s character) are a duet formed of singer and composer Mai Meneses (a contestant in Operación Triunfo 2, the spanish contest American Idol is based on), and musician Kim Fanlo.\n\nTheir music mixes pop and classic rock and covers everyday worries such as love, solitude and the search for ideals, using basic and delicate melodies coupled with sincere lyrics.\n\nTheir first album "He Perdido Los Zapatos" (I\'ve lost my shoes) - Universal 2006 <a href="https://www.last.fm/music/Nena+Daconte">Read more on Last.fm</a>',
#   141250,
#   2106756,
#   "['Amaral', 'El Canto del Loco', 'La Oreja de Van Gogh', 'El Sueño de Morfeo', 'Pereza']"),
#  ('The New Raemon',
#   'The New Raemon is an indie pop band from Barcelona, Spain. The band has been active since 2008 and is fronted by the Catalan musician Ramon Rodriguez who sings and plays guitar. He is accompanied by Ricky Falkner, who plays bass, drums as well as being the backing vocals. Pablo Garrido plays electric guitar and Marc Prats plays keyboard. <a href="https://www.last.fm/music/The+New+Raemon">Read more on Last.fm</a>',
#   51516,
#   1773156,
#   "['McEnroe', 'The New Raemon, Francisco Nixon & Ricardo Vicente', 'Francisco Nixon', 'Egon Soda', 'Manos De Topo']"),
#  ('Duo Dinamico',
#   ' <a href="https://www.last.fm/music/+noredirect/Duo+Dinamico">Read more on Last.fm</a>',
#   15100,
#   78432,
#   '[]'),
#  ('Emilia, Pardo y Bazán',
#   ' <a href="https://www.last.fm/music/Emilia,+Pardo+y+Baz%C3%A1n">Read more on Last.fm</a>',
#   978,
#   18314,
#   "['canciller', 'Sweet Q', 'Alejandro Rosa', 'Señor Torrance', 'sugarcrush']"),
#  ('Kañasur',
#   ' <a href="https://www.last.fm/music/Ka%C3%B1asur">Read more on Last.fm</a>',
#   172,
#   1638,
#   "['Cherezade', 'El Suso', 'El biri', 'María Artés Lamorena', 'Fran Ocaña']"),
#  ('Son Del Barrio',
#   ' <a href="https://www.last.fm/music/Son+del+Barrio">Read more on Last.fm</a>',
#   414,
#   1430,
#   "['Kalita del Sur', 'Demarco Flamenco', 'Pedro El Flamenkito', 'Indara', 'Manuel González (Ex Rebujito)']"),
#  ('Maria Carrasco',
#   ' <a href="https://www.last.fm/music/Maria+Carrasco">Read more on Last.fm</a>',
#   2916,
#   20101,
#   "['Belén Moreno', 'Lya', 'Natalia Y Maka', 'Joana Jiménez', 'SinLache']"),
#  ('Neleonard',
#   'En Elefant Records creemos profundamente en NELEONARD. Creemos en las letras de Nele, en su idea fija de hacer canciones POP: grandes, llenas de detalles, con la ambición de conseguir que se te enganchen a la primera escucha y sin ningún pudor en tratar sobre el AMOR y el desencanto de las relaciones, sean del tipo que sean. Y por ello mismo, el debut discográfico de NELEONARD va a ser el primer 10” que engrose el catálogo de nuestra colección de nuevos artistas New Adventures In Pop. <a href="https://www.last.fm/music/Neleonard">Read more on Last.fm</a>',
#   1913,
#   27494,
#   "['Sagrado Corazón de Jesús', 'Hazte Lapón', 'Rusos Blancos', 'Doble Pletina', 'El Palacio De Linares']"),
#  ('Ketito',
#   ' <a href="https://www.last.fm/music/Ketito">Read more on Last.fm</a>',
#   318,
#   1926,
#   "['aldeskuido', 'Natalia Y Maka', 'El Tren De Los Sueños', 'Los Rebujitos', 'El biri']"),
#  ('El Grajo',
#   ' <a href="https://www.last.fm/music/El+Grajo">Read more on Last.fm</a>',
#   779,
#   9415,
#   '[]'),
#  ('Roberto Casalino',
#   ' <a href="https://www.last.fm/music/Roberto+Casalino">Read more on Last.fm</a>',
#   388,
#   8030,
#   "['Syria', 'Romina Falconi', 'Giovanni Caccamo', 'Federica Abbate', 'Chiara Galiazzo']"),
#  ('Gabriel Arriaga',
#   ' <a href="https://www.last.fm/music/Gabriel+Arriaga">Read more on Last.fm</a>',
#   835,
#   3224,
#   "['Dario Dario', 'Rómulo Caicedo', 'El Charrito Negro', 'Arelys Henao', 'Luis Alberto Posada']"),
#  ('Luisa Lacerda',
#   ' <a href="https://www.last.fm/music/Luisa+Lacerda">Read more on Last.fm</a>',
#   742,
#   6120,
#   "['Vanessa Moreno', 'Paulo Bellinati', 'Pietá', 'Tavinho Moura', 'Roberto Mendes']"),
#  ('Aries',
#   'There are multiple artists with the name Aries:\n\n1) Aries, hailing from Southern California, currently holds over 52 million total views and more than 430,000+ subscribers on his growing YouTube channel. He has been making videos since 2012; most of them are beat tutorials or challenges, of which the resulting beats are posted to his secondary SoundCloud page, WUNDERWORLD. He has just recently started releasing full-length songs under his WUNDERWORLD label (formally Chapter 9) the majority of which are all sung, written, and produced by him. <a href="https://www.last.fm/music/Aries">Read more on Last.fm</a>',
#   416881,
#   22898759,
#   "['Tom the Mail Man', 'Juno', 'iAmJakeHill', 'iann dior', '99 NEIGHBORS']"),
#  ('Joan As Police Woman',
#   'Joan As Police Woman is American musician, singer-songwriter and producer Joan Wasser (born July 26, 1970, in Biddeford, Maine). She is a violinist and singer/songwriter in the indie rock world. She\'s best known for her album Real Life. In addition to her stints with Dambuilders, Mind Science of the Mind, and Those Bastard Souls, Wasser\'s resume includes live performances and studio work with Lou Reed, Tanya Donelly, Sheryl Crow, Dave Gahan, Elton John <a href="https://www.last.fm/music/Joan+as+Police+Woman">Read more on Last.fm</a>',
#   337014,
#   4771482,
#   "['Anna Calvi', 'Nadine Shah', 'My Brightest Diamond', 'Emilíana Torrini', 'Martha Wainwright']"),
#  ('Al Rangone',
#   ' <a href="https://www.last.fm/music/Al+Rangone">Read more on Last.fm</a>',
#   210,
#   2475,
#   "['Diego Zamboni', 'Tonya Todisco', 'Paolo Tarantino', 'Ruggero Scandiuzzi', 'Giusy Mercury']"),
#  ('MINOS',
#   'There are three artists with the name Minos\n\n1) A South-Korean rapper\n\n2) A power metal group from Rochester, Minnesota, USA.\n\n3)  A hip hop artist from Warri, Delta State, Nigeria. \n\n4) A German drum & bass producer <a href="https://www.last.fm/music/Minos">Read more on Last.fm</a>',
#   12465,
#   90433,
#   "['Rezilient', 'Aleyum', 'ALEXVNDER', 'Reburf', 'Leniz']"),
#  ("Los Ayer's",
#   ' <a href="https://www.last.fm/music/Los+Ayer%27s">Read more on Last.fm</a>',
#   486,
#   2345,
#   "['Oscar Agudelo', 'El Caballero Gaucho', 'Oscar Larroca', 'Carlos Dante', 'Agustín Magaldi']"),
#  ('Roto',
#   ' It’s tempting to describe guitarist, pianist and songwriter James Rotondi--aka ROTO--as a “journeyman” musician, due to his lengthy stints with the French group Air, Mike Patton’s Mr. Bungle, jazz-hop pioneers The Grassy Knoll, and other groundbreaking bands. Still, the Brooklyn-based performer would insist that the title of his first solo album, Summer Home, aptly suggests the sense of homecoming that the record represents; a laid-back, free-spirited musical home base <a href="https://www.last.fm/music/Roto">Read more on Last.fm</a>',
#   6546,
#   25818,
#   "['Cherry Pit', 'Trail', 'SOBA', 'Lucid Monday', 'Cozy Kev']"),
#  ('Franktony',
#   ' <a href="https://www.last.fm/music/Franktony">Read more on Last.fm</a>',
#   787,
#   3017,
#   "['Bowen y Villafuerte', 'Rilabeats', 'Dj Estefan', 'alexis play', 'Irie Kingz']"),
#  ('WHY@DOLL',
#   'WHY@DOLL (ホワイドール) is a Japanese idol group formed in May 2011.\nIt currently consists of 2 members: Uratani Haruna (浦谷はるな) and Aoki Chiharu (青木千春).\n\nThe idol unit is from Sapporo on the island of Hokkaido. The girls are now mainly active in Tokyo. <a href="https://www.last.fm/music/WHY@DOLL">Read more on Last.fm</a>',
#   3454,
#   56677,
#   "['彼女のサーブ&レシーブ', 'Galette', 'crap clap', 'Predianna', 'callme']"),
#  ('Hermanas Villareal',
#   ' <a href="https://www.last.fm/music/HERMANAS+VILLAREAL">Read more on Last.fm</a>',
#   59,
#   168,
#   "['Lucho Bowen', 'Mary Ramia', 'Ana Elena Sandoval', 'Margarita Cueto', 'Luis Alberto Posada']"),
#  ('Ciudadano Toto',
#   'Real name Adrián José Nievas. Argentinian pop and rock singer/songwriter, born in October 3, 1967. Frontman of the influential bands Adicta and Increíbles Ciudadanos Vivientes. \n\nSee also: Adrián Nievas. <a href="https://www.last.fm/music/Ciudadano+Toto">Read more on Last.fm</a>',
#   583,
#   20546,
#   "['Adicta', 'Increíbles Ciudadanos Vivientes', 'Maria Wolff', 'Javiera Mena', 'San Martín Vampire']"),
#  ('Insomniac Records',
#   ' <a href="https://www.last.fm/music/Insomniac+Records">Read more on Last.fm</a>',
#   286,
#   847,
#   '[\'ʟᴜᴄᴀ ʟᴜsʜ\', \'IN / ROTATION\', \'Insomniac Events\', "spinnin\' records", \'owsla\']'),
#  ('Gildardo Montoya',
#   'Un 25 de noviembre de 1976, en la calle 30 con carrera 76 del barrio Belén en Medellín, murió en un accidente de tránsito Gildardo Montoya. Jairo Paternina, quien fuera cantante de El Combo de las Estrellas, le había vendido a Gildardo una moto Honda 350 y a las 3:30 de la tarde de ese día iba acompañado de Darío Valenzuela (El brujo de la consola) cuando un carro se les atravesó, quitándole la vida a uno de los más grandes compositores que ha dado este país. Valenzuela quedó vivo para contar la historia. <a href="https://www.last.fm/music/Gildardo+Montoya">Read more on Last.fm</a>',
#   8159,
#   46984,
#   "['Armando Hernandez', 'Pastor Lopez Y Su Combo', 'Calixto Ochoa', 'Nelson Henriquez', 'Los Warahuaco']"),
#  ('Banda Warilou',
#   ' <a href="https://www.last.fm/music/Banda+Warilou">Read more on Last.fm</a>',
#   1931,
#   14117,
#   "['Kim Marques', 'Nilson Chaves', 'Arraial Do Pavulagem', 'Aldo Sena', 'Felix Robatto']"),
#  ('Los Relicarios',
#   ' <a href="https://www.last.fm/music/Los+Relicarios">Read more on Last.fm</a>',
#   3862,
#   20276,
#   "['El Caballero Gaucho', 'Luis Alberto Posada', 'Darío Gómez', 'El Charrito Negro', 'Joaquin Bedoya']"),
#  ('Bowen y Villafuerte',
#   ' <a href="https://www.last.fm/music/Bowen+y+Villafuerte">Read more on Last.fm</a>',
#   1556,
#   8952,
#   "['Olimpo Cardenas', 'Tito Cortes', 'Oscar Agudelo', 'Carlos Arturo', 'Charlie Figueroa']"),
#  ('Luciano y Concholon',
#   ' <a href="https://www.last.fm/music/Luciano+y+Concholon">Read more on Last.fm</a>',
#   90,
#   283,
#   "['Garzón y Collazos', 'Los Tolimenses', 'Obdulio y Julián', 'Hermanos Martínez', 'Silva Y Villalba']"),
#  ('Nicola Arigliano',
#   'Nicholas Arigliano - an Italian singer of jazz, the "Frank Sinatra" of Italy - was born on December 6, 1923 in Squinzano and died on March 30, 2010.\n\nAt 11 years old he ran away to Milan, as he was humiliated by his family due to his stuttering. Because of his difficult childhood he used to sign autographs, later on, by the name \'Pasquale\'. He took lessons in music theory, played the saxophone and sang in a few amateur bands, with american-style singers. <a href="https://www.last.fm/music/Nicola+Arigliano">Read more on Last.fm</a>',
#   63013,
#   247269,
#   "['Renato Rascel', 'Teddy Reno', 'Johnny Dorelli', 'Alberto Rabagliati', 'Carla Boni']"),
#  ('Nelson Henriquez',
#   ' <a href="https://www.last.fm/music/Nelson+Henriquez">Read more on Last.fm</a>',
#   12032,
#   57201,
#   "['Los Graduados', 'Pastor Lopez Y Su Combo', 'Los Hispanos', 'Armando Hernandez', 'Los Warahuaco']"),
#  ('Nechivile',
#   ' <a href="https://www.last.fm/music/Nechivile">Read more on Last.fm</a>',
#   6048,
#   68313,
#   "['Hugo Pena e Gabriel', 'Zé Henrique & Gabriel', 'Hugo Pena & Gabriel', 'marcos e fernando', 'Janaynna']"),
#  ('Kayla Diamond',
#   'Kayla Diamond is a Toronto-based singer-songwriter and the first place winner of Slaight Music’s 2015 It’s Your Shot contest. Kayla discovered this award while in her second year of law school in Windsor, Ontario and upon winning, decided to pursue a full time career in music. Kayla is currently working with some of the country’s top songwriters and producers on her debut release, due in 2017 on Cadence Music.   <a href="https://www.last.fm/music/Kayla+Diamond">Read more on Last.fm</a>',
#   7916,
#   62719,
#   "['Eleven Past One', '[SEBELL]', 'Elijah Woods x Jamie Fine', 'famba', 'Neverest']"),
#  ('Sofiano',
#   ' <a href="https://www.last.fm/music/Sofiano">Read more on Last.fm</a>',
#   6,
#   14,
#   '[]'),
#  ('Fresno',
#   'Fresno is a brazilian Rock outfit hailing from Porto Alegre, the band was formed by school friends Leandro "Nego" Pereira (vocals) Lucas "Paraiba" Silveira (guitars), Gustavo "Vavo" Mantovani (guitars), and Pedro "Cuper" Cupertino (drums) in 1999. Bassist Bruno "Lezo" Teixeira joined soon after, and the five-piece was up and running. Their first demo EP, 2001\'s O Acaso do Erro, marked the beginning of their recording career, but turned out to be the end of the road for Pereira, who called it a day, with Silveira taking over on vocals. <a href="https://www.last.fm/music/Fresno">Read more on Last.fm</a>',
#   308216,
#   33679353,
#   "['Esteban', 'NX Zero', 'Gloria', 'Hevo84', 'Forfun']"),
#  ('Flor de Mururé',
#   ' <a href="https://www.last.fm/music/Flor+de+Murur%C3%A9">Read more on Last.fm</a>',
#   579,
#   5281,
#   "['Iris da Selva', 'Íra', 'Arthur da Silva', 'Raidol', 'Jeff Moraes']"),
#  ('Bouba Menguè',
#   ' <a href="https://www.last.fm/music/Bouba+Mengu%C3%A8">Read more on Last.fm</a>',
#   2,
#   13,
#   '[]'),
#  ('Darío Gómez',
#   'Darío de Jesús Gómez Zapata, más conocido mundialmente como Darío Gómez y por el apodo de "El Rey del Despecho", es un cantante y compositor de la música tradicional colombiana que nació en San Jerónimo, Antioquia, Colombia, el 6 de febrero de 1951.\n\nDario Gomez es uno de los artistas populares más destacados que han nacido en Colombia, comenzó a escribir versos a los 14 años y a buscar apoyo mientras trabajaba como mecánico. Su iniciación en la interpretación ocurrió con un grupo llamado Los Legendarios <a href="https://www.last.fm/music/+noredirect/Dar%C3%ADo+G%C3%B3mez">Read more on Last.fm</a>',
#   12143,
#   165697,
#   "['Luis Alberto Posada', 'El Charrito Negro', 'Luisito Muñoz', 'Jhonny Rivera', 'Jimmy Gutierrez']"),
#  ('Andro Skrt',
#   ' <a href="https://www.last.fm/music/Andro+Skrt">Read more on Last.fm</a>',
#   43,
#   194,
#   "['Chucky73']"),
#  ('Elymar Santos',
#   ' <a href="https://www.last.fm/music/Elymar+Santos">Read more on Last.fm</a>',
#   4973,
#   43076,
#   "['Gilliard', 'Michael Sullivan', 'Waldick Soriano', 'Marcos Sabino', 'Eduardo Dussek']"),
#  ('Surma Chanu',
#   ' <a href="https://www.last.fm/music/surma+chanu">Read more on Last.fm</a>',
#   242,
#   2654,
#   "['Aj Maisnam', 'RAJ ELANGBAM', 'Kenedy Khuman', 'Arbin Soibam', 'Pushparani Huidrom']"),
#  ('Martin Mkrtchyan',
#   ' <a href="https://www.last.fm/music/Martin+Mkrtchyan">Read more on Last.fm</a>',
#   1425,
#   19268,
#   "['Arman Hovhannisyan', 'Razmik Amyan', 'Tigran Asatryan', 'Armenchik', 'TATA SIMONYAN']"),
#  ('Kalpana Hansda',
#   ' <a href="https://www.last.fm/music/Kalpana+Hansda">Read more on Last.fm</a>',
#   9,
#   36,
#   '[]'),
#  ('Abhijit Majumdar',
#   ' <a href="https://www.last.fm/music/Abhijit+Majumdar">Read more on Last.fm</a>',
#   131,
#   710,
#   "['Humane Sagar', 'Ira Mohanty', 'Kumar Bapi', 'Namita Agrawal', 'Asima Panda']"),
#  ('Bhakta Prasad Barik',
#   ' <a href="https://www.last.fm/music/Bhakta+Prasad+Barik">Read more on Last.fm</a>',
#   1,
#   1,
#   '[]'),
#  ('Raju Rawal',
#   ' <a href="https://www.last.fm/music/Raju+Rawal">Read more on Last.fm</a>',
#   119,
#   324,
#   "['Balli Mohanwadi', 'GOKUL SHARMA', 'Tulchharam Bhangawa', 'Chotu Singh Rawna', 'Ruchika Jangid']"),
#  ('Devi',
#   '“This stuff ought to be the new sound of the city, the new sound of the suburbs and has the snazz to be the first real rock breakout in a long time.” – Midwest Record \n\n"Get Free has everything a band ought to deliver: catchy, melodic songs, gorgeously soaring vocals, killer musicianship and a centerpiece that\'s a genuine classic…promises to captivate just as many singer/songwriter fans as headbangers. Definitely one of the year\'s very best. " - Lucid Culture <a href="https://www.last.fm/music/Devi">Read more on Last.fm</a>',
#   12746,
#   62473,
#   "['Sartek', 'Kalpana', 'Mike Metro', 'Jelle Slump', 'SvanteG']"),
#  ('Zubeen Garg',
#   'Zubeen Garg (born Zubeen Borthakur; 18 November 1972) is an Indian singer, music director, composer, lyricist, music producer, actor, film director, film producer, script writer and philanthropist. He primarily works for and sings in the Assamese, Bengali and Hindi-language film and music industries, but has sung in many other languages and dialects, including Bishnupriya Manipuri, Boro, English, Goalpariya, Kannada, Karbi, Khasi, Malayalam, Marathi, Mising, Nepali, Odia, Sanskrit, Sindhi, Tamil, Telugu, Tiwa. <a href="https://www.last.fm/music/Zubeen+Garg">Read more on Last.fm</a>',
#   14093,
#   174560,
#   "['Sonu Nigam', 'Himesh Reshammiya', 'Arijit Singh', 'Mohammed Rafi', 'Anand Raj Anand']"),
#  ('Mousam Gogoi',
#   ' <a href="https://www.last.fm/music/Mousam+Gogoi">Read more on Last.fm</a>',
#   42,
#   441,
#   "['Dimpy Sonowal', 'Dikshu', 'Jackson Frost', 'Blue Harvest & Alex H', 'Neel Akash']"),
#  ('Dikshu',
#   ' <a href="https://www.last.fm/music/Dikshu">Read more on Last.fm</a>',
#   344,
#   3299,
#   "['Neel Akash', 'Achurjya Borpatra', 'Simanta Shekhar', 'Subasana Dutta', 'Deeplina Deka']"),
#  ('Sound Of Monkey',
#   ' <a href="https://www.last.fm/music/Sound+of+Monkey">Read more on Last.fm</a>',
#   277,
#   2691,
#   "['Lowdick', 'Anarcute', 'Glory of Love', 'Metalican', 'Close Head']"),
#  ('Renan e Rafael',
#   ' <a href="https://www.last.fm/music/Renan+e+Rafael">Read more on Last.fm</a>',
#   301,
#   1725,
#   "['Kleo Dibah', 'Zé Henrique & Gabriel', 'Fred Sunwalk', 'Francis & Felipe', 'O Trio do Brasil']"),
#  ('Dreamhunter',
#   'There are three bands that go by this name:\n\n1) Dreamhunter is a Swedish hard rock band that has released two albums; Kingdom Come in 2000 and Bad Attitude in 2001. Both albums have received a lot of praise in the hard rock press, no doubt thanks to the catchy, hookladen songs.  \nThe band formed in the late seventies under the name Gain in Örebro, Sweden, and recorded three songs for the Swedish compilation album "Alsterett". They changed their name to Life Line and released two singles in 1986. <a href="https://www.last.fm/music/Dreamhunter">Read more on Last.fm</a>',
#   4467,
#   58880,
#   "['Montecarlo Hotel Project', 'Stuce The Sketch', 'Aliuama', 'The Diventa Project', 'Fly 3 Project']"),
#  ('Mithu Marshal',
#   ' <a href="https://www.last.fm/music/Mithu+Marshal">Read more on Last.fm</a>',
#   170,
#   669,
#   "['Ritesh Pandey', 'Arvind Akela Kallu Ji', 'Neelkamal Singh', 'Samar Singh', 'Khesari Lal Yadav']"),
#  ('Kaboy Kamakili',
#   ' <a href="https://www.last.fm/music/Kaboy+Kamakili">Read more on Last.fm</a>',
#   19,
#   131,
#   "['The Dogg', 'Ethnix Namibia', 'MUSHE', 'DJ Vuyo', 'Young T WokOngha']"),
#  ('Chorus',
#   'Chorus is a general term for various groups of vocalists. <a href="https://www.last.fm/music/Chorus">Read more on Last.fm</a>',
#   95314,
#   496508,
#   "['照井順政', 'Hiroaki Tsutsumi', 'Orchestra', 'S. P. Balasubrahmanyam', 'Josh Gad']"),
#  ('Celso Adolfo',
#   'Celso Adolfo (São Domingos do Prata, Minas Gerais state, Brazil, born September 9, 1952) is a Brazilian musician, singer-songwriter.\n\nCelso Adolfo started his career in 1983 with the release of his first album, the LP Coração Brasileiro, produced by one of the main Brazilian legendary composer and singer Milton Nascimento, who recorded "Coração Brasileiro" on his album Anima.  In the same year, Elba Ramalho, a northern star singer from Brazil,  made a record and a concert of great repercussion with the same “Coração Brasileiro”. <a href="https://www.last.fm/music/Celso+Adolfo">Read more on Last.fm</a>',
#   2623,
#   15005,
#   "['Tavinho Moura', 'Vital Farias', 'Banda De Pau E Corda', 'Renato Braz', 'Claudio Nucci']"),
#  ('Lucie',
#   'Lucie is a pop-rock band from the Czech Republic. They became one of the most successful rock bands in Czech history despite the fact that they have always refused to play on TV (maybe because of use of recordings instead of live performance).\n\nLucie je česká hudební skupina. Po počátečním období krystalizace personálního obsazení a hudebního stylu (léta 1985–1987) vstoupila na hudební scénu první singlovou nahrávkou v roce 1988. <a href="https://www.last.fm/music/Lucie">Read more on Last.fm</a>',
#   34300,
#   1706100,
#   "['Wanastowi Vjecy', 'Chinaski', 'Tři Sestry', 'Buty', 'Kabát']"),
#  ('Alok Kumar',
#   ' <a href="https://www.last.fm/music/Alok+Kumar">Read more on Last.fm</a>',
#   182,
#   858,
#   "['Khesari Lal Yadav', 'Neelkamal Singh', 'Ritesh Pandey', 'Priyanka Singh', 'Arvind Akela Kallu Ji']"),
#  ('Trina',
#   'Katrina Laverne Taylor (born December 3, 1974), better known by her stage name Trina, is an American rapper, songwriter and model from Miami, Florida. Trina first gained notoriety in 1998 with her appearance on Trick Daddy\'s second studio album www.thug.com to the single "Nann Nigga." She scored her first Top 5 on the Billboard Hot 100 as a feature artist on Chingy single "Right Thurr." Two years later, Trina scored her own on Top 20 single on the Billboard Hot 100 with "Here We Go" featuring Kelly Rowland,which became her first worldwide hit. <a href="https://www.last.fm/music/Trina">Read more on Last.fm</a>',
#   351013,
#   2884664,
#   '[\'Foxy Brown\', "Lil\' Kim", \'City Girls\', \'Trick Daddy\', \'Khia\']'),
#  ('Rajender Singh Kharkiya',
#   ' <a href="https://www.last.fm/music/Rajender+Singh+Kharkiya">Read more on Last.fm</a>',
#   133,
#   1042,
#   "['RP Singh', 'Bintu Pabra', 'Rajender Kharkiya', 'Khasa Aala Chahar', 'Ndee Kundu']"),
#  ('Akshaya Mohanty',
#   'Akshaya Mohanty was a popular singer songwriter and composer in Odia music.\nHe was Born at Cuttack , Orissa , India  on 12 October 1937. He had no formal training in music. Many believe that while his talent and dedication were the reasons behind his ultimate success, lack of formal training in music allowed him to experiment without being bound by the tradition.He broke the then prevalent traditional musical style in Odia musical scene and brought in fresh ideas into the scene. He claimed to have Mohd. Rafi as his early influences.  <a href="https://www.last.fm/music/Akshaya+Mohanty">Read more on Last.fm</a>',
#   386,
#   6801,
#   "['Bhikari Bal', 'Namita Agrawal', 'Humane Sagar', 'Prashant Muduli', 'Bhikhari Bala']"),
#  ('Prakash Jal',
#   ' <a href="https://www.last.fm/music/Prakash+Jal">Read more on Last.fm</a>',
#   14,
#   16,
#   '[]'),
#  ('Jignesh Barot',
#   ' <a href="https://www.last.fm/music/Jignesh+Barot">Read more on Last.fm</a>',
#   741,
#   3678,
#   "['Jignesh Kaviraj', 'Kirtidan Ghadhavi', 'Umesh Barot', 'Rajesh Ahir', 'Kirtidan Gadhvi']"),
#  ('Aakangkhya Das',
#   ' <a href="https://www.last.fm/music/Aakangkhya+Das">Read more on Last.fm</a>',
#   13,
#   25,
#   '[]'),
#  ('Ritesh Pandey',
#   ' <a href="https://www.last.fm/music/Ritesh+Pandey">Read more on Last.fm</a>',
#   2470,
#   10142,
#   "['Khesari Lal Yadav', 'Neelkamal Singh', 'Shilpi Raj', 'Arvind Akela Kallu Ji', 'Rakesh Mishra']"),
#  ('The John Dank Show',
#   'The John Dank Show demonstrates, not just their passion and hard work but, their skills as young musicians. With an effortless sound infusion and youthful mastery of various genres, they bill themselves as an Alternative Rock/reggae band. But, they’ve got a unique sound of their own: not entirely island, not completely rock, throw in a dash of reggae, sprinkle it with some beach sand, and give it a whiff of something ‘dank’, beer, whiskey or barbecue (or a combination of all four), and you’ve got The John Dank Show. <a href="https://www.last.fm/music/The+John+Dank+Show">Read more on Last.fm</a>',
#   417,
#   4271,
#   "['Jason J.', 'Fat Tofu', 'Joe Garrido', 'Pati', 'Local Deluxe']"),
#  ('Rohit Thakor',
#   ' <a href="https://www.last.fm/music/Rohit+Thakor">Read more on Last.fm</a>',
#   22,
#   27,
#   '[]'),
#  ('Seguimos Perdiendo',
#   ' <a href="https://www.last.fm/music/seguimos+perdiendo">Read more on Last.fm</a>',
#   4776,
#   238126,
#   "['La Venganza de Punk Ramon', 'tungas', 'Clase 76', 'Embajada Boliviana', 'Taller Para Niños']"),
#  ('Havelocke',
#   ' <a href="https://www.last.fm/music/Havelocke">Read more on Last.fm</a>',
#   774,
#   6218,
#   '[\'Delaire The Liar\', \'Slash Fiction\', \'Nervus\', \'From Inside\', "L\'exquisite Douleur"]'),
#  ('Indra Dhavsi',
#   ' <a href="https://www.last.fm/music/Indra+Dhavsi">Read more on Last.fm</a>',
#   23,
#   30,
#   '[]'),
#  ('Dr JB',
#   ' <a href="https://www.last.fm/music/DR+JB">Read more on Last.fm</a>',
#   47,
#   202,
#   "['Tsy Misy Roiroy', 'MAMY GOTSO', 'Arnaah', 'Ramaroson Wilson', 'Jerry Marcoss']"),
#  ('Arvind Akela Kallu Ji',
#   'Born on 26 July 1997, Arvind Akela (Kallu) is an Indian actor who is known for his Bhojpuri songs \'Murga Bechain Bate\' and \'Choliya Ke Huk Raja Ji\' , He is the most popular singer in the Bhojpuri Industry with fans worldwide. <a href="https://www.last.fm/music/Arvind+Akela+Kallu+Ji">Read more on Last.fm</a>',
#   3480,
#   20634,
#   "['Neelkamal Singh', 'Khesari Lal Yadav', 'Shivani Singh', 'R Jay Kang', 'Ritesh Pandey']"),
#  ('Oli Big',
#   ' <a href="https://www.last.fm/music/Oli+Big">Read more on Last.fm</a>',
#   25,
#   66,
#   '[]'),
#  ('TOTALFAT',
#   'TOTALFAT is melodic punk band formed in 1999 from Hachioji. TOTALFAT consisted of vocalist/guitarist Jose (ホセ), vocalist/bassist Shun, guitarist Kuboty, and drummer Bunta.\n\nTOTALFAT started out playing NOFX songs in 2000. Their shows were mainly songs of TEN FOOT POLE, MILLENCOLIN and SLICK SHOES.\n\nIn 2003, TOTALFAT released their 1st album entitled \'End of Introduction\', from a Japanese independent label named CATCH ALL RECORDS. They embarked on a CD release Japan tour which included 41 shows. The first album sold about 3,500 copies. <a href="https://www.last.fm/music/TOTALFAT">Read more on Last.fm</a>',
#   30726,
#   928501,
#   "['dustbox', 'Shank', 'HEY-SMITH', 'Ken Yokoyama', '04 Limited Sazabys']"),
#  ('BATTLE BOYS',
#   ' <a href="https://www.last.fm/music/BATTLE+BOYS">Read more on Last.fm</a>',
#   299,
#   4678,
#   '[]'),
#  ('Gopal Gurjar',
#   ' <a href="https://www.last.fm/music/Gopal+Gurjar">Read more on Last.fm</a>',
#   219,
#   414,
#   "['Ajay Hooda', 'Vishvajeet Choudhary', 'Renuka Panwar', 'Ruchika Jangid', 'Sandeep Surila']"),
#  ('Bianka',
#   ' <a href="https://www.last.fm/music/BIANKA">Read more on Last.fm</a>',
#   15726,
#   164575,
#   '[]'),
#  ('Farrux Xamrayev',
#   ' <a href="https://www.last.fm/music/Farrux+Xamrayev">Read more on Last.fm</a>',
#   225,
#   3848,
#   '[\'JASUR UMIROV\', \'Ummon\', \'Farrux Xamraev\', "Ulug\'bek Rahmatullayev", \'Botirjon Qodirov\']'),
#  ('Vlado Kreslin',
#   'Vlado Kreslin is one of the most recognizable Slovenian artists ever. His music is a mix of rock\'n\'roll, blues, folk and Slovenian national music. He started his musical career in 70s as a drummer in a group called Apollo. Then he played in couple of groups and after that he started a solo career. In the year 1983 Vlado started playing with Martin Krpan (Slovenian rock group) that produced one of his most known songs Od višine se zvrti. When he ended <a href="https://www.last.fm/music/Vlado+Kreslin">Read more on Last.fm</a>',
#   6198,
#   207835,
#   "['Big Foot Mama', 'Dan D', 'MI2', 'Zoran Predin', 'Martin Krpan']"),
#  ('Pawan Singh',
#   ' <a href="https://www.last.fm/music/Pawan+Singh">Read more on Last.fm</a>',
#   8828,
#   67079,
#   "['Khesari Lal Yadav', 'Neelkamal Singh', 'Samar Singh', 'Shilpi Raj', 'Shivani Singh']"),
#  ('Davi e Fernando',
#   ' <a href="https://www.last.fm/music/Davi+e+Fernando">Read more on Last.fm</a>',
#   2872,
#   8864,
#   "['Gaby Violeira', 'Zé Gustavo & Dominico', 'Bruno Reis & Thiago', 'Thiago Castelli', 'João de Souza & Bonifacio']"),
#  ('Jendral Kantjil',
#   ' <a href="https://www.last.fm/music/Jendral+Kantjil">Read more on Last.fm</a>',
#   213,
#   745,
#   "['pyong pyong', 'KarnaMereka', 'Superglad', 'MCPR', 'Still Virgin']"),
#  ('Joe Brown',
#   'There are more than one artists named Joe Brown:\n\n1. Joe Brown (born Joseph Roger Brown on 13 May 1941, in Swarby, Lincolnshire) is a popular British entertainer of the 1960s and beyond\n\n2. Joe Brown is also a virtually unknown harmonica player who appears on the Negro folk music of Alabama series.  \n\n3. A Korean hip-hop artist who is also in the Jiggy Fellaz crew.\n\n\n1) JOE BROWN:  Joseph Roger "Joe" Brown, MBE (born 13 May 1941,[1] Swarby, Lincolnshire) is an English entertainer. <a href="https://www.last.fm/music/Joe+Brown">Read more on Last.fm</a>',
#   48610,
#   286096,
#   "['Sandie Shaw', 'The Spencer Davis Group', 'Adam Faith', 'Petula Clark', 'The Seekers']"),
#  ('Domenico Modugno',
#   'Domenico Modugno (January 9, 1928 – August 6, 1994) was an Italian singer and songwriter.\n\nFrom a young age Domenico wanted to become an actor and in 1951, after his military service, he enrolled in an acting school. While still studying he had a role in a cinematographic version of Filumena Marturano by Eduardo De Filippo, and some other films.\n\nIn 1957, his song Lazzarella, sung by Aurelio Fierro, came second in the Festival della Canzone Napoletana, bringing him the first popularity. <a href="https://www.last.fm/music/Domenico+Modugno">Read more on Last.fm</a>',
#   180604,
#   1057012,
#   "['Gino Paoli', 'Marino Marini', 'Renato Carosone', 'Tony Dallara', 'Tony Renis']"),
#  ('Baidyanath Dash',
#   ' <a href="https://www.last.fm/music/Baidyanath+Dash">Read more on Last.fm</a>',
#   10,
#   37,
#   '[]'),
#  ('Nataliya Vlasova',
#   ' <a href="https://www.last.fm/music/Nataliya+Vlasova">Read more on Last.fm</a>',
#   614,
#   2490,
#   "['Maxim Fadeev', 'NePara', 'Irakli', 'Igor Nikolayev', 'Fabrika']"),
#  ('Legendboy',
#   ' <a href="https://www.last.fm/music/Legendboy">Read more on Last.fm</a>',
#   1380,
#   13187,
#   "['Ponwp', 'VARINZ', 'first anuwat', 'Maiyarap', 'UrboyTJ']"),
#  ('Amar Devarakonda',
#   ' <a href="https://www.last.fm/music/Amar+Devarakonda">Read more on Last.fm</a>',
#   1,
#   1,
#   '[]'),
#  ('Justin Tweito',
#   ' <a href="https://www.last.fm/music/Justin+Tweito">Read more on Last.fm</a>',
#   1309,
#   6328,
#   "['London Gatch', 'Luke + Anna Hellebronth', 'Matt Boswell', 'Cameron Keith', 'The Worship Initiative']"),
#  ('Ramesh Roshan',
#   ' <a href="https://www.last.fm/music/Ramesh+Roshan">Read more on Last.fm</a>',
#   1,
#   1,
#   '[]'),
#  ('Bubblegum Lemonade',
#   'Bubblegum Lemonade is a 1960s influenced 12-string Indiepop band based in Glasgow, Scotland. Their fondness of the Byrds, the Jesus and Mary Chain, the Beach Boys,  and the Monkees comes across on such songs as Caroline\'s Radio, Famous Blue Anorak, Surfin\' USB, She brings The Sunshine, and Falling In Love With A Sad Song.\n\nThey have, so far, released three CD albums; Doubleplusgood (November 2008), Sophomore Release (November 2010) and Some Like It Pop (November 2013). <a href="https://www.last.fm/music/Bubblegum+Lemonade">Read more on Last.fm</a>',
#   18151,
#   159541,
#   "['Strawberry Whiplash', 'The Electric Pop Group', 'The Airfields', 'The Felt Tips', 'Pocketbooks']"),
#  ('Ernest Ashworth',
#   'Ernest Bert Ashworth (December 15, 1928 – March 2, 2009) was an American country music singer and longtime Grand Ole Opry star. Signed to the Hickory label, he recorded two studio albums in his career and charted several singles on Billboard Hot Country Songs, including the number one "Talk Back Trembling Lips" and six other top ten hits. <a href="https://www.last.fm/music/Ernest+Ashworth">Read more on Last.fm</a>',
#   5093,
#   24279,
#   "['Tony Booth', 'Durwood Haddock', 'Leona Williams', 'Jan Howard', 'Crystal Sands']"),
#  ('Jike Junyi',
#   'Jike Junyi (Simplified Chinese: 吉克隽逸; Traditional Chinese: 吉克雋逸 | Pinyin: Jíkè juàn yì), also known as Summer Momoko (born May 13, 1988), is a Mandarin singer originating from Ganluo, Sichuan, China. She is best known as being the second runner-up of Season One of The Voice Of China. Junyi is also an actress and appeared in the movie Outcast with Nicholas Cage and Hayden Christensen. Junyi also colaborated with Snoop Dogg on her song Summer Time. <a href="https://www.last.fm/music/Jike+Junyi">Read more on Last.fm</a>',
#   2689,
#   20366,
#   "['吉克雋逸', '黃子弘凡', '吉克隽逸', 'Tiger Hu', 'Yisa Yu']"),
#  ('Stella Mengele',
#   ' <a href="https://www.last.fm/music/Stella+Mengele">Read more on Last.fm</a>',
#   9,
#   17,
#   '[]'),
#  ('Lee ALeum',
#   ' <a href="https://www.last.fm/music/Lee+ALeum">Read more on Last.fm</a>',
#   17,
#   30,
#   '[]'),
#  ('Румиса Никаева',
#   ' <a href="https://www.last.fm/music/%D0%A0%D1%83%D0%BC%D0%B8%D1%81%D0%B0+%D0%9D%D0%B8%D0%BA%D0%B0%D0%B5%D0%B2%D0%B0">Read more on Last.fm</a>',
#   110,
#   819,
#   "['Мадина Домбаева', 'Тамила Сагаипова', 'Элиза Идрисова', 'Makka Mezhieva', 'Ильяс Эбиев']"),
#  ('Ahmad Solo',
#   ' <a href="https://www.last.fm/music/Ahmad+Solo">Read more on Last.fm</a>',
#   314,
#   3867,
#   "['Sina Parsian', 'NOVAN', 'Yousef Zamani', 'Soheil Mehrzadegan', 'Emo band']"),
#  ('Mario Battaini',
#   ' <a href="https://www.last.fm/music/Mario+Battaini">Read more on Last.fm</a>',
#   3409,
#   19354,
#   "['Carlo Venturi', 'Castellina-Pasi', 'Jean Segurel', 'Michel Pruvot', 'Gigi Stok']"),
#  ('KIM of Diamonds',
#   ' <a href="https://www.last.fm/music/KIM+of+Diamonds">Read more on Last.fm</a>',
#   54,
#   437,
#   '[]'),
#  ('Yma Sumac',
#   'Yma Sumac (September 13, 1922 – November 1, 2008) was the stage name of a Peruvian singer named Zoila Augusta Emperatriz Chavarri del Castillo. When still a child in rural Peru, she attracted notice for her extraordinary voice, and joined the Compañía Peruana de Arte in the early 1940s. \n\nYma Súmac was born in Callao, El Callao, Peru. Other dates mentioned in her various biographies range from 1921 to 1929. Some sources claim that she was not born in Ichocán <a href="https://www.last.fm/music/Yma+Sumac">Read more on Last.fm</a>',
#   165356,
#   1639673,
#   "['Les Baxter', 'Martin Denny', 'Arthur Lyman', 'Esquivel', 'Tak Shindo']"),
#  ('Playground Circus',
#   'Playground Circus is a Punk-Rock band formed in northern Greece during 2013.\nThey released their debut EP in 2014, entitled “The King is Born” and took to the stages of Europe to spread their music. Among the artists that they have shared the stage with are: Marky Ramone (Ramones), Michael Graves (Misfits), House of Pain, This is a Standoff, Barb Wire Dolls, Atlas Losing Grip, Everlast and many more. At the moment they are at the final stages of mixing and mastering their latest work entitled “King for a Day”. <a href="https://www.last.fm/music/Playground+Circus">Read more on Last.fm</a>',
#   345,
#   1291,
#   "['Scooped up!', 'Bronnie', 'Rival Town', 'Static Authority', 'Worst in Me']"),
#  ('Walter Wanderley',
#   'A Brazilian organist/composer who stumbled upon a gold mine in the 1960s, Walter Wanderley has been resurrected posthumously in the 1990s, a purveyor of lounge music for a young generation. Yet his sound on the organ, generated by a crisp, lightweight, staccato attack, can be mistaken for no one else\'s - and his choice of material showed much good taste, particularly when exploring his countrymen\' s songs. Although his most popular records contained only a minimum of melodic jazz improvisation, he could stretch out when he wanted to. <a href="https://www.last.fm/music/Walter+Wanderley">Read more on Last.fm</a>',
#   290544,
#   2461473,
#   '[\'Tamba Trio\', \'Roberto Menescal E Seu Conjunto\', \'Astrud Gilberto\', "Sérgio Mendes & Brasil \'66", \'Herb Alpert and the Tijuana Brass\']'),
#  ('Sarat Nayak',
#   ' <a href="https://www.last.fm/music/Sarat+Nayak">Read more on Last.fm</a>',
#   3,
#   39,
#   '[]'),
#  ('Odair Jose',
#   ' <a href="https://www.last.fm/music/+noredirect/Odair+Jose">Read more on Last.fm</a>',
#   27346,
#   267161,
#   '[]'),
#  ('Airbag',
#   'There are  at least 9 bands with the same name:\n\n1. Airbag,  from Norway\n2. Airbag, from Spain\n3. Airbag, from Argentina\n4. Airbag, from South Korea.\n5. Airbag, from Bulgaria\n6. Airbag, from the Netherlands\n7. Airbag, from China\n8. Airbag, from Japan\n9. Airbag, from Czech Republic\n\n1 .Airbag is a five member progressive rock group from Norway. The line up (from 2010) is Anders Hovdan - Bass, Asle Tostrup - Vocals, guitar, Bjørn Riis - Guitar, vocals, Henrik Fossum - Drums and Jørgen Hagen - Keyboards. <a href="https://www.last.fm/music/Airbag">Read more on Last.fm</a>',
#   152008,
#   6236658,
#   "['Bjørn Riis', 'RPWL', 'The Pineapple Thief', 'Gazpacho', 'Nosound']"),
#  ('Nueva Vulcano',
#   'After Aina split up, Artur Estrada, his singer and guitarrist decided to make a new band with Albert Guárdia (also Drummer for The Moon Men) and Bassist ex-Shanty Rd.\'s Wences Aparicio. Their sound is inclassificable in any genre, some influences are Los Planetas, My Bloody Valentine, Hüsker Dü and Jawbox. ¡A mi me gustan más que a un tonto un lápiz! (I like them more than a fat kid loves cakes!) <a href="https://www.last.fm/music/Nueva+Vulcano">Read more on Last.fm</a>',
#   18975,
#   636459,
#   "['Madee', 'Half Foot Outside', 'The Unfinished Sympathy', 'Betunizer', 'Nisei']"),
#  ('Diamante Negro',
#   'Un fisioterapeuta, un enfermero y un técnico de sonido. Dos de ellos fueron amigos y luego compañeros de escenario y al otro lo conocieron en la escena barcelonesa, concretamente en las caóticas noches de fiesta de la capital catalana. La primera vez que tocaron juntos no sabían ni qué era exactamente Diamante Negro. Probablemente a día de hoy tampoco lo saben, aunque a diferencia de cómo era antes, ahora les da igual y por eso basan su música en la libertad y en la ausencia de límites. <a href="https://www.last.fm/music/Diamante+Negro">Read more on Last.fm</a>',
#   11307,
#   155898,
#   "['La trinidad', 'Camellos', 'Mediapunta', 'Toldos Verdes', 'Futuro Terror']"),
#  ('Pablo Prisma y las Pirámides',
#   ' <a href="https://www.last.fm/music/Pablo+Prisma+y+las+Pir%C3%A1mides">Read more on Last.fm</a>',
#   1094,
#   15596,
#   '[]'),
#  ('Melenas',
#   'Melenas are an indie guitar pop band from Pamplona, Spain. Their self-titled début album, Melenas, was released in November 2017. Sophomore outing, Dias Raros, followed in May 2020 on Trouble In Mind Records. <a href="https://www.last.fm/music/Melenas">Read more on Last.fm</a>',
#   26803,
#   310094,
#   "['Mujeres', 'Triángulo de Amor Bizarro', 'Nation of Language', 'Pale Blue Eyes', 'Deeper']"),
#  ('Nolasco',
#   ' <a href="https://www.last.fm/music/Nolasco">Read more on Last.fm</a>',
#   12725,
#   90498,
#   "['Los Rebujitos', 'Siempre Asi', 'juanlu montoya', 'Demarco Flamenco', 'Sarayma']"),
#  ('Grises',
#   ' <a href="https://www.last.fm/music/Grises">Read more on Last.fm</a>',
#   13028,
#   167407,
#   "['Jero Romero', 'Neuman', 'Buffetlibre', 'We Are Standard', 'Hola a todo el mundo']"),
#  ('from',
#   'There are at least three artists named From:\n\n1.  From was a very obscure jazz-fusion band from southern Germany, with a penchant for jamming, for long tracks and Miles Davis styled riffing.\n\n2. From is an LA wonderpop band founded by singer/writer/producer Roni Brunn. The lineup features Paul Best on guitar, Nick Bond on keyboards, Rodrigo Nunes on drums, and Valerie Ngai on bass.\n\nFrom debuted with The American EP in 2006. The 6 track release was received with critical praise <a href="https://www.last.fm/music/From">Read more on Last.fm</a>',
#   6903,
#   69937,
#   "['Marcelo Criminal', 'Diamante Negro', 'el buen hijo', 'Marcos y Molduras', 'Mediapunta']"),
#  ('Alexie Divello',
#   ' <a href="https://www.last.fm/music/Alexie+Divello">Read more on Last.fm</a>',
#   2818,
#   10194,
#   "['Allertz', 'Electrick Village', 'Sebastian Sollerman', 'Made In June', 'John Alexander']"),
#  ('Barroso',
#   ' <a href="https://www.last.fm/music/BARROSO">Read more on Last.fm</a>',
#   1391,
#   6022,
#   "['León Bravo', 'Keen Levy', 'Dani MDR', 'Galvan Real', 'Sami Duque']"),
#  ('Joe Crepúsculo',
#   'Joe Crepúsculo, real name Joël Iriarte Parra, is a Spanish singer-songwriter. He has released eight solo albums (Escuela de zebras, Supercrepus —National Record of the Year for Rockdelux magazine—, Chill-out, Nuevo ritmo, El caldero , Wizard Ball, New Mysteries and Hard Drive).\n\nHe graduated in Philosophy at the University de Barcelona and began to form bands of many styles ranging from surf, rock, punk and electronics. Together with Daniel Granados and Vincent Leone he created Tarántula in 2003 <a href="https://www.last.fm/music/+noredirect/Joe+Crep%C3%BAsculo">Read more on Last.fm</a>',
#   41043,
#   983329,
#   "['Los Punsetes', 'Hidrogenesse', 'Nacho Vegas', 'Los Planetas', 'Sidonie']"),
#  ('Detergente Líquido',
#   ' <a href="https://www.last.fm/music/Detergente+L%C3%ADquido">Read more on Last.fm</a>',
#   1623,
#   40744,
#   "['Hazte Lapón', 'Betacam', 'Alexanderplatz', 'Kokoshca', 'Rusos Blancos']"),
#  ('Bravo Fisher!',
#   ' <a href="https://www.last.fm/music/Bravo+Fisher%21">Read more on Last.fm</a>',
#   3960,
#   45093,
#   "['Rusos Blancos', 'Ellos', 'Klaus & Kinski', 'Jero Romero', 'Algora']"),
#  ('Pitovnis',
#   ' <a href="https://www.last.fm/music/Pitovnis">Read more on Last.fm</a>',
#   540,
#   5180,
#   "['Ragdog', 'Indras', 'MISTER COMETA', 'Jaula de Grillos', 'Melocos']"),
#  ('The Reflectors',
#   'Indie-pop stories of a post-it life from Brooklyn, USA. \n\nFree spins, sketches and random musings at http://thereflectors.bandcamp.com <a href="https://www.last.fm/music/The+Reflectors">Read more on Last.fm</a>',
#   1591,
#   18348,
#   "['The Speedways', 'The Whiffs', 'Brad Marino', 'Uni Boys', 'The Boys With The Perpetual Nervousness']"),
#  ('Autoescuela',
#   'Autoescuela is a rock band from Asturias, Spain. <a href="https://www.last.fm/music/autoescuela">Read more on Last.fm</a>',
#   4238,
#   121729,
#   "['Marcelo Criminal', 'Los lagos de Hinault', 'Anne Lukin', 'Marcos y Molduras', 'Camellos']"),
#  ('Chucho',
# ...
#   2330,
#   11791,
#   "['Yockie Suryoprayogo', 'Harry Roesli Gang', 'Shanty', 'Panbers', 'Gito Rollies']"),
#  ('Sars Bharti',
#   ' <a href="https://www.last.fm/music/Sars+Bharti">Read more on Last.fm</a>',
#   19,
#   43,
#   '[]'),
#  ('Pk Deep',
#   ' <a href="https://www.last.fm/music/Pk+Deep">Read more on Last.fm</a>',
#   7,
#   25,
#   '[]'),
#  ('Altamira',
#   'There is possibly more than one artist with this name.\n\n1.) Altamira is a melodic crust band from Chicago.\n2.) Altamira is a Czech alternative/new age band.\n3.) Altamira is an instrumental progressive-punk-jazz trio from Philadelphia.\n4.) َAltamira is an Atmospheric Gothic/Doom Metal band from Hungary.\n\nAltamira from Philadelphia changed its name to MANY ARMS June 2009\nnew site: www.last.fm/music/Many+Arms <a href="https://www.last.fm/music/Altamira">Read more on Last.fm</a>',
#   120157,
#   1187679,
#   "['Trunks', 'Pineapple StormTV', 'Orgânico', 'Bin', 'San Joe']"),
#  ('Guru Haryanvi',
#   ' <a href="https://www.last.fm/music/Guru+Haryanvi">Read more on Last.fm</a>',
#   16,
#   63,
#   "['D Naveen', 'Khasa Aala Chahar', 'Manisha Sharma', 'Gold E Gill', 'Amit Dhull']"),
#  ('Kaysee',
#   ' <a href="https://www.last.fm/music/Kaysee">Read more on Last.fm</a>',
#   496,
#   2651,
#   "['Tonmoy Krypton', 'Shankuraj Konwar', 'Abhi Saikia', 'Sannidhya Bhuyan', 'Debabrata Gogoi']"),
#  ('Aasif Sayar Mewati',
#   ' <a href="https://www.last.fm/music/Aasif+Sayar+Mewati">Read more on Last.fm</a>',
#   8,
#   9,
#   '[]'),
#  ('Sazqia Rayani',
#   ' <a href="https://www.last.fm/music/Sazqia+Rayani">Read more on Last.fm</a>',
#   46,
#   140,
#   "['Arief', 'Aprilian', 'Yollanda', 'Tryana', 'Randa Putra']"),
#  ('Suman Chouhan',
#   ' <a href="https://www.last.fm/music/Suman+Chouhan">Read more on Last.fm</a>',
#   11,
#   19,
#   '[]'),
#  ('Antara Chakraborty',
#   ' <a href="https://www.last.fm/music/Antara+Chakraborty">Read more on Last.fm</a>',
#   55,
#   157,
#   "['Mantu Chhuria', 'Swayam Padhi', 'Aseema Panda', 'Kuldeep Pattanaik', 'Abinash Dash']"),
#  ('A C Bhardwaj',
#   ' <a href="https://www.last.fm/music/A+C+Bhardwaj">Read more on Last.fm</a>',
#   95,
#   219,
#   "['Nati King Kuldeep Sharma', 'Loki Verma', 'Ik Baaz', 'Surender Suri', 'vicky chauhan']"),
#  ('Sam C.S.',
#   ' <a href="https://www.last.fm/music/Sam+C.S.">Read more on Last.fm</a>',
#   14531,
#   251111,
#   "['DHIBU NINAN THOMAS', 'G. V. Prakash', 'Santhosh Narayanan', 'Yuvan Shankar Raja', 'Anirudh Ravichander']"),
#  ('Makk Makk',
#   ' <a href="https://www.last.fm/music/Makk+Makk">Read more on Last.fm</a>',
#   35,
#   89,
#   "['Manisha Sharma', 'Sahil Dhull', 'Amit Dhull', 'Jassi Kirarkot', 'Deep Sidhu']"),
#  ('Vijay Chauhan',
#   ' <a href="https://www.last.fm/music/Vijay+Chauhan">Read more on Last.fm</a>',
#   115,
#   362,
#   "['Shilpi Raj', 'Samar Singh', 'Neelkamal Singh', 'Pramod Premi Yadav', 'Khesari Lal Yadav']"),
#  ('Anil Nagori',
#   ' <a href="https://www.last.fm/music/Anil+Nagori">Read more on Last.fm</a>',
#   42,
#   174,
#   "['Jaya Kishori', 'Manoj Mishra', 'Jeetu Sharma', 'Prem Bhushan Maharaj', 'Pujya Prembhushanji Maharaj']"),
#  ('Gangadhar Bindhani',
#   ' <a href="https://www.last.fm/music/Gangadhar+Bindhani">Read more on Last.fm</a>',
#   35,
#   192,
#   "['SONAMANI PRODUCTION', 'Hara Rakab Production', 'Shiv Soren', 'Aman Murmu', 'Shivendra Murmu']"),
#  ('Raju Soren',
#   ' <a href="https://www.last.fm/music/Raju+Soren">Read more on Last.fm</a>',
#   55,
#   523,
#   "['Shivendra Murmu', 'Santhali Diwana', 'Ram Mardi', 'Dingra Boyz', 'GUHIRAM MURMU']"),
#  ('Saurav Maithani',
#   ' <a href="https://www.last.fm/music/Saurav+Maithani">Read more on Last.fm</a>',
#   201,
#   1724,
#   "['Rohit Chauhan', 'Gajendra Rana', 'Darshan Farswan', 'Manoj Arya', 'Narendra Singh Negi']"),
#  ('Bheem Kanoje',
#   ' <a href="https://www.last.fm/music/Bheem+Kanoje">Read more on Last.fm</a>',
#   137,
#   246,
#   "['Kamlesh Barot', 'Snake Church', 'Candy Ambulance', 'Vishal Khera', 'Ipeleng']"),
#  ('Bablu Ankiya',
#   ' <a href="https://www.last.fm/music/Bablu+Ankiya">Read more on Last.fm</a>',
#   59,
#   152,
#   "['Kapil Jangir', 'Jugraj Sandhu', 'Guri', 'Karan Randhawa', 'Gurnam Bhullar']"),
#  ('Charan Raj',
#   ' <a href="https://www.last.fm/music/Charan+Raj">Read more on Last.fm</a>',
#   1204,
#   28807,
#   "['Vasuki Vaibhav', 'Sanjith Hegde', 'B. Ajaneesh Loknath', 'All OK', 'ADHVIK']"),
#  ('Mantu Chhuria',
#   ' <a href="https://www.last.fm/music/Mantu+Chhuria">Read more on Last.fm</a>',
#   290,
#   2438,
#   "['Aseema Panda', 'Humane Sagar', 'Bijay Anand Sahu', 'Kuldeep Pattanaik', 'Kuldeep Pattnaik']"),
#  ('Deepak Raj Yadav',
#   ' <a href="https://www.last.fm/music/Deepak+Raj+Yadav">Read more on Last.fm</a>',
#   152,
#   391,
#   "['Ritesh Pandey', 'Neelkamal Singh', 'Khesari Lal Yadav', 'Indu Sonali', 'Shilpi Raj']"),
#  ('Ritesh Thakur',
#   ' <a href="https://www.last.fm/music/ritesh+thakur">Read more on Last.fm</a>',
#   5,
#   10,
#   '[]'),
#  ('Montu Moni Saikia',
#   ' <a href="https://www.last.fm/music/Montu+Moni+Saikia">Read more on Last.fm</a>',
#   135,
#   496,
#   "['Neel Akash', 'Dikshu', 'Achurjya Borpatra', 'Bhaskar Opswel', 'Simanta Shekhar']"),
#  ('Amit Mittu',
#   ' <a href="https://www.last.fm/music/Amit+Mittu">Read more on Last.fm</a>',
#   23,
#   80,
#   "['Ishant Bhardwaj', 'Sushma Negi', 'Sunil Rana Hiyunri', 'Karnail Rana', 'Nati King Kuldeep Sharma']"),
#  ('Sricharan Mohanty',
#   ' <a href="https://www.last.fm/music/Sricharan+Mohanty">Read more on Last.fm</a>',
#   34,
#   116,
#   "['Humane Sagar', 'Kuldeep Pattnaik', 'Abinash Dash', 'Namita Agrawal']"),
#  ('Biswajeet Sarkar',
#   ' <a href="https://www.last.fm/music/Biswajeet+Sarkar">Read more on Last.fm</a>',
#   31,
#   175,
#   "['ZdL', 'Pawan', 'Nitesh Kachhap', 'Manoj Shahri', 'Nagpuri Diwana']"),
#  ('Namita Agrawal',
#   ' <a href="https://www.last.fm/music/Namita+Agrawal">Read more on Last.fm</a>',
#   336,
#   4376,
#   "['Kumar Bapi', 'Bhikhari Bala', 'Bhikari Bal', 'Humane Sagar', 'Ira Mohanty']"),
#  ('Narendra Kumar',
#   ' <a href="https://www.last.fm/music/Narendra+Kumar">Read more on Last.fm</a>',
#   44,
#   150,
#   "['Arabinda Muduli', 'Anasuya Nath', 'Namita Agrawal', 'Basanta Patra', 'md. aziz']"),
#  ('Patrick Dimon',
#   ' <a href="https://www.last.fm/music/Patrick+Dimon">Read more on Last.fm</a>',
#   1186,
#   7467,
#   '["Trepidant\'s", \'Montana Country\', \'Decada Explosiva\', \'Steve MacLean\', \'Terry Winter\']'),
#  ('Vinu Gaur',
#   ' <a href="https://www.last.fm/music/Vinu+Gaur">Read more on Last.fm</a>',
#   557,
#   1957,
#   "['Dev Kumar Deva', 'Sandeep Surila', 'SURENDER ROMIO', 'Gajender Phogat', 'Ajay Hooda']"),
#  ('Thakur Dass Rathi',
#   ' <a href="https://www.last.fm/music/Thakur+Dass+Rathi">Read more on Last.fm</a>',
#   74,
#   328,
#   "['Inder Jeet', 'Dimple Thakur', 'Pankaj Thakur', 'vicky chauhan', 'Nati King Kuldeep Sharma']"),
#  ('Vinay Nayak',
#   ' <a href="https://www.last.fm/music/Vinay+Nayak">Read more on Last.fm</a>',
#   71,
#   219,
#   "['Jignesh Barot', 'Vijay Jornang', 'Santvani Trivedi', 'Kirtidan Gadhvi', 'Jignesh Kaviraj']"),
#  ('Rajneesh Patel',
#   ' <a href="https://www.last.fm/music/Rajneesh+Patel">Read more on Last.fm</a>',
#   132,
#   701,
#   "['Preet Bandre', 'Prashant Nakti', 'Vaishali Samant', 'Swapnil Bandodkar', 'Shubhangii Kedar']"),
#  ('Nathan Lms',
#   ' <a href="https://www.last.fm/music/Nathan+Lms">Read more on Last.fm</a>',
#   252,
#   2613,
#   "['Chingkhei Changgammayum', 'Abhisek Tongbram', 'Chand Ningthou', 'Scarxiom', 'Shei-Huum']"),
#  ('Medision Debbarma',
#   ' <a href="https://www.last.fm/music/Medision+Debbarma">Read more on Last.fm</a>',
#   12,
#   67,
#   '[]'),
#  ('Krishna Moni Chutia',
#   ' <a href="https://www.last.fm/music/Krishna+Moni+Chutia">Read more on Last.fm</a>',
#   12,
#   27,
#   "['Shruti Rane', 'Chamath Sangeeth', 'Madhushree', 'Abhijeet Sawant']"),
#  ('Aseema Panda',
#   ' <a href="https://www.last.fm/music/Aseema+Panda">Read more on Last.fm</a>',
#   197,
#   1153,
#   "['Mantu Chhuria', 'Humane Sagar', 'Bijay Anand Sahu', 'Kuldeep Pattanaik', 'Swayam Padhi']"),
#  ('Monu Negii',
#   ' <a href="https://www.last.fm/music/Monu+Negii">Read more on Last.fm</a>',
#   1,
#   1,
#   '[]'),
#  ('Surya Negi',
#   ' <a href="https://www.last.fm/music/Surya+Negi">Read more on Last.fm</a>',
#   2,
#   3,
#   '[]'),
#  ('G. V. Prakash',
#   'G. V. Prakash Kumar is an Indian composer, actor, producer and singer. He has predominantly scored music for Tamil films. His first film was S Pictures\' Veyyil.  <a href="https://www.last.fm/music/G.+V.+Prakash">Read more on Last.fm</a>',
#   24936,
#   1078748,
#   "['Santhosh Narayanan', 'Anirudh Ravichander', 'Yuvan Shankar Raja', 'Hiphop Tamizha', 'Harris Jayaraj']"),
#  ('Refo Dan Fauna',
#   ' <a href="https://www.last.fm/music/Refo+Dan+Fauna">Read more on Last.fm</a>',
#   5948,
#   65373,
#   "['Orkes Pensil Alis', 'MAMANG KESBOR', 'Candra Darusman', 'NonaRia', 'FLEUR!']"),
#  ('Sandeep Roy',
#   ' <a href="https://www.last.fm/music/sandeep+roy">Read more on Last.fm</a>',
#   13,
#   1682,
#   '[]'),
#  ('Wassi Wanted Mewati',
#   ' <a href="https://www.last.fm/music/Wassi+Wanted+Mewati">Read more on Last.fm</a>',
#   2,
#   3,
#   '[]'),
#  ('Aditya Yadav',
#   ' <a href="https://www.last.fm/music/Aditya+Yadav">Read more on Last.fm</a>',
#   3167,
#   21965,
#   "['Stebin Ben', 'Prashant Katheriya', 'Saaj Bhatt', 'Shivai Vyas', 'siddharth slathia']"),
#  ('Kundan Kumar',
#   ' <a href="https://www.last.fm/music/Kundan+Kumar">Read more on Last.fm</a>',
#   16,
#   40,
#   '[]'),
#  ('Pawan Roy',
#   ' <a href="https://www.last.fm/music/Pawan+Roy">Read more on Last.fm</a>',
#   123,
#   1163,
#   "['Nagpuri Diwana', 'Pawan', 'Ignesh Kumar', 'Manoj Sahri', 'Chhotelal Oraon']"),
#  ('Roshan Vaishnav',
#   ' <a href="https://www.last.fm/music/Roshan+Vaishnav">Read more on Last.fm</a>',
#   34,
#   110,
#   "['Mongra Vishwakarma', 'Khesari Lal Yadav']"),
#  ('Ades Sadewa',
#   ' <a href="https://www.last.fm/music/Ades+Sadewa">Read more on Last.fm</a>',
#   14,
#   56,
#   '[]'),
#  ('Geetika Devdas',
#   ' <a href="https://www.last.fm/music/Geetika+Devdas">Read more on Last.fm</a>',
#   1,
#   1,
#   '[]'),
#  ('the butterfly effect_india',
#   ' <a href="https://www.last.fm/music/the+butterfly+effect_india">Read more on Last.fm</a>',
#   91,
#   812,
#   "['Debabrata Gogoi', 'Aarxslan', 'Bishrut Saikia', 'Prabin Borah', 'Shankuraj Konwar']"),
#  ('RB Gujjar',
#   ' <a href="https://www.last.fm/music/RB+Gujjar">Read more on Last.fm</a>',
#   254,
#   1453,
#   "['Khasa Aala Chahar', 'Fazilpuria', 'Raj Mawar', 'R Maan', 'Sahil Dhull']"),
#  ('Sumit Singh Chandravanshi',
#   ' <a href="https://www.last.fm/music/Sumit+Singh+Chandravanshi">Read more on Last.fm</a>',
#   45,
#   67,
#   "['Shilpi Raj', 'Ankush Raja', 'Samar Singh', 'Khesari Lal Yadav', 'Neelkamal Singh']"),
#  ('Richhpal Dhaliwal',
#   ' <a href="https://www.last.fm/music/Richhpal+Dhaliwal">Read more on Last.fm</a>',
#   14,
#   17,
#   '[]'),
#  ('Sathyaprakash',
#   ' <a href="https://www.last.fm/music/Sathyaprakash">Read more on Last.fm</a>',
#   5866,
#   67968,
#   "['Ghibran', 'Vivek - Mervin', 'Darbuka Siva', 'Silambarasan TR', 'Thalapathy Vijay']"),
#  ('Riyan Brebet',
#   ' <a href="https://www.last.fm/music/Riyan+Brebet">Read more on Last.fm</a>',
#   44,
#   122,
#   '[]'),
#  ('Hozan Muzaffer',
#   ' <a href="https://www.last.fm/music/HOZAN+MUZAFFER">Read more on Last.fm</a>',
#   42,
#   437,
#   "['Cansever', 'Şehribana Kurdi', 'Koma Amed', 'bismilli zeko', 'Grup Seyran']"),
#  ('Analaga',
#   'Eduardo Borges de Souza, better known as Dudu Borges and, in some cases, by the artistic name Analaga (Campo Grande, March 28, 1983), is a Brazilian multi-instrumentalist, composer, arranger, and music producer.\n\nHe is a former member of the Christian rock band Resgate, in which he participated from 2002 to 2012, acting as a keyboardist, composer, and music producer. However, most of his notoriety was acquired by working with artists in the sertanejo music scene <a href="https://www.last.fm/music/ANALAGA">Read more on Last.fm</a>',
#   46467,
#   318981,
#   "['Black Days', 'Danna Lisboa', 'Mariana Rios', 'Francinne', 'Dreicon']"),
#  ('Alex e Leandro',
#   ' <a href="https://www.last.fm/music/alex+e+leandro">Read more on Last.fm</a>',
#   505,
#   1664,
#   "['Mariana & Mateus', 'Mayke & Rodrigo', 'Adriano Rhod', 'Bruno & Denner', 'PH e Michel']"),
#  ('Bhungar Khan',
#   ' <a href="https://www.last.fm/music/Bhungar+Khan">Read more on Last.fm</a>',
#   68,
#   2210,
#   "['Memraj Lawa Thadiya', 'Ajit Babu', 'Kanaram Depan', 'Ajeet Premi', 'Tahseem Dehangal']"),
#  ('Shiva Choudhary',
#   ' <a href="https://www.last.fm/music/Shiva+Choudhary">Read more on Last.fm</a>',
#   2586,
#   21542,
#   "['Raj Mawar', 'Renuka Panwar', 'Gajender Phogat', 'Gagan Haryanvi', 'Pawan Pilania']"),
#  ('Ajay Chauhan',
#   ' <a href="https://www.last.fm/music/Ajay+Chauhan">Read more on Last.fm</a>',
#   267,
#   1754,
#   "['Vicky Rajta', 'Nati King Kuldeep Sharma', 'Ajju Tomar', 'Arun Justa', 'Suresh Sharma']"),
#  ('Jalal Khan Lava',
#   ' <a href="https://www.last.fm/music/Jalal+Khan+Lava">Read more on Last.fm</a>',
#   11,
#   33,
#   '[]'),
#  ('Chaman Lehri',
#   ' <a href="https://www.last.fm/music/Chaman+Lehri">Read more on Last.fm</a>',
#   72,
#   198,
#   "['Muhfaad', 'Jassie Gill', 'Raf Saperra', 'Sharn', 'Miss Pooja']"),
#  ('Babloo Rapta',
#   ' <a href="https://www.last.fm/music/Babloo+Rapta">Read more on Last.fm</a>',
#   4,
#   37,
#   "['Mahender Sharonthi', 'Arun Justa', 'Keval Ram Basta', 'Strings, Rohail Hyatt', 'Shafqat Amanat Ali, Rohail Hyatt']"),
#  ('Maxter Warjri and The Band',
#   ' <a href="https://www.last.fm/music/Maxter+Warjri+and+The+Band">Read more on Last.fm</a>',
#   14,
#   83,
#   "['Desmond Rimaki Sunn', 'George Shadap']"),
#  ('Los Alfiles',
#   ' <a href="https://www.last.fm/music/Los+Alfiles">Read more on Last.fm</a>',
#   219,
#   954,
#   "['Los Moros', 'Los Linces', 'Siete Lunas', 'Daniel Agostini', 'Miguel Alejandro']"),
#  ('Rahmat Tahalu',
#   ' <a href="https://www.last.fm/music/Rahmat+Tahalu">Read more on Last.fm</a>',
#   1331,
#   6982,
#   "['VinKy YT', 'Sahrul Ckn', 'Dariz RMX', 'DJ Haning', 'Dj Komang Rimex']"),
#  ('Rambun Pamenan',
#   ' <a href="https://www.last.fm/music/Rambun+Pamenan">Read more on Last.fm</a>',
#   8,
#   21,
#   '[]'),
#  ('Anna Surwade',
#   ' <a href="https://www.last.fm/music/Anna+Surwade">Read more on Last.fm</a>',
#   17,
#   61,
#   "['Bhaiya More', 'Hiten Shivde', 'Prashant Desale', 'Vinod Kumavat', 'Jagdish Sandhanshiv']"),
#  ('Marito',
#   ' <a href="https://www.last.fm/music/Marito">Read more on Last.fm</a>',
#   3849,
#   14792,
#   "['Rodrigo Tapari', 'Sound De Barrio', 'El Reja', 'Sofia Gazzaniga', 'LemonChamp']"),
#  ('Puratana',
#   ' <a href="https://www.last.fm/music/Puratana">Read more on Last.fm</a>',
#   1,
#   2,
#   '[]'),
#  ('Neha Raj',
#   ' <a href="https://www.last.fm/music/Neha+Raj">Read more on Last.fm</a>',
#   131,
#   2351,
#   "['Chaman Srivastava', 'Pankaj Puri', 'Shailesh Premi', 'Sunita Yadav', 'Alwela Ashok']"),
#  ('Kuldeep Pattanaik',
#   ' <a href="https://www.last.fm/music/Kuldeep+Pattanaik">Read more on Last.fm</a>',
#   188,
#   1358,
#   "['Kuldeep Pattnaik', 'Humane Sagar', 'Anshuman Satapathy', 'Subhrajit Mohanty', 'Abinash Dash']"),
#  ('Naeem Hazarvi',
#   ' <a href="https://www.last.fm/music/Naeem+Hazarvi">Read more on Last.fm</a>',
#   438,
#   3083,
#   "['Zeeshan Khan Rokhri', 'Abrar-Ul-Haq', 'Naseebo Lal', 'Sahir Ali Bagga', 'Noor Jehan']"),
#  ('Zinti Panging',
#   ' <a href="https://www.last.fm/music/Zinti+Panging">Read more on Last.fm</a>',
#   1,
#   1,
#   '[]'),
#  ('Skd Raj',
#   ' <a href="https://www.last.fm/music/Skd+Raj">Read more on Last.fm</a>',
#   22,
#   82,
#   "['Tuntun Yadav', 'Chandan Chanchal', 'Neelkamal Singh', 'Samar Singh', 'Shivani Singh']"),
#  ('Panini Brunch',
#   ' <a href="https://www.last.fm/music/Panini+Brunch">Read more on Last.fm</a>',
#   810,
#   3391,
#   "['Shin Hyun Woo', 'Norwegian Wood', 'Sweden Laundry', 'NuitNuit', 'Kim Min seok']"),
#  ('Kinjal Dave',
#   ' <a href="https://www.last.fm/music/Kinjal+Dave">Read more on Last.fm</a>',
#   1318,
#   10788,
#   "['Geeta Rabari', 'Kirtidan Ghadhavi', 'Aishwarya Majmudar', 'Kirtidan Gadhvi', 'Jigardan Gadhavi']")]

# %%
values = list(df_values.itertuples(index=False, name=None))

# %%
import mysql.connector
from mysql.connector import errorcode

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='prueba_musictrends')


mycursor = cnx.cursor()
sql = "INSERT INTO lastfm (nombre_artista, bio, listeners, playcount, similar) VALUES (%s, %s, %s, %s,%s)"
val = values

try: 
    mycursor.executemany(sql, val)
    cnx.commit()
    print(mycursor.rowcount, "registro/s insertado/s.")

except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
# Out:
# 627 registro/s insertado/s.
