# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
CLIENT_ID = 'tu client_id'
CLIENT_SECRET = 'tu client_secret'

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
datos = sp.search(q="genre:rock, year:2020", type="track", limit=50, offset=50)

# %%
datos.keys()
# Out:
# dict_keys(['tracks'])

# %%
datos["tracks"].keys()
# Out:
# dict_keys(['href', 'limit', 'next', 'offset', 'previous', 'total', 'items'])

# %%
datos["tracks"]["items"]
# Out:
# [{'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['ES'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6C74xT2vstvQOMMFKhjMOv'},
#    'href': 'https://api.spotify.com/v1/albums/6C74xT2vstvQOMMFKhjMOv',
#    'id': '6C74xT2vstvQOMMFKhjMOv',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27306f4c87f75cefbb9952c0667'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0206f4c87f75cefbb9952c0667'},
#     {'height': 64,
#      'width': 64,
# ...

# %%
len(datos["tracks"]["items"])
# Out:
# 50

# %%
for i in range(0,500, 50):
    print(i)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450

# %%
for i in range(2020, 2026):
    q=f"genre:rock, year:{i}"
    print(q)
# Out:
# genre:rock, year:2020
# genre:rock, year:2021
# genre:rock, year:2022
# genre:rock, year:2023
# genre:rock, year:2024
# genre:rock, year:2025

# %%
datos["tracks"]["items"][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# datos["tracks"]["items"][0]["name"]
# Out:
# 'Superpoderes'
