# %% [markdown]
# # DATOS DE TRANCE DE LA API DE SPOTIFY

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# Python-dotenv could not parse statement starting at line 2
# True

# %%
sp_clave = os.getenv("Lau_Spotify_id")
sp_contraseña = os.getenv("Lau_Spotify_secret")

# %%
#Autentificación:
auth_manager = sp = SpotifyClientCredentials(client_id=sp_clave,
                                             client_secret=sp_contraseña)

sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
# buscamos con SEARCH - SEARCH FOR ITEM y aquí vemos los parámetros q son cesarios:

# 500 canciones por género y año ===> 250
# offset nos hace "páginas" en base al índice de los elementos
# limt = 50 y offset = 0 y luego 50, 100, 150, 200. etc hasta llegar al 500
# pensar una variable xa q nos lo haga solo
#for i in range(0, 5001, 50):
#   print(i)
#for i in range(2020, 2025):  # escogemos 5 años entre 2019-2023
#    q= f"genre:rock, year:{i}"
#    print(q)

# include_external no nos interesa

# vamos a Spotipy y vemos cómo se solicita desde aqui
# tenemos SEARCH:
# sp.search(q="", type="track", limit=50, offset=0) donde q= "genre:rock, year:2020"


# TENEMOS QUE EXTRAER: 
# #250 canciones por género y año (5 años entre 2019-2023), artista (nombre), género musical, tipo (canción = tracks), nombre (canción = "tracks"), año de lanzamiento, (excluimos ID)
# género musical (trance) y tipo (tracks) los añadimos al final porque son parámetros de la búsqueda (no nos van a salir como datos)
# podemos incluir nombre (álbum = "album") como next steps

# %%
datos_trance = sp.search(q="genre:trance, year:2019", type="track", limit=50, offset=0)

# %%
datos_trance.keys()
# Out:
# dict_keys(['tracks'])

# %%
datos_trance["tracks"]["items"][0].keys()
#interesan album, artists, id, name
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
datos_trance["tracks"]["items"][0]["name"]
# nombre de la primera cancion
# Out:
# 'Exile Babylon'

# %%
len(datos_trance["tracks"]["items"]) # tengo 50 items, registros
# Out:
# 50

# %%
len(datos_trance["tracks"]["items"][0]) # que son 18 keys en items
# Out:
# 18

# %%
datos_trance["tracks"]["items"][0]["album"].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'is_playable', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
datos_trance["tracks"]["items"][0]["album"]["release_date"]
# año de lanzamiento (album)
# Out:
# '2019-05-06'

# %%
datos_trance["tracks"]["items"][0]["album"]["artists"][0]["name"]
# nombre del artista
# Out:
# 'Har-El'

# %%
datos_trance["tracks"]["items"][0]["name"]
# nombre de la primera cancion
# Out:
# 'Exile Babylon'

# %%
datos_trance["tracks"]["items"][0]["album"]["release_date"]
# año de lanzamiento (album)
# Out:
# '2019-05-06'

# %%
canciones_trance = {"nombre_artista": [], "nombre_canción": [], "año_lanzamiento": []}

for datos in datos_trance["tracks"]["items"]:
    canciones_trance["nombre_artista"].append(datos["album"]["artists"][0]["name"])
    canciones_trance["nombre_canción"].append(datos["name"])
    canciones_trance["año_lanzamiento"].append(datos["album"]["release_date"])
    
    break  # 1 canción si quitamos el break da las 50 canciones de trance del primer offset (50) del año 2019
canciones_trance
# Out:
# {'nombre_artista': ['Har-El'],
#  'nombre_canción': ['Exile Babylon'],
#  'año_lanzamiento': ['2019-05-06']}

# %%
# parte de búsqueda por año y con el offset: 

for i in range(2019,2020):  # ahora pongo 1 año, uego será (2019,2024)
    print(i)
    for o in range(0,201,50):
        q=f"genre:roca:{i}"
        datos_trance = sp.search(q="genre:trance", type="track",limit=50,offset=o)
        print (datos_trance.keys())
        print(o)
    #for x in range(0,15):
        #(print(datos["tracks"]["items"][x]["name"]))
    #break
# Out:
# 2019
# dict_keys(['tracks'])
# 0
# dict_keys(['tracks'])
# 50
# dict_keys(['tracks'])
# 100
# dict_keys(['tracks'])
# 150
# dict_keys(['tracks'])
# 200

# %%
import json
import pandas as pd

# %%
canciones_trance = {"nombre_artista": [], "nombre_cancion": [], "año_lanzamiento": [], "género_musical": [], "tipo": []}
for anio in range(2019,2024):
    for offset in range(0, 250, 50):
        datos_trance = sp.search(q=f"genre:trance, year:{anio}", type="track", limit=50, offset=offset)
        for cancion in datos_trance["tracks"]["items"]:
            canciones_trance["nombre_artista"].append(cancion["album"]["artists"][0]["name"])
            canciones_trance["nombre_cancion"].append(cancion["name"])
            canciones_trance["género_musical"].append("trance")
            canciones_trance["año_lanzamiento"].append(cancion["album"]["release_date"])
            canciones_trance["tipo"].append(cancion["type"])
df_trance = pd.DataFrame(canciones_trance)
df_trance
# Out:
#        nombre_artista                                     nombre_cancion  \
# 0              Har-El                                      Exile Babylon
# 1     Various Artists                                 Fly into the Night
# 2     Various Artists                                The Last Conception
# 3     Various Artists                                     Carpo (AIR265)
# 4     Various Artists                                          Snowdrift
# ...               ...                                                ...
# 1245       Aly & Fila                               Soundscape (FSOE795)
# 1246     Andy Woldman              Dagger Eyes - Gav Easby Remix - Mixed
# 1247  Various Artists                        Devil's Deal - HIGH X Remix
# 1248     Manuel Rocca  Rennervate (LEVITATED 142) - Plutian Remix - M...
# 1249  Various Artists                                Dawn - Extended Mix
#
#      año_lanzamiento género_musical   tipo
# 0         2019-05-06         trance  track
# 1         2019-09-06         trance  track
# 2         2019-11-22         trance  track
# 3         2019-06-25         trance  track
# 4               2019         trance  track
# ...              ...            ...    ...
# 1245      2023-03-02         trance  track
# 1246      2023-11-27         trance  track
# 1247      2023-03-31         trance  track
# 1248      2023-02-24         trance  track
# 1249      2023-09-15         trance  track
#
# [1250 rows x 5 columns]

# %%
df_trance.to_csv("trancedatabase.csv")

# %%
df_values=pd.read_csv("trancedatabase.csv")

# %%
df_values
# Out:
#       Unnamed: 0   nombre_artista  \
# 0              0           Har-El
# 1              1    Stefre Roland
# 2              2  Various Artists
# 3              3  Various Artists
# 4              4          Key4050
# ...          ...              ...
# 1245        1245  Various Artists
# 1246        1246          Bynomic
# 1247        1247         deeinagi
# 1248        1248  Various Artists
# 1249        1249  Various Artists
#
#                                          nombre_cancion año_lanzamiento  \
# 0                                         Exile Babylon      2019-05-06
# 1                                  Miami - Original Mix      2019-02-14
# 2                                        Carpo (AIR265)      2019-06-25
# 3                                   The Last Conception      2019-11-22
# 4                                              Squirrel      2019-05-24
# ...                                                 ...             ...
# 1245                                           Mutagens      2023-04-21
# 1246                                       Coil - Mixed      2023-08-14
# 1247        Club Del Ocio - about : river Remix - Mixed      2023-11-24
# 1248  The Y Makes the Difference - Captivating Tranc...      2023-03-15
# 1249                       Party Season - Mainstage Mix      2023-03-16
#
#      género_musical   tipo
# 0            trance  track
# 1            trance  track
# 2            trance  track
# 3            trance  track
# 4            trance  track
# ...             ...    ...
# 1245         trance  track
# 1246         trance  track
# 1247         trance  track
# 1248         trance  track
# 1249         trance  track
#
# [1250 rows x 6 columns]

# %%
list(df_values.itertuples(index=False, name=None))
# seguimos teniendo el error de la primera columna con nuestros csv
# Out:
# [(0, 'Har-El', 'Exile Babylon', '2019-05-06', 'trance', 'track'),
#  (1, 'Stefre Roland', 'Miami - Original Mix', '2019-02-14', 'trance', 'track'),
#  (2, 'Various Artists', 'Carpo (AIR265)', '2019-06-25', 'trance', 'track'),
#  (3,
#   'Various Artists',
#   'The Last Conception',
#   '2019-11-22',
#   'trance',
#   'track'),
#  (4, 'Key4050', 'Squirrel', '2019-05-24', 'trance', 'track'),
#  (5, 'Various Artists', 'Beyond The Stars', '2019-11-14', 'trance', 'track'),
#  (6,
#   'Goa Doc',
#   'Jess Inspace - Psychedelic Goa Trance 2020 DJ Mixed',
#   '2019-11-27',
#   'trance',
#   'track'),
#  (7,
#   'Various Artists',
#   'Rearm - Extended Mix',
#   '2019-07-26',
#   'trance',
#   'track'),
#  (8,
#   'Various Artists',
#   'Lone Wanderer - Original Mix',
#   '2019-11-24',
#   'trance',
#   'track'),
#  (9,
#   'Airwave',
#   'Musings Of A Lifetime - Remastered Album Mix',
#   '2019-09-30',
#   'trance',
#   'track'),
#  (10,
#   'Various Artists',
#   'Superman - Bjorn Mandry Remix',
#   '2019-06-21',
#   'trance',
#   'track'),
#  (11,
#   'Various Artists',
#   'Kill The Fear - Extended Mix',
#   '2019-05-17',
#   'trance',
#   'track'),
#  (12,
#   'Armin van Buuren ASOT Radio',
#   'A State Of Trance (ASOT 941) - Track Recap, Pt. 2',
#   '2019-11-21',
#   'trance',
#   'track'),
#  (13,
#   'Various Artists',
#   'Eliphant - Original Mix',
#   '2019-12-19',
#   'trance',
#   'track'),
#  (14,
#   'Various Artists',
#   "Cosmodrome - Daniel Kandi Psy'lift Remix",
#   '2019-04-29',
#   'trance',
#   'track'),
#  (15, 'Various Artists', 'Strandloper', '2019-12-20', 'trance', 'track'),
#  (16, '40Thavha', 'Astronaut', '2019-09-23', 'trance', 'track'),
#  (17, 'Rodrigo Lapena', 'India', '2019-09-16', 'trance', 'track'),
#  (18,
#   'EL-Jay',
#   'The Door Of My Soul - 2010 Remix',
#   '2019-11-01',
#   'trance',
#   'track'),
#  (19,
#   'Various Artists',
#   'Julika - Kaiser Souzai Remix',
#   '2019-04-19',
#   'trance',
#   'track'),
#  (20, 'Various Artists', 'The Eridium', '2019-04-17', 'trance', 'track'),
#  (21, 'Bynomic', 'Frozen Dreams', '2019-07-01', 'trance', 'track'),
#  (22,
#   'Roman Messer Suanda Radio',
#   'Distance (Suanda 188) - Festival Mix',
#   '2019-08-21',
#   'trance',
#   'track'),
#  (23, 'Various Artists', 'The Sky', '2019-10-11', 'trance', 'track'),
#  (24,
#   'Armin van Buuren ASOT Radio',
#   "A State Of Trance (ASOT 926) - This Week's Service For Dreamers, Pt. 1",
#   '2019-08-08',
#   'trance',
#   'track'),
#  (25, 'Various Artists', 'Silver Clouds', '2019-04-25', 'trance', 'track'),
#  (26,
#   "Rick Pier O'Neil",
#   'Cancun - Replicanth & Rodrigo Cortazar Remix',
#   '2019-11-11',
#   'trance',
#   'track'),
#  (27,
#   'Andrew Rayel',
#   'Better Place (FYH156)',
#   '2019-05-22',
#   'trance',
#   'track'),
#  (28,
#   'Armin van Buuren ASOT Radio',
#   'A State Of Trance (ASOT 931) - Track Recap, Pt. 3',
#   '2019-09-12',
#   'trance',
#   'track'),
#  (29, 'Various Artists', 'Nyquist', '2019-03-20', 'trance', 'track'),
#  (30,
#   'Roman Messer Suanda Radio',
#   'Your Love (Suanda 205)',
#   '2019-12-18',
#   'trance',
#   'track'),
#  (31, 'Armos', 'A Volar - Armos Remix', '2019-01-14', 'trance', 'track'),
#  (32,
#   'Various Artists',
#   'Forever in Her Eyes - Danny Legatto Radio Cut',
#   '2019-05-24',
#   'trance',
#   'track'),
#  (33,
#   'Various Artists',
#   'New Life - Gaston Ponte Remix',
#   '2019-12-16',
#   'trance',
#   'track'),
#  (34,
#   "Cosmic Gate's Wake Your Mind Radio",
#   'Arm Strong (WYM257) - Extended Mix',
#   '2019-03-11',
#   'trance',
#   'track'),
#  (35,
#   'Amir Hussain',
#   'Noorwala Aaya Hai (Ya Rasulallah)',
#   '2019-12-05',
#   'trance',
#   'track'),
#  (36, 'Eric Lune', 'Milan to Minsk', '2019-10-21', 'trance', 'track'),
#  (37, 'Various Artists', 'Devotion', '2019-12-16', 'trance', 'track'),
#  (38,
#   'Various Artists',
#   'Colours - Outro Mix',
#   '2019-03-15',
#   'trance',
#   'track'),
#  (39, 'Various Artists', 'SychoActive', '2019-09-20', 'trance', 'track'),
#  (40,
#   'Nicola Maddaloni',
#   'New Horizons - VaNISH Remix',
#   '2019-07-15',
#   'trance',
#   'track'),
#  (41, 'Various Artists', 'Journey to Avalon', '2019-05-28', 'trance', 'track'),
#  (42, 'Juan Ibanez', 'Ariad', '2019-01-03', 'trance', 'track'),
#  (43,
#   'Pedro Capelossi',
#   'Cala Mystica - D.Jameson Remix',
#   '2019-01-14',
#   'trance',
#   'track'),
#  (44, 'Kenan Savrun', 'Rigel', '2019-02-18', 'trance', 'track'),
#  (45,
#   'Markus Schulz - Global DJ Broadcast',
#   'Come Home',
#   '2019-07-12',
#   'trance',
#   'track'),
#  (46,
#   'Various Artists',
#   'Ground Zero - Original',
#   '2019-01-07',
#   'trance',
#   'track'),
#  (47,
#   'California Sunshine',
#   'Backwards - Remix',
#   '2019-04-19',
#   'trance',
#   'track'),
#  (48,
#   'Felipe Michan',
#   'The Blue in Your Eyes',
#   '2019-04-29',
#   'trance',
#   'track'),
#  (49, 'Chris Giuliano', 'Cali Quake', '2019-10-11', 'trance', 'track'),
#  (50,
#   'Various Artists',
#   'Implant - Kasper Koman Remix',
#   '2019-10-18',
#   'trance',
#   'track'),
#  (51,
#   'Roman Messer Suanda Radio',
#   'Anywhere With You (Suanda 206) - Tom Exo Remix',
#   '2019-12-25',
#   'trance',
#   'track'),
#  (52,
#   'Various Artists',
#   'Through The Wormhole',
#   '2019-12-20',
#   'trance',
#   'track'),
#  (53,
#   'Chris Hampshire',
#   'The Door - Activa Remix',
#   '2019-05-03',
#   'trance',
#   'track'),
#  (54,
#   'Armin van Buuren ASOT Radio',
#   'A State Of Trance (Introduction) - Listen to my latest live set',
#   '2019-08-01',
#   'trance',
#   'track'),
#  (55,
#   'Roman Messer Suanda Radio',
#   'Butterfly (Suanda 164) - Alex Wright Remix',
#   '2019-03-06',
#   'trance',
#   'track'),
#  (56, 'Various Artists', 'License to Dance', '2019-06-14', 'trance', 'track'),
#  (57, 'Milos Miladinovic', 'Demain - Mixed', '2019-10-14', 'trance', 'track'),
#  (58,
#   "Ferry Corsten's Countdown",
#   'Boomerang (CC6033) - Igor S Mix',
#   '2019-01-18',
#   'trance',
#   'track'),
#  (59, 'Aldo Henrycho', 'Sunflowers', '2019-12-06', 'trance', 'track'),
#  (60, 'Various Artists', 'Clap Along', '2019-07-19', 'trance', 'track'),
#  (61,
#   'Nicola Maddaloni',
#   'Beh - Extended Mix',
#   '2019-06-28',
#   'trance',
#   'track'),
#  (62,
#   'Sneila',
#   'Meanwhile On Another Planet',
#   '2019-10-24',
#   'trance',
#   'track'),
#  (63,
#   'Various Artists',
#   'Voyager - Extended Mix',
#   '2019-08-02',
#   'trance',
#   'track'),
#  (64,
#   'Urban Meditation',
#   'Rings of Saturn (Bots Mix by Vudu Boss)',
#   '2019-11-05',
#   'trance',
#   'track'),
#  (65, 'Atomic Pulse', 'Cymatics Frequency', '2019-03-31', 'trance', 'track'),
#  (66,
#   'Pants',
#   'Malice In Wonderland - High Dosage Remix',
#   '2019-10-25',
#   'trance',
#   'track'),
#  (67,
#   'Various Artists',
#   'Hidden Life - Radio Cut',
#   '2019-08-02',
#   'trance',
#   'track'),
#  (68,
#   'Various Artists',
#   'Flow - Invisible Reality Remix',
#   '2019-07-19',
#   'trance',
#   'track'),
#  (69, 'Aevus', 'Renaissance', '2019-08-30', 'trance', 'track'),
#  (70,
#   'Various Artists',
#   'Running in Underground - Le Blanque Mix',
#   '2019-08-02',
#   'trance',
#   'track'),
#  (71,
#   'High Frequencies',
#   'Pentos - Extended Mix',
#   '2019-02-22',
#   'trance',
#   'track'),
#  (72,
#   'Various Artists',
#   'We Are One - Club Mix',
#   '2019-12-16',
#   'trance',
#   'track'),
#  (73,
#   'Juan Sapia',
#   'Here for You - Bookwood Remix',
#   '2019-07-15',
#   'trance',
#   'track'),
#  (74,
#   'Various Artists',
#   'Virtuoso - Didrapest Remix',
#   '2019-06-07',
#   'trance',
#   'track'),
#  (75, 'Tom Wax', 'You Make Me - Dub Mix', '2019-05-17', 'trance', 'track'),
#  (76,
#   'Andrew Rayel',
#   'Secret (FYH161) - Kinetic Mix',
#   '2019-06-26',
#   'trance',
#   'track'),
#  (77, 'Ricardo Piedra', 'Vagabond', '2019-02-11', 'trance', 'track'),
#  (78, 'Alexander Popov', 'You', '2019-10-04', 'trance', 'track'),
#  (79, 'Stargazers', 'Black Diamond', '2019-11-01', 'trance', 'track'),
#  (80,
#   'Bynomic',
#   'The Girl From the Universe',
#   '2019-03-11',
#   'trance',
#   'track'),
#  (81,
#   'Various Artists',
#   'Step Outside - Matt Darey Extended Trance Mix',
#   '2019-08-02',
#   'trance',
#   'track'),
#  (82,
#   'Anjunabeats',
#   'Group Therapy (Messages Pt. 4) [ABGT359]',
#   '2019-12-15',
#   'trance',
#   'track'),
#  (83,
#   'Various Artists',
#   'Declare - Atomic Pulse Remix',
#   '2019-05-07',
#   'trance',
#   'track'),
#  (84,
#   'Anjunabeats',
#   'Group Therapy (Messages Pt. 7) [ABGT358]',
#   '2019-12-08',
#   'trance',
#   'track'),
#  (85,
#   'Various Artists',
#   'Dreamer (Tommy Reid Remix)',
#   '2019-06-28',
#   'trance',
#   'track'),
#  (86,
#   'Various Artists',
#   'Sharazed - The Painkillers Remix',
#   '2019-08-17',
#   'trance',
#   'track'),
#  (87,
#   "Rick Pier O'Neil",
#   'Idea - Ryan Halifax Remix',
#   '2019-01-26',
#   'trance',
#   'track'),
#  (88,
#   'Ori Uplift',
#   'Wonderful Feeling [UpOnly 355] - Ryan Raeside - Mix Cut',
#   '2019-12-03',
#   'trance',
#   'track'),
#  (89, 'Madwave', 'Interlunium - Radio Mix', '2019-04-01', 'trance', 'track'),
#  (90,
#   'Various Artists',
#   'Zero Gravity - Roman Messer Remix',
#   '2019-03-22',
#   'trance',
#   'track'),
#  (91, 'Various Artists', 'Uprising', '2019-06-21', 'trance', 'track'),
#  (92, 'Ronski Speed', 'Arise - Club Mix 2', '2019-08-19', 'trance', 'track'),
#  (93,
#   'Goa Doc',
#   'Inner Earth - Goa Psytrance 2020 DJ Mixed',
#   '2019-11-25',
#   'trance',
#   'track'),
#  (94, 'Various Artists', 'Blossom', '2019-11-01', 'trance', 'track'),
#  (95, 'Various Artists', 'Arca', '2019-03-20', 'trance', 'track'),
#  (96, 'Various Artists', 'Juno', '2019-08-23', 'trance', 'track'),
#  (97,
#   'Roman Messer Suanda Radio',
#   'Serenity (Suanda 204)',
#   '2019-12-11',
#   'trance',
#   'track'),
#  (98,
#   'Various Artists',
#   'Balearic Soul - Dreamy Remix',
#   '2019-03-14',
#   'trance',
#   'track'),
#  (99,
#   'Various Artists',
#   'Energy Flows in You - Radio Edit',
#   '2019-05-10',
#   'trance',
#   'track'),
#  (100,
#   'Various Artists',
#   'Gravitational Pull',
#   '2019-07-26',
#   'trance',
#   'track'),
#  (101,
#   'Various Artists',
#   'Carte Blanche (AIR254) - KhoMha Remix',
#   '2019-04-09',
#   'trance',
#   'track'),
#  (102, 'Various Artists', 'Hysteresis', '2019-11-01', 'trance', 'track'),
#  (103,
#   'Blank & Jones',
#   'Change My Mind - Pete Herbert Dub',
#   '2019-01-04',
#   'trance',
#   'track'),
#  (104,
#   "Ferry Corsten's Countdown",
#   'Through The Stars (CC617)',
#   '2019-04-26',
#   'trance',
#   'track'),
#  (105, 'Various Artists', 'Forever', '2019-03-21', 'trance', 'track'),
#  (106,
#   'Various Artists',
#   'Landside - Dezza Remix',
#   '2019-07-26',
#   'trance',
#   'track'),
#  (107,
#   'Various Artists',
#   'Set You Free - Radio Mix',
#   '2019-04-26',
#   'trance',
#   'track'),
#  (108,
#   'Various Artists',
#   'Techmology - Deejavoo Remix',
#   '2019-10-18',
#   'trance',
#   'track'),
#  (109,
#   'Various Artists',
#   'Turn Back The Time - Extended Mix',
#   '2019-04-22',
#   'trance',
#   'track'),
#  (110, 'Various Artists', 'Miracle', '2019-06-14', 'trance', 'track'),
#  (111, 'Various Artists', 'Save Your Life', '2019-08-07', 'trance', 'track'),
#  (112,
#   'Various Artists',
#   'The Space We Are 2020',
#   '2019-07-19',
#   'trance',
#   'track'),
#  (113,
#   'Andrew Rayel',
#   'Eight To Sixteen (FYH157)',
#   '2019-05-29',
#   'trance',
#   'track'),
#  (114,
#   'Various Artists',
#   'U Found Me - Mix Cut',
#   '2019-03-08',
#   'trance',
#   'track'),
#  (115,
#   '21street',
#   'Eclipse - Alessandro Remix',
#   '2019-01-25',
#   'trance',
#   'track'),
#  (116,
#   'Anjunabeats',
#   'Group Therapy (Messages Pt. 4) [ABGT359]',
#   '2019-12-15',
#   'trance',
#   'track'),
#  (117, 'Andrew Rayel', 'Find You (FYH178)', '2019-10-30', 'trance', 'track'),
#  (118,
#   "Ferry Corsten's Countdown",
#   "Corsten's Countdown 638 Intro",
#   '2019-09-20',
#   'trance',
#   'track'),
#  (119, 'Various Artists', 'Alcoholic', '2019-11-18', 'trance', 'track'),
#  (120,
#   'Aldo Henrycho',
#   'Sunflowers - Sound State Remix',
#   '2019-12-06',
#   'trance',
#   'track'),
#  (121,
#   'Miroslav Vrlik',
#   'Open Your Heart - Sound Quelle Remix',
#   '2019-09-30',
#   'trance',
#   'track'),
#  (122,
#   'Various Artists',
#   'Deep into Sun - Short Mix',
#   '2019-04-12',
#   'trance',
#   'track'),
#  (123, 'Various Artists', 'Namor Hero', '2019-08-31', 'trance', 'track'),
#  (124, 'Chris Giuliano', 'Cali Quake', '2019-10-11', 'trance', 'track'),
#  (125, 'Cold Stone', 'Touch Heavens', '2019-07-12', 'trance', 'track'),
#  (126,
#   'Roman Messer Suanda Radio',
#   'Pure Heart (Suanda 184) - Syntouch Remix',
#   '2019-07-24',
#   'trance',
#   'track'),
#  (127, 'Neogenia', 'Soul Collector', '2019-01-19', 'trance', 'track'),
#  (128,
#   'Carl Daylim',
#   'Torres - Extended Mix',
#   '2019-02-08',
#   'trance',
#   'track'),
#  (129,
#   "Ferry Corsten's Countdown",
#   "Corsten's Countdown 645 Intro",
#   '2019-11-08',
#   'trance',
#   'track'),
#  (130,
#   "Ferry Corsten's Countdown",
#   'Big Sky (CC631) - Agnelli & Nelson Remix',
#   '2019-08-05',
#   'trance',
#   'track'),
#  (131,
#   'Alberto Blanco',
#   'Stratosphere - rAin Remix',
#   '2019-11-04',
#   'trance',
#   'track'),
#  (132,
#   'Various Artists',
#   'The Ambush (Extended Mix)',
#   '2019-12-31',
#   'trance',
#   'track'),
#  (133, 'Various Artists', 'Universal', '2019-05-31', 'trance', 'track'),
#  (134, 'Kenan Savrun', 'Rigel', '2019-02-18', 'trance', 'track'),
#  (135, 'Martin Libsen', 'Angel of hope', '2019-05-03', 'trance', 'track'),
#  (136,
#   'Various Artists',
#   'No Time - Radio Edit',
#   '2019-04-26',
#   'trance',
#   'track'),
#  (137, 'Various Artists', 'Triquetra', '2019-10-04', 'trance', 'track'),
#  (138,
#   'Andrew Rayel',
#   'Try For Me (FYH167) - Somna Remix',
#   '2019-08-07',
#   'trance',
#   'track'),
#  (139,
#   'Armin van Buuren ASOT Radio',
#   'A State Of Trance (ASOT 945) - Number 2 - Tune Of The Year, Pt. 1',
#   '2019-12-19',
#   'trance',
#   'track'),
#  (140, 'Various Artists', 'Tape Mode', '2019-10-18', 'trance', 'track'),
#  (141,
#   'Cameron Mo',
#   'Unknown Quantity - Extended Mix',
#   '2019-06-07',
#   'trance',
#   'track'),
#  (142,
#   'Various Artists',
#   'Bora Bora 2.0 - Valiant Kings & Sonny Vice Remix',
#   '2019-05-31',
#   'trance',
#   'track'),
#  (143,
#   "Cosmic Gate's Wake Your Mind Radio",
#   'Wake Your Mind Intro (WYM271)',
#   '2019-06-17',
#   'trance',
#   'track'),
#  (144,
#   'TH Brother',
#   'Piratas Do Caribe Nossas Cores Erguei - Original Mix',
#   '2019-01-28',
#   'trance',
#   'track'),
#  (145, 'Alexander Popov', 'You', '2019-10-04', 'trance', 'track'),
#  (146, 'Ronski Speed', 'Arise - Club Mix 2', '2019-08-19', 'trance', 'track'),
#  (147,
#   'Various Artists',
#   'Searching - Daxson Extended Remix',
#   '2019-01-18',
#   'trance',
#   'track'),
#  (148, 'Armin van Buuren', 'Solar', '2019-05-03', 'trance', 'track'),
#  (149,
#   'Various Artists',
#   'Left Of Us (AIR269)',
#   '2019-07-23',
#   'trance',
#   'track'),
#  (150,
#   'Roman Messer Suanda Radio',
#   'The Nightfly (Suanda 181)',
#   '2019-07-03',
#   'trance',
#   'track'),
#  (151,
#   'Markus Schulz - Global DJ Broadcast',
#   'Come Home',
#   '2019-07-12',
#   'trance',
#   'track'),
#  (152,
#   'Andrew Rayel',
#   'Keep On Holding (FYH185) - ilan Bluestone & Maor Levi Remix',
#   '2019-12-18',
#   'trance',
#   'track'),
#  (153,
#   'High Frequencies',
#   'Pentos - Extended Mix',
#   '2019-02-22',
#   'trance',
#   'track'),
#  (154,
#   'Andrew Rayel',
#   'Find Your Harmony (FYH158) - Intro',
#   '2019-06-05',
#   'trance',
#   'track'),
#  (155, 'North Core Project', 'Disco Bitch', '2019-04-30', 'trance', 'track'),
#  (156,
#   'Anden State',
#   'Highlight - Extended Mix',
#   '2019-08-05',
#   'trance',
#   'track'),
#  (157,
#   "Cosmic Gate's Wake Your Mind Radio",
#   'Push (WYM295)',
#   '2019-12-02',
#   'trance',
#   'track'),
#  (158,
#   'Stargazers',
#   'Walk Between Your Shadows - Extended Mix',
#   '2019-11-01',
#   'trance',
#   'track'),
#  (159, 'Milad E', 'Aegean', '2019-04-02', 'trance', 'track'),
#  (160, 'Various Artists', 'You', '2019-06-14', 'trance', 'track'),
#  (161, 'Various Artists', 'Save You', '2019-10-04', 'trance', 'track'),
#  (162,
#   'Various Artists',
#   'Galaxy - Radio Edit',
#   '2019-06-14',
#   'trance',
#   'track'),
#  (163,
#   'Various Artists',
#   'Bora Bora 2.0 - E.M.C.K. Remix',
#   '2019-04-26',
#   'trance',
#   'track'),
#  (164, 'Various Artists', 'Vaya Caramba', '2019-12-03', 'trance', 'track'),
#  (165,
#   'Roman Messer Suanda Radio',
#   'After Life (Suanda 193) [Exclusive]',
#   '2019-09-25',
#   'trance',
#   'track'),
#  (166, 'Various Artists', 'Man In Egypt', '2019-09-20', 'trance', 'track'),
#  (167, 'Armos', 'Sabrosa - Big Room Remix', '2019-01-14', 'trance', 'track'),
#  (168,
#   'Junk Project',
#   'Control ‘99 - Dave Joy & Chris SX Remix',
#   '2019-04-26',
#   'trance',
#   'track'),
#  (169,
#   'Markus Schulz - Global DJ Broadcast',
#   'Parachuting - Club Mix',
#   '2019-01-18',
#   'trance',
#   'track'),
#  (170,
#   'Various Artists',
#   'Fieldglass - Original Mix',
#   '2019-09-01',
#   'trance',
#   'track'),
#  (171, '40Thavha', 'Astronaut', '2019-09-23', 'trance', 'track'),
#  (172,
#   'Various Artists',
#   'Glory - Extended Mix',
#   '2019-12-16',
#   'trance',
#   'track'),
#  (173, 'Mart Sine', "It's Your Life - Dub", '2019-05-24', 'trance', 'track'),
#  (174,
#   'Sam Townend',
#   'Sherbert Supernova - Mix Cut',
#   '2019-09-23',
#   'trance',
#   'track'),
#  (175,
#   'Andrew Rayel',
#   'SHINE Ibiza Anthem 2019 (FYH152)',
#   '2019-04-24',
#   'trance',
#   'track'),
#  (176,
#   'Various Artists',
#   'You and I Forever - Radio Mix',
#   '2019-11-22',
#   'trance',
#   'track'),
#  (177,
#   'Roman Messer Suanda Radio',
#   'Did We Feel (Suanda 207) - Frainbreeze Progressive Dub Mix',
#   '2019-12-31',
#   'trance',
#   'track'),
#  (178, 'Various Artists', 'Wait For Me', '2019-07-05', 'trance', 'track'),
#  (179,
#   'Various Artists',
#   'Paper Boats - Uplifting Mix',
#   '2019-12-23',
#   'trance',
#   'track'),
#  (180,
#   'Various Artists',
#   'Kill The Fear - Extended Mix',
#   '2019-05-17',
#   'trance',
#   'track'),
#  (181, 'Various Artists', 'Verum', '2019-07-01', 'trance', 'track'),
#  (182,
#   'Ryan Raya',
#   "Autumn Emotion - Calvin O'Commor Remix",
#   '2019-06-01',
#   'trance',
#   'track'),
#  (183,
#   'Various Artists',
#   'Zero Gravity - Roman Messer Remix',
#   '2019-03-22',
#   'trance',
#   'track'),
#  (184,
#   'Roman Messer Suanda Radio',
#   'Your Love (Suanda 205)',
#   '2019-12-18',
#   'trance',
#   'track'),
#  (185,
#   'Roman Messer Suanda Radio',
#   'Serenity (Suanda 204)',
#   '2019-12-11',
#   'trance',
#   'track'),
#  (186,
#   'Sneila',
#   'Meanwhile On Another Planet',
#   '2019-10-24',
#   'trance',
#   'track'),
#  (187,
#   'Various Artists',
#   'Forever in Her Eyes - Danny Legatto Radio Cut',
#   '2019-05-24',
#   'trance',
#   'track'),
#  (188, 'Various Artists', 'Tears', '2019-02-22', 'trance', 'track'),
#  (189, 'Various Artists', 'Trigger (AIR256)', '2019-04-23', 'trance', 'track'),
#  (190,
#   'Various Artists',
#   'Declare - Atomic Pulse Remix',
#   '2019-05-07',
#   'trance',
#   'track'),
#  (191, 'Various Artists', 'SychoActive', '2019-09-20', 'trance', 'track'),
#  (192, 'North Core Project', 'Take Control', '2019-04-30', 'trance', 'track'),
#  (193,
#   'Various Artists',
#   'No Time - original mix',
#   '2019-09-09',
#   'trance',
#   'track'),
#  (194,
#   'Various Artists',
#   'Manchester Nights (AIR259)',
#   '2019-05-14',
#   'trance',
#   'track'),
#  (195, 'Armin van Buuren', 'Allies', '2019-05-03', 'trance', 'track'),
#  (196,
#   'Jaytech',
#   'All In - Parallels Extended Mix',
#   '2019-08-06',
#   'trance',
#   'track'),
#  (197, 'Various Artists', 'Impulses', '2019-01-22', 'trance', 'track'),
#  (198,
#   'Paul (AR)',
#   'Breaking Mad - Kieran J Remix',
#   '2019-06-24',
#   'trance',
#   'track'),
#  (199,
#   'Armin van Buuren ASOT Radio',
#   'A State Of Trance (ASOT 944) - Coming Up, Pt. 2',
#   '2019-12-12',
#   'trance',
#   'track'),
#  (200, 'Various Artists', 'Rise', '2019-12-16', 'trance', 'track'),
#  (201, 'Steve Brian', 'Roadtrip - Mixed', '2019-12-20', 'trance', 'track'),
#  (202,
#   'Airwave',
#   'Bellywood - Remastered Original Mix',
#   '2019-10-28',
#   'trance',
#   'track'),
#  (203,
#   'Accuface',
#   'Jet Lag - Remastered Radio Edit',
#   '2019-12-16',
#   'trance',
#   'track'),
#  (204,
#   'Coldharbour presents The Harbour',
#   'The New Breed (Airwalk Festival 2019 Anthem) (The Harbour 2)',
#   '2019-11-15',
#   'trance',
#   'track'),
#  (205, 'Neogenia', 'Soul Collector', '2019-01-19', 'trance', 'track'),
#  (206,
#   'Various Artists',
#   "Nighttime Sky (Ben'Yala Remix)",
#   '2019-03-29',
#   'trance',
#   'track'),
#  (207,
#   'Various Artists',
#   'One Last Time - Daniel Kandi Dark Mix',
#   '2019-08-14',
#   'trance',
#   'track'),
#  (208, 'Andrew Rayel', 'Shifter (FYH173)', '2019-09-18', 'trance', 'track'),
#  (209,
#   'Various Artists',
#   'Polar Nights - Alexey Ryasnyansky Remix',
#   '2019-04-19',
#   'trance',
#   'track'),
#  (210, 'Various Artists', 'Honey', '2019-07-19', 'trance', 'track'),
#  (211,
#   'Various Artists',
#   'Carnival - Global Warming Radio Mix',
#   '2019-07-05',
#   'trance',
#   'track'),
#  (212, 'Solarstone', 'Shield Pt. I', '2019-02-01', 'trance', 'track'),
#  (213,
#   'Various Artists',
#   'Lost Connection - Original',
#   '2019-12-20',
#   'trance',
#   'track'),
#  (214, 'Peter Santos', 'Planet 9', '2019-05-27', 'trance', 'track'),
#  (215,
#   'Roman Messer Suanda Radio',
#   'Infinity (Suanda 189) [Suanda Gold Classic]',
#   '2019-08-28',
#   'trance',
#   'track'),
#  (216,
#   'Tastexperience',
#   "Don't Wanna Hide Anymore - Extended",
#   '2019-05-31',
#   'trance',
#   'track'),
#  (217, 'Various Artists', 'True Love', '2019-06-13', 'trance', 'track'),
#  (218,
#   'Roman Messer Suanda Radio',
#   'Arkane (Suanda 178) [Suanda Gold Classic] - Mark W Remix',
#   '2019-06-12',
#   'trance',
#   'track'),
#  (219, 'Various Artists', 'Flux State', '2019-01-28', 'trance', 'track'),
#  (220,
#   "Ferry Corsten's Countdown",
#   'Blue Deck',
#   '2019-02-08',
#   'trance',
#   'track'),
#  (221,
#   'Greenage',
#   "Shelby - Rick Pier O'Neil Remix",
#   '2019-04-19',
#   'trance',
#   'track'),
#  (222,
#   'Van Yorge',
#   'Acabanera - Cosmaks Remix',
#   '2019-12-07',
#   'trance',
#   'track'),
#  (223,
#   'Tech D',
#   'Unbalanced - Christian Monique Remix',
#   '2019-06-24',
#   'trance',
#   'track'),
#  (224,
#   '40Thavha',
#   'I Can See the Future with You',
#   '2019-03-15',
#   'trance',
#   'track'),
#  (225,
#   'Various Artists',
#   'Something More - Extended Mix',
#   '2019-11-22',
#   'trance',
#   'track'),
#  (226,
#   'Airwave',
#   'Forgotten Memories - Remastered Original Mix',
#   '2019-10-28',
#   'trance',
#   'track'),
#  (227,
#   'Various Artists',
#   'Classic Vee - Kabalistic Mix',
#   '2019-11-08',
#   'trance',
#   'track'),
#  (228,
#   'Pedro Capelossi',
#   'Another Creepy Story',
#   '2019-01-14',
#   'trance',
#   'track'),
#  (229, 'Various Artists', 'Eleven', '2019-04-19', 'trance', 'track'),
#  (230,
#   'Various Artists',
#   'A Day in Africa - Marius Drescher Remix',
#   '2019-11-22',
#   'trance',
#   'track'),
#  (231, 'Various Artists', 'In The Rain', '2019-12-20', 'trance', 'track'),
#  (232, 'Gux Jimenez', 'Element 911', '2019-10-21', 'trance', 'track'),
#  (233,
#   'Armos',
#   'The Whispers - Extended Mix',
#   '2019-05-31',
#   'trance',
#   'track'),
#  (234, 'Quarrel', 'Harmed Siren', '2019-05-27', 'trance', 'track'),
#  (235,
#   'Armin van Buuren ASOT Radio',
#   'A State Of Trance (ASOT 941) - Track Recap, Pt. 1',
#   '2019-11-21',
#   'trance',
#   'track'),
#  (236,
#   'Various Artists',
#   'Black Fantasy - Original Mix',
#   '2019-08-02',
#   'trance',
#   'track'),
#  (237,
#   'Various Artists',
#   'Blue Dream - Goraieb Remix',
#   '2019-06-10',
#   'trance',
#   'track'),
#  (238, 'Neutron', 'Omnia', '2019-01-14', 'trance', 'track'),
#  (239,
#   'Various Artists',
#   'Back to Home - Original Mix',
#   '2019-04-10',
#   'trance',
#   'track'),
#  (240, 'Various Artists', 'Perfect Rave', '2019-08-28', 'trance', 'track'),
#  (241,
#   'Andrew Rayel',
#   'SHINE Ibiza Anthem 2019 (FYH152)',
#   '2019-04-24',
#   'trance',
#   'track'),
#  (242,
#   'Various Artists',
#   'Granted - Radio Cut',
#   '2019-05-10',
#   'trance',
#   'track'),
#  (243,
#   'Various Artists',
#   'Ivory - Volkan Erman Remix',
#   '2019-06-10',
#   'trance',
#   'track'),
#  (244,
#   'Venetica',
#   'Point Pleasant - Platinum Edit',
#   '2019-02-25',
#   'trance',
#   'track'),
#  (245, 'Various Artists', 'Piano Jackers', '2019-05-24', 'trance', 'track'),
#  (246,
#   'Coldharbour presents The Harbour',
#   'Culture Shock (The Harbour 3)',
#   '2019-12-20',
#   'trance',
#   'track'),
#  (247,
#   'Various Artists',
#   'Landside - Dezza Remix',
#   '2019-07-26',
#   'trance',
#   'track'),
#  (248,
#   'Various Artists',
#   'Between The Truth & The Lie - Beatsole Remix',
#   '2019-11-08',
#   'trance',
#   'track'),
#  (249, 'Various Artists', 'Malta', '2019-10-04', 'trance', 'track'),
#  (250,
#   'Various Artists',
#   'Are Am Eye? - Yves De Ruyter Single Mix',
#   '2020-12-18',
#   'trance',
#   'track'),
#  (251, 'Various Artists', 'Acid', '2020-11-27', 'trance', 'track'),
#  (252, 'Various Artists', 'Like a Diamond', '2020-09-02', 'trance', 'track'),
#  (253,
#   'Various Artists',
#   'Obsession - Frank Biazzi Remix',
#   '2020-09-02',
#   'trance',
#   'track'),
#  (254, 'Various Artists', 'Horizon', '2020-06-05', 'trance', 'track'),
#  (255, 'Nifra', 'The Fall (Rebel Radio 059)', '2020-07-01', 'trance', 'track'),
#  (256,
#   'Brooklyn Bounce',
#   'The Theme (Of Progressive Attack) - Sergio Marin & Luke Remix',
#   '2020-05-15',
#   'trance',
#   'track'),
#  (257,
#   'Ori Uplift Radio',
#   'Home [UpOnly 393] - Aimoon Remix - Mix Cut',
#   '2020-08-27',
#   'trance',
#   'track'),
#  (258,
#   'Various Artists',
#   'Reverie - Elypsis Extended Mix',
#   '2020-06-05',
#   'trance',
#   'track'),
#  (259, 'Madloch', 'Embers - GMJ Remix', '2020-12-14', 'trance', 'track'),
#  (260,
#   'Armin van Buuren ASOT Radio',
#   'A State Of Trance (ASOT 950 - Part 2) - Outro',
#   '2020-01-30',
#   'trance',
#   'track'),
#  (261,
#   'Invisible Reality',
#   'Criminal Code - Original Mix',
#   '2020-01-24',
#   'trance',
#   'track'),
#  (262,
#   'Various Artists',
#   'The Light Goes On',
#   '2020-10-19',
#   'trance',
#   'track'),
#  (263, 'Various Artists', 'Spiritual Lesson', '2020-11-23', 'trance', 'track'),
#  (264, 'Ricardo Piedra', 'Blackberry', '2020-11-16', 'trance', 'track'),
#  (265,
#   "Cosmic Gate's Wake Your Mind Radio",
#   'Finestrat (WYM337) - Avenia Remix',
#   '2020-09-21',
#   'trance',
#   'track'),
#  (266,
#   'Andrew Rayel',
#   'Somewhere Inside (FYH207) - Bogdan Vix & Claudiu Adam Remix',
#   '2020-05-27',
#   'trance',
#   'track'),
#  (267, 'Dustin Husain', 'Watch My Hadouken', '2020-12-04', 'trance', 'track'),
#  (268,
#   "Cosmic Gate's Wake Your Mind Radio",
#   'Exploration Of Space (WYM335) - Grum Remix',
#   '2020-09-07',
#   'trance',
#   'track'),
#  (269, 'Various Artists', 'Katharsis', '2020-11-06', 'trance', 'track'),
#  (270,
#   'Various Artists',
#   'Feel The Beat - Part 2',
#   '2020-07-02',
#   'trance',
#   'track'),
#  (271,
#   'Various Artists',
#   'Astral Haven - Paul Arcane Remix',
#   '2020-07-03',
#   'trance',
#   'track'),
#  (272, 'Various Artists', 'Cerulean', '2020-04-10', 'trance', 'track'),
#  (273, 'Gux Jimenez', 'Aquatix', '2020-11-02', 'trance', 'track'),
#  (274,
#   'Various Artists',
#   'Home - Aimoon Remix',
#   '2020-08-28',
#   'trance',
#   'track'),
#  (275,
#   'Spencer Brown',
#   'Donna - Original Mix',
#   '2020-04-24',
#   'trance',
#   'track'),
#  (276, 'Various Artists', 'How I Miss You', '2020-07-17', 'trance', 'track'),
#  (277, 'Various Artists', "Can't Stay Here", '2020-04-10', 'trance', 'track'),
#  (278,
#   'Andrew Rayel',
#   'In And Out Of Love (FYH217) - ilan Bluestone & Maor Levi Remix',
#   '2020-08-05',
#   'trance',
#   'track'),
#  (279,
#   'Aly & Fila',
#   'Road To Vilna (FSOE 676)',
#   '2020-11-18',
#   'trance',
#   'track'),
#  (280,
#   'Tiff Lacey',
#   'Tomorrow Never Comes - Trance Remix',
#   '2020-08-18',
#   'trance',
#   'track'),
#  (281,
#   'Various Artists',
#   'Someone To Love You - DubVision Remix',
#   '2020-07-31',
#   'trance',
#   'track'),
#  (282, 'Volcano', 'Riding the Wave', '2020-04-24', 'trance', 'track'),
#  (283,
#   'Tritonal Tritonia Radio',
#   'Electric Kids (Tritonia 313) - Taylor Torrence Remix',
#   '2020-09-02',
#   'trance',
#   'track'),
#  (284,
#   'Xiasou',
#   'Instant Specs - Anton Borin Remix',
#   '2020-12-07',
#   'trance',
#   'track'),
#  (285,
#   'Various Artists',
#   'Starting A Fire - Extended Mix',
#   '2020-12-18',
#   'trance',
#   'track'),
#  (286,
#   'Anjunabeats',
#   'Group Therapy (Messages Pt. 5) [ABGT365]',
#   '2020-01-31',
#   'trance',
#   'track'),
#  (287,
#   'Kay-D',
#   'Karmagenda - Floating Machine Remix',
#   '2020-12-07',
#   'trance',
#   'track'),
#  (288, 'Various Artists', 'Juno', '2020-01-06', 'trance', 'track'),
#  (289,
#   'Tom Wax',
#   'Make Them Dance - Club Mix',
#   '2020-09-18',
#   'trance',
#   'track'),
#  (290, 'Ander One', 'My Response', '2020-11-09', 'trance', 'track'),
#  (291,
#   'Various Artists',
#   'Earthlight - Original',
#   '2020-03-30',
#   'trance',
#   'track'),
#  (292,
#   'Various Artists',
#   'X-Files Theme Remix - Short Happy',
#   '2020-10-23',
#   'trance',
#   'track'),
#  (293, 'Phanatic', 'Guarana - 2010 Edit', '2020-06-05', 'trance', 'track'),
#  (294,
#   'Rockka',
#   'Visual Aids - Adlows Remix',
#   '2020-04-05',
#   'trance',
#   'track'),
#  (295,
#   'Markus Schulz - Global DJ Broadcast',
#   'Powerball',
#   '2020-02-14',
#   'trance',
#   'track'),
#  (296,
#   'Ben DJ',
#   'Good Life (feat. Romy Dya) - Kuazo Remix',
#   '2020-06-26',
#   'trance',
#   'track'),
#  (297,
#   'Various Artists',
#   'Second Reset - Radio Edit',
#   '2020-02-07',
#   'trance',
#   'track'),
#  (298,
#   'Various Artists',
#   'Aestimare - Daniel Glover Rmx',
#   '2020-03-22',
#   'trance',
#   'track'),
#  (299, 'Various Artists', 'Who Am I', '2020-12-25', 'trance', 'track'),
#  (300, 'Various Artists', 'Time Machine', '2020-12-11', 'trance', 'track'),
#  (301, 'Kevin Vega', 'Alpha Male', '2020-12-04', 'trance', 'track'),
#  (302,
#   'Ciro Visone',
#   'Italia Nel Cuore - Extended Mix',
#   '2020-05-08',
#   'trance',
#   'track'),
#  (303, 'Various Artists', 'Acting Space', '2020-04-06', 'trance', 'track'),
#  (304,
#   'Armin van Buuren ASOT Radio',
#   'A State Of Trance (ASOT 953) - Track Recap, Pt. 4',
#   '2020-02-27',
#   'trance',
#   'track'),
#  (305,
#   'Roman Messer Suanda Radio',
#   'Serenity (Suanda 211) - Eximinds Remix',
#   '2020-01-29',
#   'trance',
#   'track'),
#  (306, 'Inkfish', 'Struggle', '2020-09-14', 'trance', 'track'),
#  (307, 'Andrew Rayel', 'Ariel (FYH225)', '2020-09-30', 'trance', 'track'),
#  (308,
#   'Andrew Rayel',
#   'Away With You (FYH192)',
#   '2020-02-12',
#   'trance',
#   'track'),
#  (309, 'Various Artists', 'North', '2020-07-10', 'trance', 'track'),
#  (310,
#   'Various Artists',
#   'Brainchild - Original',
#   '2020-10-09',
#   'trance',
#   'track'),
#  (311,
#   'Various Artists',
#   'Purple Urkle - Extended Mix',
#   '2020-01-31',
#   'trance',
#   'track'),
#  (312,
#   'Simos Tagias',
#   'The Rise - EANP Remix',
#   '2020-10-05',
#   'trance',
#   'track'),
#  (313,
#   'Sue McLaren',
#   'Never Ever After - Radio Edit',
#   '2020-08-14',
#   'trance',
#   'track'),
#  (314, 'Various Artists', 'Green Light', '2020-03-04', 'trance', 'track'),
#  (315,
#   'Muvy',
#   "Can't Stay Here - Extended Mix",
#   '2020-01-31',
#   'trance',
#   'track'),
#  (316,
#   'Taylor Torrence',
#   'Maelstrom - Mixed',
#   '2020-12-04',
#   'trance',
#   'track'),
#  (317,
#   'Various Artists',
#   'Emotions - Caballero Remix',
#   '2020-11-17',
#   'trance',
#   'track'),
#  (318,
#   'Ori Uplift',
#   'Vanaheim [UpOnly 400] - Mix Cut',
#   '2020-10-11',
#   'trance',
#   'track'),
#  (319, 'Various Artists', 'Nella Notte', '2020-04-30', 'trance', 'track'),
#  (320, 'Various Artists', 'Karayana', '2020-01-06', 'trance', 'track'),
#  (321,
#   'Nima van Ghavim',
#   'Serotonin - Extended Mix',
#   '2020-09-14',
#   'trance',
#   'track'),
#  (322,
#   'Various Artists',
#   'For You To Wake Up',
#   '2020-05-08',
#   'trance',
#   'track'),
#  (323,
#   'Andrew Rayel',
#   'Rising Tide (FYH221)',
#   '2020-09-02',
#   'trance',
#   'track'),
#  (324,
#   'Andrew Rayel',
#   'Rosy (FYH210) [Light Side Track Of The Week]',
#   '2020-06-17',
#   'trance',
#   'track'),
#  (325,
#   'Various Artists',
#   'Evolution - Commander Club Dub',
#   '2020-12-18',
#   'trance',
#   'track'),
#  (326,
#   'Electronics Fusion',
#   'Touched by the Purple - Electronics Fusion Hands On Remix',
#   '2020-06-17',
#   'trance',
#   'track'),
#  (327,
#   'Alberto Blanco',
#   'Eternal Sunshine - Rodrigo Baroni Remix',
#   '2020-03-02',
#   'trance',
#   'track'),
#  (328,
#   'Averagaint',
#   'Singularity - Radio Mix',
#   '2020-01-24',
#   'trance',
#   'track'),
#  (329,
#   'Roman Messer Suanda Radio',
#   'Escape (Suanda 255)',
#   '2020-12-16',
#   'trance',
#   'track'),
#  (330,
#   'Butterfly Music Highlights',
#   'Refuge - Extended Mix',
#   '2020-12-20',
#   'trance',
#   'track'),
#  (331,
#   'Above & Beyond Group Therapy',
#   'Group Therapy (Messages Pt. 9) [ABGT378]',
#   '2020-04-26',
#   'trance',
#   'track'),
#  (332, 'Steve Allen', 'Trinket (RNMS35)', '2020-03-13', 'trance', 'track'),
#  (333,
#   'Roman Messer Suanda Radio',
#   'Sweet Desire (Suanda 209)',
#   '2020-01-15',
#   'trance',
#   'track'),
#  (334,
#   'Alien Factory',
#   'Freak Tonight - 2020 Radio Mix',
#   '2020-08-21',
#   'trance',
#   'track'),
#  (335,
#   'Various Artists',
#   'Space Care - Original',
#   '2020-03-30',
#   'trance',
#   'track'),
#  (336,
#   'Various Artists',
#   'A Day In Africa - Extended Mix',
#   '2020-11-16',
#   'trance',
#   'track'),
#  (337,
#   'Armin van Buuren ASOT Radio',
#   'A State Of Trance (ASOT 990) - Interview with Marco V, Pt. 1',
#   '2020-11-12',
#   'trance',
#   'track'),
#  (338,
#   'Above & Beyond Group Therapy',
#   'Group Therapy (Messages Pt. 6) [ABGT382]',
#   '2020-05-24',
#   'trance',
#   'track'),
#  (339, 'Various Artists', 'Closer', '2020-04-24', 'trance', 'track'),
#  (340, 'Woody van Eyden', 'Remember - Mixed', '2020-08-11', 'trance', 'track'),
#  (341,
#   'Maykel Piron',
#   'Punk (ARNXT014) - Tom Staar Remix',
#   '2020-06-15',
#   'trance',
#   'track'),
#  (342,
#   'Various Artists',
#   'Lullaby - NoMosk Chillout Remix',
#   '2020-12-11',
#   'trance',
#   'track'),
#  (343,
#   'Ori Uplift',
#   'Beyond Time [UpOnly 382] - Asteroid Mix - Mix Cut',
#   '2020-06-09',
#   'trance',
#   'track'),
#  (344,
#   'Tritonal Tritonia Radio',
#   'Excalibur (Tritonia 315)',
#   '2020-09-16',
#   'trance',
#   'track'),
#  (345,
#   'Elite Electronic',
#   'LED City - Extended Mix',
#   '2020-02-24',
#   'trance',
#   'track'),
#  (346, 'Various Artists', 'Bipolar', '2020-03-03', 'trance', 'track'),
#  (347,
#   'Emmanuel Top',
#   'Arab Affair - Etienne Marcel Discussions Remix',
#   '2020-11-15',
#   'trance',
#   'track'),
#  (348, 'Various Artists', 'Angelic Stairway', '2020-12-07', 'trance', 'track'),
#  (349,
#   'Various Artists',
#   'Beautiful Nothing',
#   '2020-10-30',
#   'trance',
#   'track'),
#  (350, 'Various Artists', 'Human Energy', '2020-11-26', 'trance', 'track'),
#  (351,
#   'Aly & Fila',
#   'Ocean Breeze (FSOE 647)',
#   '2020-04-30',
#   'trance',
#   'track'),
#  (352,
#   'Various Artists',
#   'Eclipse - Short Mix',
#   '2020-06-26',
#   'trance',
#   'track'),
#  (353,
#   'Ewan Rill',
#   'Sun Is Missing - Original Mix',
#   '2020-01-20',
#   'trance',
#   'track'),
#  (354,
#   'Various Artists',
#   'Feel Alive - Extended Mix',
#   '2020-11-20',
#   'trance',
#   'track'),
#  (355, 'Various Artists', "Let's Burn This", '2020-09-25', 'trance', 'track'),
#  (356,
#   'Various Artists',
#   'Chasing The Sun - Schodt Remix',
#   '2020-07-21',
#   'trance',
#   'track'),
#  (357,
#   'Andrew Rayel',
#   'All For Love (FYH208) [Favorite Of The Moment]',
#   '2020-06-03',
#   'trance',
#   'track'),
#  (358,
#   'Various Artists',
#   'Contamination - Ciro Parcheri Remix',
#   '2020-07-10',
#   'trance',
#   'track'),
#  (359,
#   'Tritonal Tritonia Radio',
#   'Tritonia (Tritonia 326) - Coming Up, Pt. 2',
#   '2020-12-10',
#   'trance',
#   'track'),
#  (360, 'Various Artists', 'The Magic', '2020-12-11', 'trance', 'track'),
#  (361, 'Various Artists', 'Reverie', '2020-07-17', 'trance', 'track'),
#  (362,
#   'DoctorSpook',
#   'Nirvana - Progressive Goa Mix Edit',
#   '2020-11-24',
#   'trance',
#   'track'),
#  (363,
#   'Various Artists',
#   'Advance - Greenage Remix',
#   '2020-12-14',
#   'trance',
#   'track'),
#  (364, 'Various Artists', 'Sunday Sunrise', '2020-10-09', 'trance', 'track'),
#  (365,
#   'Various Artists',
#   'Never Let Me Down',
#   '2020-05-15',
#   'trance',
#   'track'),
#  (366,
#   'Aly & Fila',
#   'The Sun Will Rise Again (FSOE 642) - Paul Denton Remix',
#   '2020-03-26',
#   'trance',
#   'track'),
#  (367,
#   'Various Artists',
#   'M [Metropolis] - Extended Mix',
#   '2020-12-18',
#   'trance',
#   'track'),
#  (368, 'Arthur Volt', 'Find Me', '2020-04-06', 'trance', 'track'),
#  (369,
#   'Various Artists',
#   'Home & You - Radio Edit',
#   '2020-09-18',
#   'trance',
#   'track'),
#  (370,
#   'Gerard Bozyk',
#   'Journey to Avalon - Mixed',
#   '2020-01-21',
#   'trance',
#   'track'),
#  (371,
#   'Various Artists',
#   'A Day in Africa - Marius Drescher Remix',
#   '2020-01-10',
#   'trance',
#   'track'),
#  (372, 'Various Artists', 'Just for You', '2020-11-06', 'trance', 'track'),
#  (373,
#   'Steve Allen',
#   'Silhouette (RNMS35) - Steve Allen 2019 Respray',
#   '2020-03-13',
#   'trance',
#   'track'),
#  (374, 'R.A.Z', 'Beyond Imagination', '2020-07-24', 'trance', 'track'),
#  (375,
#   'Various Artists',
#   "Shelby - Rick Pier O'Neil Remix",
#   '2020-05-22',
#   'trance',
#   'track'),
#  (376, 'Elite Electronic', 'Hyperspeed', '2020-03-13', 'trance', 'track'),
#  (377,
#   'Various Artists',
#   'Night After Night',
#   '2020-06-15',
#   'trance',
#   'track'),
#  (378,
#   'Jelly For The Babies',
#   'Talas - Mario Neha Remix',
#   '2020-07-27',
#   'trance',
#   'track'),
#  (379,
#   'Andrew Rayel',
#   'Always (FYH198) - Assaf Remix',
#   '2020-03-25',
#   'trance',
#   'track'),
#  (380,
#   'Clay van Dijk',
#   'Static - Nishan Lee Remix - Mixed',
#   '2020-11-12',
#   'trance',
#   'track'),
#  (381, 'Aly & Fila', 'Impact (FSOE 644)', '2020-04-09', 'trance', 'track'),
#  (382,
#   'Aly & Fila',
#   'Million Voices - Extended Mix',
#   '2020-10-16',
#   'trance',
#   'track'),
#  (383, 'Aly & Fila', 'Automatik (FSOE 639)', '2020-03-05', 'trance', 'track'),
#  (384, 'Hanski', 'Synesthesia', '2020-07-27', 'trance', 'track'),
#  (385,
#   'TEIAO',
#   'Tolaria West - Diego Berrondo & Alex Efe Remix - Mixed',
#   '2020-01-06',
#   'trance',
#   'track'),
#  (386,
#   'Aevus',
#   'Teegarden (B) - FLRK! Remix',
#   '2020-08-07',
#   'trance',
#   'track'),
#  (387,
#   'Various Artists',
#   'Passenger - Paul Thomas & White-Akre Club Mix',
#   '2020-05-15',
#   'trance',
#   'track'),
#  (388, 'Dj Bim', 'Loopy - Original Mix', '2020-10-16', 'trance', 'track'),
#  (389, 'Sygma', 'Kaibigan', '2020-05-29', 'trance', 'track'),
#  (390,
#   'Various Artists',
#   'Fever 2019 - Extended Mix',
#   '2020-04-16',
#   'trance',
#   'track'),
#  (391,
#   'Various Artists',
#   'Much Better - Oscar Cano Remix',
#   '2020-07-06',
#   'trance',
#   'track'),
#  (392, 'Various Artists', 'Voyager', '2020-02-10', 'trance', 'track'),
#  (393,
#   'Various Artists',
#   'Never Fade Away - Extended Mix',
#   '2020-11-27',
#   'trance',
#   'track'),
#  (394,
#   'Various Artists',
#   'The World Belongs To Us',
#   '2020-02-10',
#   'trance',
#   'track'),
#  (395,
#   'Various Artists',
#   'Stole - Extended Mix',
#   '2020-07-20',
#   'trance',
#   'track'),
#  (396,
#   'Butterfly Music Highlights',
#   'Ray Of Hope - Extended Mix',
#   '2020-12-20',
#   'trance',
#   'track'),
#  (397,
#   'Various Artists',
#   'Supernova Explosion',
#   '2020-12-24',
#   'trance',
#   'track'),
#  (398,
#   'Supernatural',
#   'Rumble - Original Mix',
#   '2020-10-30',
#   'trance',
#   'track'),
#  (399,
#   'Various Artists',
#   'Love On the Run - Chicane Long Mix',
#   '2020-09-04',
#   'trance',
#   'track'),
#  (400, 'Aly & Fila', 'Outro (FSOE 677)', '2020-11-25', 'trance', 'track'),
#  (401,
#   'Various Artists',
#   'Say That You Love Me',
#   '2020-06-15',
#   'trance',
#   'track'),
#  (402,
#   'Various Artists',
#   'Light It Up - Jens O. Remix',
#   '2020-02-14',
#   'trance',
#   'track'),
#  (403,
#   'Various Artists',
#   'Species Amongst Us',
#   '2020-11-30',
#   'trance',
#   'track'),
#  (404,
#   'Various Artists',
#   'River of Light - Radio Edit',
#   '2020-03-20',
#   'trance',
#   'track'),
#  (405,
#   'Mallorca Lee',
#   'Have We Met Before - Extended Mix',
#   '2020-12-15',
#   'trance',
#   'track'),
#  (406,
#   'Francesco Pico',
#   'Inverse Osmosis - Mixed',
#   '2020-07-13',
#   'trance',
#   'track'),
#  (407,
#   'Ori Uplift',
#   'Kingdom **Exclusive Premiere** [UpOnly 390] - Sunyella & Anton van Sprundel Dub Mix - Mix Cut',
#   '2020-08-05',
#   'trance',
#   'track'),
#  (408, 'Various Artists', 'Vibrante', '2020-03-05', 'trance', 'track'),
#  (409, 'Various Artists', 'Annihilation', '2020-12-30', 'trance', 'track'),
#  (410,
#   'Various Artists',
#   'Different Ways - Sasha Van Laur Remix',
#   '2020-11-11',
#   'trance',
#   'track'),
#  (411,
#   'Andrew Rayel',
#   'Lasers (FYH207) [Light Side Track Of The Week]',
#   '2020-05-27',
#   'trance',
#   'track'),
#  (412, 'HamzeH', 'Back In The Days', '2020-01-06', 'trance', 'track'),
#  (413, 'Andrew Rayel', 'Kingdom (FYH221)', '2020-09-02', 'trance', 'track'),
#  (414, 'Various Artists', 'Vaya Caramba', '2020-02-20', 'trance', 'track'),
#  (415,
#   'Bellatrix',
#   'Young Man on Acid - Terrasun Remix',
#   '2020-12-30',
#   'trance',
#   'track'),
#  (416, 'Tom Wax', 'The Bomb - Club Mix', '2020-09-18', 'trance', 'track'),
#  (417, 'Ryan Raya', 'True Emotion', '2020-06-30', 'trance', 'track'),
#  (418, 'Sub6', 'Unation - Evi Orgatz Remix', '2020-09-02', 'trance', 'track'),
#  (419, 'Andrew Rayel', 'Poseidon (FYH206)', '2020-05-20', 'trance', 'track'),
#  (420, 'Sue McLaren', 'Better Part of Me', '2020-08-14', 'trance', 'track'),
#  (421,
#   'DJ Sakin',
#   'The End is the Beginning - Club Mix',
#   '2020-12-01',
#   'trance',
#   'track'),
#  (422, 'Various Artists', 'Sweet Desire', '2020-04-10', 'trance', 'track'),
#  (423,
#   'Roman Messer Suanda Radio',
#   'ID (Suanda 225)',
#   '2020-05-13',
#   'trance',
#   'track'),
#  (424, 'Various Artists', 'Excommunicado', '2020-10-16', 'trance', 'track'),
#  (425,
#   'Tycoos Future Horizons Radio',
#   "L'Envoi [FHR295] - Mix Cut",
#   '2020-10-10',
#   'trance',
#   'track'),
#  (426,
#   'Roman Messer Suanda Radio',
#   'Oblivion (Suanda 243) [Track Of The Week]',
#   '2020-09-23',
#   'trance',
#   'track'),
#  (427, 'Various Artists', 'Your Choice', '2020-03-22', 'trance', 'track'),
#  (428, 'Various Artists', 'Sarcophyton', '2020-03-27', 'trance', 'track'),
#  (429,
#   'Gux Jimenez',
#   'Feel the Calm - Chill Mix',
#   '2020-07-27',
#   'trance',
#   'track'),
#  (430, 'GXD', 'Secret', '2020-01-24', 'trance', 'track'),
#  (431,
#   'Various Artists',
#   'Battleship - Radio Mix',
#   '2020-11-27',
#   'trance',
#   'track'),
#  (432,
#   'Various Artists',
#   'Eternal - Original Mix',
#   '2020-11-29',
#   'trance',
#   'track'),
#  (433,
#   'Bynomic',
#   'Cleansing Thunderstrom - Matias Carafa Remix',
#   '2020-04-27',
#   'trance',
#   'track'),
#  (434,
#   'Various Artists',
#   'Oranai - Nicholas Van Orton Summer Remix',
#   '2020-06-15',
#   'trance',
#   'track'),
#  (435,
#   'Various Artists',
#   'Anima - Nicolas Leonelli Rmx',
#   '2020-01-26',
#   'trance',
#   'track'),
#  (436, 'James Warren', 'Modulator - Mixed', '2020-06-08', 'trance', 'track'),
#  (437,
#   'Chris Cargo',
#   'Home - Instrumental Mix',
#   '2020-06-15',
#   'trance',
#   'track'),
#  (438,
#   'Various Artists',
#   "I've Been Needing You - AxelPolo Remix",
#   '2020-11-30',
#   'trance',
#   'track'),
#  (439,
#   'Phanatic',
#   'Signs of Revolution - Phanatic Remix',
#   '2020-03-16',
#   'trance',
#   'track'),
#  (440, 'Mariano Favre', 'Orion', '2020-03-09', 'trance', 'track'),
#  (441,
#   'DoctorSpook',
#   'Love Peace Order Truth',
#   '2020-11-26',
#   'trance',
#   'track'),
#  (442, 'MatricK', 'Flaming', '2020-03-25', 'trance', 'track'),
#  (443, 'TH Brother', '303', '2020-01-23', 'trance', 'track'),
#  (444,
#   'Various Artists',
#   'Myonic - Airwave Remix',
#   '2020-07-20',
#   'trance',
#   'track'),
#  (445,
#   'Various Artists',
#   'Strange Reality - Original Mix',
#   '2020-12-18',
#   'trance',
#   'track'),
#  (446,
#   'Armin van Buuren ASOT Radio',
#   'A State Of Trance (ASOT 992) - Track Recap, Pt. 5',
#   '2020-11-26',
#   'trance',
#   'track'),
#  (447, 'Various Artists', 'Coelum 2019', '2020-02-10', 'trance', 'track'),
#  (448,
#   'Armin van Buuren ASOT Radio',
#   'A State Of Trance (ASOT 949) - Shout Outs, Pt. 2',
#   '2020-01-16',
#   'trance',
#   'track'),
#  (449, 'Various Artists', 'Unicorn', '2020-12-28', 'trance', 'track'),
#  (450,
#   'Atomic Pulse',
#   'Solar Flare - Original Mix',
#   '2020-09-15',
#   'trance',
#   'track'),
#  (451,
#   'Above & Beyond Group Therapy',
#   'Group Therapy (Messages Pt. 3) [ABGT389]',
#   '2020-07-12',
#   'trance',
#   'track'),
#  (452, 'DoctorSpook', 'Solar Wind', '2020-11-24', 'trance', 'track'),
#  (453,
#   'Maykel Piron',
#   'Punk (ARNXT014) - Tom Staar Remix',
#   '2020-06-15',
#   'trance',
#   'track'),
#  (454,
#   'Various Artists',
#   'Still Got Time - Jordy Eley Extended Mix',
#   '2020-11-13',
#   'trance',
#   'track'),
#  (455,
#   'Various Artists',
#   'Lullaby - NoMosk Chillout Remix',
#   '2020-12-11',
#   'trance',
#   'track'),
#  (456, 'Sub6', 'Unation - Evi Orgatz Remix', '2020-09-02', 'trance', 'track'),
#  (457,
#   'Mariano Favre',
#   'Distant Planets - Christian Monique Remix',
#   '2020-03-09',
#   'trance',
#   'track'),
#  (458,
#   'Various Artists',
#   'One Way - Original Mix',
#   '2020-06-19',
#   'trance',
#   'track'),
#  (459,
#   'Ori Uplift',
#   'Vanaheim [UpOnly 400] - Mix Cut',
#   '2020-10-11',
#   'trance',
#   'track'),
#  (460,
#   'Markus Schulz Destinations',
#   'Mota-Mota (Destinations 10) - Talla 2XLC Prog Remix',
#   '2020-10-16',
#   'trance',
#   'track'),
#  (461, 'Impulse Wave', 'Basilisk', '2020-01-27', 'trance', 'track'),
#  (462,
#   'Ori Uplift Radio',
#   'Home [UpOnly 393] - Aimoon Remix - Mix Cut',
#   '2020-08-27',
#   'trance',
#   'track'),
#  (463,
#   'Various Artists',
#   'Feel Alive - Extended Mix',
#   '2020-11-20',
#   'trance',
#   'track'),
#  (464,
#   'Ori Uplift',
#   'King of the Night [UpOnly 369] - Mix Cut',
#   '2020-03-12',
#   'trance',
#   'track'),
#  (465,
#   'Various Artists',
#   'Energize 303 - Radio Edit',
#   '2020-05-22',
#   'trance',
#   'track'),
#  (466, 'Sinan Arsan', 'Suspense', '2020-11-09', 'trance', 'track'),
#  (467, 'Various Artists', 'Contact', '2020-12-21', 'trance', 'track'),
#  (468, 'Rockka', 'Eternal - Original Mix', '2020-04-30', 'trance', 'track'),
#  (469, 'Kay-D', 'Karmagenda', '2020-12-07', 'trance', 'track'),
#  (470, 'Marcprest', 'Wabi Sabi - Radio Edit', '2020-12-04', 'trance', 'track'),
#  (471,
#   'Tycoos Future Horizons Radio',
#   "L'Envoi [FHR295] - Mix Cut",
#   '2020-10-10',
#   'trance',
#   'track'),
#  (472, 'Various Artists', 'Humble', '2020-04-18', 'trance', 'track'),
#  (473,
#   'Francesco Pico',
#   'Inverse Osmosis - Mixed',
#   '2020-07-13',
#   'trance',
#   'track'),
#  (474, 'Elite Electronic', 'Hyperspeed', '2020-03-13', 'trance', 'track'),
#  (475, 'Various Artists', 'Diver Down', '2020-05-22', 'trance', 'track'),
#  (476,
#   'Tritonal Tritonia Radio',
#   'It Was Real (Tritonia 326)',
#   '2020-12-10',
#   'trance',
#   'track'),
#  (477,
#   'Ori Uplift',
#   'Undefined Universe [UpOnly 384] - Mix Cut',
#   '2020-06-20',
#   'trance',
#   'track'),
#  (478, 'John Grand', 'See You - DJ Version', '2020-11-06', 'trance', 'track'),
#  (479, "Rick Pier O'Neil", 'Okxo', '2020-12-15', 'trance', 'track'),
#  (480, 'Skynet', 'Stargazing', '2020-03-02', 'trance', 'track'),
#  (481, 'Various Artists', 'Epilogue - Mixed', '2020-12-18', 'trance', 'track'),
#  (482,
#   'Andrew Rayel',
#   'Kick, Bass & Trance (FYH229) - Attila Syah Remix',
#   '2020-10-28',
#   'trance',
#   'track'),
#  (483,
#   'NAHS',
#   'Take One of Us - Rodrigo Lapena Remix - Mixed',
#   '2020-09-28',
#   'trance',
#   'track'),
#  (484, 'Ron with Leeds', 'Neila', '2020-01-03', 'trance', 'track'),
#  (485,
#   'Various Artists',
#   'Break Free - Original Mix',
#   '2020-06-30',
#   'trance',
#   'track'),
#  (486, 'Madloch', 'Black Spur', '2020-12-14', 'trance', 'track'),
#  (487, 'California Sunshine', 'Fly High', '2020-06-12', 'trance', 'track'),
#  (488,
#   'Various Artists',
#   'Talisman - Radio Edit',
#   '2020-10-30',
#   'trance',
#   'track'),
#  (489,
#   'Various Artists',
#   'Tartaros - Extended Mix',
#   '2020-12-28',
#   'trance',
#   'track'),
#  (490,
#   'Various Artists',
#   'Built To Last - Ferry Tayle Remix',
#   '2020-05-29',
#   'trance',
#   'track'),
#  (491, 'Various Artists', 'Benedictus', '2020-02-10', 'trance', 'track'),
#  (492,
#   'Andrew Rayel',
#   'All For Love (FYH219) - Giuseppe Ottaviani Remix',
#   '2020-08-19',
#   'trance',
#   'track'),
#  (493,
#   'Roman Messer Suanda Radio',
#   'Lost & Found (Suanda 247) - Full Fire Mix',
#   '2020-10-21',
#   'trance',
#   'track'),
#  (494,
#   'Andrew Rayel',
#   'Hearts Of Heaven (FYH225) - Escea Remix',
#   '2020-09-30',
#   'trance',
#   'track'),
#  (495,
#   'East',
#   'Mystery - Adrian Alexander Extended Dub Mix',
#   '2020-09-25',
#   'trance',
#   'track'),
#  (496, 'Ahmed Romel', 'Divine - Mix Cut', '2020-10-26', 'trance', 'track'),
#  (497, 'Sunlight Project', 'Mustang', '2020-01-24', 'trance', 'track'),
#  (498, 'Various Artists', 'Move On', '2020-10-30', 'trance', 'track'),
#  (499, 'Andrew Rayel', 'Vortex (FYH196)', '2020-03-11', 'trance', 'track'),
#  (500, 'Various Artists', 'Deranged - Mixed', '2021-02-05', 'trance', 'track'),
#  (501,
#   'Markus Schulz',
#   'While We Wait (Year in Review 2020)',
#   '2021-01-22',
#   'trance',
#   'track'),
#  (502, 'Mark & Lukas', 'Our Home', '2021-03-05', 'trance', 'track'),
#  (503, 'Nick Stoynoff', 'Random Dj Tool', '2021-10-27', 'trance', 'track'),
#  (504,
#   'Alex Leavon',
#   "There's A Tomorrow - Extended Mix",
#   '2021-03-05',
#   'trance',
#   'track'),
#  (505, 'Maykel Piron', 'Apricus (ARNXT049)', '2021-02-15', 'trance', 'track'),
#  (506,
#   'Various Artists',
#   'Shadows (The Sound of Without You) - F.G. Noise Extended Mix',
#   '2021-12-17',
#   'trance',
#   'track'),
#  (507,
#   'DoctorSpook',
#   'Shamanic Dance on Ayahuasca',
#   '2021-04-20',
#   'trance',
#   'track'),
#  (508,
#   'Stage Van H',
#   'Coastal Waves - Mutual Mode Remix',
#   '2021-12-24',
#   'trance',
#   'track'),
#  (509, 'DoctorSpook', 'Sunset', '2021-12-07', 'trance', 'track'),
#  (510,
#   'Various Artists',
# ...
#   '2022-08-20',
#   'trance',
#   'track'),
#  (826, 'Chris Sterio', 'Balanced - Mixed', '2022-03-04', 'trance', 'track'),
#  (827, 'Andrew Rayel', 'Destiny (FYH321)', '2022-08-24', 'trance', 'track'),
#  (828,
#   'Roman Messer Suanda Radio',
#   'The Way Of Magic (Suanda 354)',
#   '2022-11-09',
#   'trance',
#   'track'),
#  (829, 'Various Artists', 'Enlighten Me', '2022-01-21', 'trance', 'track'),
#  (830, 'DJ Ruby', 'Supreme - Mixed', '2022-04-26', 'trance', 'track'),
#  (831,
#   'Various Artists',
#   'Alien Technology - Driving Edit',
#   '2022-09-26',
#   'trance',
#   'track'),
#  (832, 'James Warren', 'Doxtoutheo - Mixed', '2022-04-22', 'trance', 'track'),
#  (833, 'Gorkiz', 'Polaris - Mixed', '2022-05-19', 'trance', 'track'),
#  (834, 'Gangguru', 'Ramawaï - Early Mix', '2022-12-25', 'trance', 'track'),
#  (835,
#   'Various Artists',
#   'Candle Flame - Original Mix',
#   '2022-02-12',
#   'trance',
#   'track'),
#  (836,
#   'Various Artists',
#   'Brave - F.G. Noise Edit',
#   '2022-04-29',
#   'trance',
#   'track'),
#  (837,
#   'DoctorSpook',
#   'Omnipresent Technology',
#   '2022-11-06',
#   'trance',
#   'track'),
#  (838,
#   'Various Artists',
#   'A Hundred Ways - Temple One Remix',
#   '2022-02-11',
#   'trance',
#   'track'),
#  (839,
#   'Proton Radio',
#   'Friends Forever - Ian Dillon Remix - Mixed',
#   '2022-01-24',
#   'trance',
#   'track'),
#  (840,
#   'Various Artists',
#   'Called By A Whisper',
#   '2022-11-04',
#   'trance',
#   'track'),
#  (841,
#   'Various Artists',
#   'Glass Jaw - Nikko Mavridis Rmx',
#   '2022-03-18',
#   'trance',
#   'track'),
#  (842, 'Five', 'Tale - Mixed', '2022-08-07', 'trance', 'track'),
#  (843,
#   'Various Artists',
#   'Hear Me Out - Extended Mix',
#   '2022-10-14',
#   'trance',
#   'track'),
#  (844,
#   'Gangguru',
#   'Japanese Fight - Alternate Mix',
#   '2022-12-25',
#   'trance',
#   'track'),
#  (845,
#   'Various Artists',
#   'Reaction - Paul Hamilton Rmx',
#   '2022-10-06',
#   'trance',
#   'track'),
#  (846, 'Alexey Sonar', 'Tarantella - Mixed', '2022-06-10', 'trance', 'track'),
#  (847,
#   'Nick Stoynoff',
#   'High Supply - Ashhen Dubscape',
#   '2022-07-01',
#   'trance',
#   'track'),
#  (848,
#   'Various Artists',
#   'Ab-Chic - Acrid Abeyance Remix',
#   '2022-08-09',
#   'trance',
#   'track'),
#  (849,
#   'Various Artists',
#   "Back To The Future - Daniel Kandi's Classic Mix",
#   '2022-01-21',
#   'trance',
#   'track'),
#  (850, 'Alexey Sonar', 'Tarantella - Mixed', '2022-06-10', 'trance', 'track'),
#  (851,
#   'Nick Stoynoff',
#   'High Supply - Ashhen Dubscape',
#   '2022-07-01',
#   'trance',
#   'track'),
#  (852,
#   'Various Artists',
#   'Ab-Chic - Acrid Abeyance Remix',
#   '2022-08-09',
#   'trance',
#   'track'),
#  (853,
#   'Various Artists',
#   "Back To The Future - Daniel Kandi's Classic Mix",
#   '2022-01-21',
#   'trance',
#   'track'),
#  (854, 'DoctorSpook', 'Artrance - Mixed', '2022-08-18', 'trance', 'track'),
#  (855, 'Various Artists', 'The Motto', '2022-07-13', 'trance', 'track'),
#  (856,
#   'Johnny M',
#   'In Apricis - Vitaly Shturm Remix - Mixed',
#   '2022-02-05',
#   'trance',
#   'track'),
#  (857,
#   'Alexey Sonar',
#   'Ambiguous Cycle - Mixed',
#   '2022-06-17',
#   'trance',
#   'track'),
#  (858, 'Chromatone', 'Diskofunktional', '2022-09-26', 'trance', 'track'),
#  (859, 'Priya Sen', 'The Box - Mixed', '2022-09-05', 'trance', 'track'),
#  (860,
#   'Various Artists',
#   'Amalthea - Radio Edit',
#   '2022-01-14',
#   'trance',
#   'track'),
#  (861, 'Ewan Rill', 'My Gate', '2022-09-02', 'trance', 'track'),
#  (862,
#   'Cream (PL)',
#   'Astral - Teleport-X Remix',
#   '2022-03-30',
#   'trance',
#   'track'),
#  (863, 'Tom Wax', 'Fear of the Unknown', '2022-09-19', 'trance', 'track'),
#  (864,
#   'Various Artists',
#   'Freefalling (Mixed)',
#   '2022-12-09',
#   'trance',
#   'track'),
#  (865,
#   'Aldo Henrycho',
#   'Hope - Carlo Camargo Remix',
#   '2022-03-25',
#   'trance',
#   'track'),
#  (866, 'Various Artists', 'You Can Run', '2022-11-11', 'trance', 'track'),
#  (867,
#   'Various Artists',
#   'Symphonica II (The Journey Continues) - Extended Mix',
#   '2022-01-21',
#   'trance',
#   'track'),
#  (868, 'Tron', 'Tbh', '2022-07-27', 'trance', 'track'),
#  (869, 'Paul Hamilton', 'Nothing Matters', '2022-07-15', 'trance', 'track'),
#  (870,
#   'Various Artists',
#   'Sevlar - Extended Mix',
#   '2022-12-16',
#   'trance',
#   'track'),
#  (871, 'Goa Doc', 'Mastermind Voices', '2022-05-27', 'trance', 'track'),
#  (872, 'Five', 'Leku - Mixed', '2022-10-12', 'trance', 'track'),
#  (873,
#   'Ornery',
#   'Black Mass - Extended Mix - Mixed',
#   '2022-08-29',
#   'trance',
#   'track'),
#  (874,
#   'Francesco Fruci',
#   'La Cona - Extended Mix',
#   '2022-05-27',
#   'trance',
#   'track'),
#  (875,
#   'Various Artists',
#   'Lighting Fires - Paul Denton Extended Remix',
#   '2022-04-15',
#   'trance',
#   'track'),
#  (876, 'Various Artists', 'What You NE/ED', '2022-11-18', 'trance', 'track'),
#  (877,
#   'Various Artists',
#   'Psychadelia - Club Mix',
#   '2022-12-15',
#   'trance',
#   'track'),
#  (878,
#   'Serge Landar',
#   'Crystalized - rAin Remix - Mixed',
#   '2022-01-14',
#   'trance',
#   'track'),
#  (879,
#   'Various Artists',
#   "Hearts Unite - Katrin's World Remix",
#   '2022-01-28',
#   'trance',
#   'track'),
#  (880, 'Yonsh', 'Digital Air', '2022-03-04', 'trance', 'track'),
#  (881,
#   'Tritonal Tritonia Radio',
#   'Tritonia (Tritonia 367) - Coming Up, Pt. 2',
#   '2022-01-27',
#   'trance',
#   'track'),
#  (882, 'Various Artists', 'Borderline', '2022-03-25', 'trance', 'track'),
#  (883,
#   'Various Artists',
#   'Fade Away - Extended Mix',
#   '2022-06-24',
#   'trance',
#   'track'),
#  (884,
#   'Various Artists',
#   'Sojuz - Aioaska Remix',
#   '2022-08-05',
#   'trance',
#   'track'),
#  (885, 'Future Sound of Egypt', 'Galactica', '2022-05-11', 'trance', 'track'),
#  (886,
#   'Various Artists',
#   'Freedom (Original Mix)',
#   '2022-02-18',
#   'trance',
#   'track'),
#  (887,
#   'Aly & Fila FSOE Radio',
#   'Ocean Of Time (FSOE758)',
#   '2022-06-16',
#   'trance',
#   'track'),
#  (888,
#   'Various Artists',
#   'Beyond The Lights',
#   '2022-10-12',
#   'trance',
#   'track'),
#  (889,
#   'Various Artists',
#   'Papillon - Sergey Salekhov Extended Remix',
#   '2022-09-09',
#   'trance',
#   'track'),
#  (890, 'Kailum', 'Inner Trance', '2022-11-12', 'trance', 'track'),
#  (891,
#   'Various Artists',
#   "Remember - Paul Van Dyk's Recollected Remix",
#   '2022-02-25',
#   'trance',
#   'track'),
#  (892,
#   'Various Artists',
#   'Kick It - Dominik Koislmeyer Remix',
#   '2022-08-08',
#   'trance',
#   'track'),
#  (893,
#   'Thomas Schwartz',
#   'I Have Touched The Sky',
#   '2022-01-07',
#   'trance',
#   'track'),
#  (894,
#   'Hobin Rude',
#   'In Apricis - Sinan Arsan Remix',
#   '2022-01-07',
#   'trance',
#   'track'),
#  (895,
#   'Mayro',
#   'Crazy Thoughts - Blanka Barbara Remix',
#   '2022-06-24',
#   'trance',
#   'track'),
#  (896,
#   'Various Artists',
#   'Peace and Love - Extended Mix',
#   '2022-08-17',
#   'trance',
#   'track'),
#  (897,
#   'Andrew Rayel',
#   'La Nuit (FYH309) [A Breath Of Aether] - Maarten de Jong Mix',
#   '2022-06-01',
#   'trance',
#   'track'),
#  (898, 'Various Artists', "Don't Be Shy", '2022-06-10', 'trance', 'track'),
#  (899,
#   'Various Artists',
#   'Escape Line - Tycoos Extended Proglifting Remix',
#   '2022-11-20',
#   'trance',
#   'track'),
#  (900,
#   'Various Artists',
#   'Stimulation - Extended Mix',
#   '2022-06-24',
#   'trance',
#   'track'),
#  (901,
#   'Various Artists',
#   'Digit - G.Pal Remix',
#   '2022-04-01',
#   'trance',
#   'track'),
#  (902,
#   'Digital Mess',
#   'Uno Dau - Cathy K Remix',
#   '2022-06-17',
#   'trance',
#   'track'),
#  (903, 'Various Artists', 'Summer Nights', '2022-04-08', 'trance', 'track'),
#  (904,
#   'Various Artists',
#   'Earth - Original Mix',
#   '2022-06-10',
#   'trance',
#   'track'),
#  (905,
#   'Various Artists',
#   'Axolotol - Pad One Rmx',
#   '2022-07-07',
#   'trance',
#   'track'),
#  (906,
#   'Alan Cerra',
#   'Omen - Secretly Famous Remix',
#   '2022-07-04',
#   'trance',
#   'track'),
#  (907, 'Various Artists', 'Caravan', '2022-04-22', 'trance', 'track'),
#  (908,
#   'Various Artists',
#   'Coconut Island - Adip Kiyoi Remix',
#   '2022-05-06',
#   'trance',
#   'track'),
#  (909,
#   'Ori Uplift',
#   'Butterflies (UpOnly 486) - Mix Cut',
#   '2022-06-11',
#   'trance',
#   'track'),
#  (910, 'Christian Burns', 'Honour', '2022-03-11', 'trance', 'track'),
#  (911, 'Kroman', 'Cudec (ESRD12) - Mixed', '2022-06-10', 'trance', 'track'),
#  (912,
#   'Various Artists',
#   'Our Love - Christopher Corrigan Remix',
#   '2022-12-16',
#   'trance',
#   'track'),
#  (913, 'Various Artists', 'Falling Skies', '2022-08-20', 'trance', 'track'),
#  (914,
#   "Cosmic Gate's Wake Your Mind Radio",
#   'Wake Your Mind Intro (WYMR407)',
#   '2022-01-21',
#   'trance',
#   'track'),
#  (915, 'James Warren', 'Manifest - Mixed', '2022-11-04', 'trance', 'track'),
#  (916,
#   'Paul Hamilton',
#   'Nothing Matters - CaThY K Remix',
#   '2022-07-15',
#   'trance',
#   'track'),
#  (917, 'Fenna Day', 'Enough', '2022-07-01', 'trance', 'track'),
#  (918, 'Various Artists', 'Save Me', '2022-08-19', 'trance', 'track'),
#  (919,
#   'Proton Radio',
#   'Drift - Auditoria Remix - Mixed',
#   '2022-11-22',
#   'trance',
#   'track'),
#  (920,
#   'Various Artists',
#   'Quantum Leap - Original Mix',
#   '2022-01-28',
#   'trance',
#   'track'),
#  (921, 'Kazko', 'Spells', '2022-02-25', 'trance', 'track'),
#  (922, 'Ric Niels', 'Rapture Sky', '2022-09-30', 'trance', 'track'),
#  (923, 'Kamasutra', 'Passionate Ambience', '2022-07-08', 'trance', 'track'),
#  (924,
#   'Future Sound of Egypt',
#   'Take Flight',
#   '2022-07-04',
#   'trance',
#   'track'),
#  (925,
#   'Various Artists',
#   'Snow Echoes - Original Mix',
#   '2022-05-27',
#   'trance',
#   'track'),
#  (926,
#   'Various Artists',
#   'Time and Space - Alexander Koning Remix',
#   '2022-02-04',
#   'trance',
#   'track'),
#  (927, 'Alexey Sonar', 'Energy - Mixed', '2022-03-15', 'trance', 'track'),
#  (928,
#   'Roman Messer Suanda Radio',
#   'In Our Memories (Suanda 361)',
#   '2022-12-28',
#   'trance',
#   'track'),
#  (929,
#   'Various Artists',
#   'This Is All We Have - Sunset Mix (Radio Edit)',
#   '2022-02-11',
#   'trance',
#   'track'),
#  (930, 'Niceshot', 'Early Unlocked', '2022-04-15', 'trance', 'track'),
#  (931, 'Various Artists', 'Luna 9', '2022-12-26', 'trance', 'track'),
#  (932,
#   'Various Artists',
#   'To Be Who You Are - Extended Mix',
#   '2022-07-22',
#   'trance',
#   'track'),
#  (933, 'Hobin Rude', 'Travectio', '2022-04-15', 'trance', 'track'),
#  (934,
#   'Various Artists',
#   'Falling Stars - Extended Mix',
#   '2022-12-31',
#   'trance',
#   'track'),
#  (935, 'Various Artists', 'Found You', '2022-12-09', 'trance', 'track'),
#  (936, 'Tom Wax', 'Ketasit - Beat-A-Pella', '2022-07-22', 'trance', 'track'),
#  (937, 'California Sunshine', 'Tornado', '2022-04-08', 'trance', 'track'),
#  (938, 'Andrew Rayel', 'Cosmos (FYH327)', '2022-10-05', 'trance', 'track'),
#  (939, 'Axel Terblanche', 'Odyssey', '2022-05-18', 'trance', 'track'),
#  (940,
#   'Ryan Raya',
#   'Trance air - Sanani Remix',
#   '2022-01-31',
#   'trance',
#   'track'),
#  (941, 'Various Artists', 'Cannibal', '2022-06-03', 'trance', 'track'),
#  (942,
#   'Farius',
#   'A Big Life - Memory Loss Extended Remix',
#   '2022-04-01',
#   'trance',
#   'track'),
#  (943,
#   'Various Artists',
#   'Shadows - Original Mix',
#   '2022-07-01',
#   'trance',
#   'track'),
#  (944, 'Various Artists', 'Shadows Dancing', '2022-01-07', 'trance', 'track'),
#  (945,
#   "Har-El's California Sunshine",
#   'Equinox',
#   '2022-01-21',
#   'trance',
#   'track'),
#  (946, 'Madwave', 'Rush (MTRE017)', '2022-03-11', 'trance', 'track'),
#  (947,
#   'Madwave',
#   'Velocity in French (MTRE025)',
#   '2022-10-13',
#   'trance',
#   'track'),
#  (948,
#   'Ori Uplift',
#   "Here Comes The Rain (Best of '21) - Mix Cut",
#   '2022-12-12',
#   'trance',
#   'track'),
#  (949, 'DoctorSpook', 'They Came in Peace', '2022-04-01', 'trance', 'track'),
#  (950, 'Various Artists', "Don't Be Shy", '2022-06-10', 'trance', 'track'),
#  (951, 'Various Artists', 'The Business', '2022-03-18', 'trance', 'track'),
#  (952,
#   'Goa Doc',
#   'Time And Space (Goa Trance 2021 Mix) - Mixed',
#   '2022-09-12',
#   'trance',
#   'track'),
#  (953, 'Ric Niels', 'Chance to Live', '2022-09-13', 'trance', 'track'),
#  (954,
#   'Roman Messer Suanda Radio',
#   'Risk It All (Suanda 356) - LTN pres. Ghostbeat Remix',
#   '2022-11-23',
#   'trance',
#   'track'),
#  (955,
#   '40Thavha',
#   'Freedom To Love Blue And Yellow (Victory)',
#   '2022-06-13',
#   'trance',
#   'track'),
#  (956,
#   'Various Artists',
#   'Fractal - Original mix',
#   '2022-10-07',
#   'trance',
#   'track'),
#  (957,
#   'Various Artists',
#   'Desire - Invisible Reality Remix',
#   '2022-08-05',
#   'trance',
#   'track'),
#  (958,
#   'Rockka',
#   'Mississippi - D.Jameson Remix',
#   '2022-03-11',
#   'trance',
#   'track'),
#  (959,
#   'Various Artists',
#   'Colder - Achilles Extended Remix',
#   '2022-05-27',
#   'trance',
#   'track'),
#  (960, 'Jorza', 'Bad Dreams', '2022-06-03', 'trance', 'track'),
#  (961,
#   'Jachmastr',
#   'Past Motion - Ed Steele Remix - Mixed',
#   '2022-05-01',
#   'trance',
#   'track'),
#  (962,
#   'Various Artists',
#   'Coconut Island - Adip Kiyoi Remix',
#   '2022-05-06',
#   'trance',
#   'track'),
#  (963, 'Various Artists', 'Arboreal', '2022-01-07', 'trance', 'track'),
#  (964,
#   'DJ Dean',
#   'Call Out - Instrumental Mix',
#   '2022-08-12',
#   'trance',
#   'track'),
#  (965,
#   'Ori Uplift',
#   "Darkness Falls (Best of '21) - Mix Cut",
#   '2022-12-12',
#   'trance',
#   'track'),
#  (966,
#   'Alan Morris',
#   'Nowhere Left To Hide - BiXX Extended Mix',
#   '2022-05-27',
#   'trance',
#   'track'),
#  (967,
#   'Various Artists',
#   'Hidden Adventure - Drama Remix',
#   '2022-06-10',
#   'trance',
#   'track'),
#  (968, 'Johnny M', 'Sooner or Later - Mixed', '2022-07-17', 'trance', 'track'),
#  (969,
#   'Various Artists',
#   'Sustancia - Facundo Santos Rmx',
#   '2022-03-18',
#   'trance',
#   'track'),
#  (970, 'Yonsh', 'Zilot - Monostone Remix', '2022-12-02', 'trance', 'track'),
#  (971,
#   'Various Artists',
#   'Shadows - Original Mix',
#   '2022-07-01',
#   'trance',
#   'track'),
#  (972, 'Various Artists', 'Shadows Dancing', '2022-01-07', 'trance', 'track'),
#  (973,
#   'Various Artists',
#   'Hold of You - Denis Kenzo Extended Mix',
#   '2022-02-11',
#   'trance',
#   'track'),
#  (974,
#   'Various Artists',
#   'Global Distortion',
#   '2022-08-17',
#   'trance',
#   'track'),
#  (975, 'Five', 'Leku - Mixed', '2022-10-12', 'trance', 'track'),
#  (976,
#   'Various Artists',
#   'Sol - JAHAYA Remix',
#   '2022-12-17',
#   'trance',
#   'track'),
#  (977, 'Various Artists', 'Mayas', '2022-12-16', 'trance', 'track'),
#  (978,
#   'Last Soldier',
#   'Centaurus - Extended Mix',
#   '2022-12-02',
#   'trance',
#   'track'),
#  (979,
#   'DoctorSpook',
#   'Mowgli - Goa Psy Trance Rave DJ Mixed',
#   '2022-03-19',
#   'trance',
#   'track'),
#  (980, 'Various Artists', "Don't Be Afraid", '2022-04-15', 'trance', 'track'),
#  (981,
#   'Various Artists',
#   'Nowhere Left To Hide - BiXX Extended Mix',
#   '2022-04-29',
#   'trance',
#   'track'),
#  (982, 'Chris Sterio', 'Balanced - Mixed', '2022-03-04', 'trance', 'track'),
#  (983,
#   'Tritonal Tritonia Radio',
#   'Tritonia (Tritonia 391) - Coming Up, Pt. 2',
#   '2022-07-29',
#   'trance',
#   'track'),
#  (984,
#   'DoctorSpook',
#   'Constant Channeling - Goa Psy Trance Rave DJ Mixed',
#   '2022-03-19',
#   'trance',
#   'track'),
#  (985,
#   'Peter Illias',
#   'Love Is Blind - Radio-Edit',
#   '2022-03-11',
#   'trance',
#   'track'),
#  (986,
#   'Various Artists',
#   'We Come in Peace (Synthatic Remix)',
#   '2022-01-07',
#   'trance',
#   'track'),
#  (987, 'James Warren', 'Kalliope - Mixed', '2022-04-22', 'trance', 'track'),
#  (988,
#   'Aldo Henrycho',
#   'Hope - Carlo Camargo Remix',
#   '2022-03-25',
#   'trance',
#   'track'),
#  (989, 'Various Artists', 'You Can Run', '2022-11-11', 'trance', 'track'),
#  (990, 'Various Artists', 'The Hero In Me', '2022-09-23', 'trance', 'track'),
#  (991, 'Various Artists', 'Unconquered', '2022-12-23', 'trance', 'track'),
#  (992, 'Various Artists', 'Lonach', '2022-03-25', 'trance', 'track'),
#  (993,
#   'Various Artists',
#   'At Large Depths - Extended Mix',
#   '2022-08-01',
#   'trance',
#   'track'),
#  (994, 'Tom Wax', 'Soulmate', '2022-09-19', 'trance', 'track'),
#  (995,
#   'Various Artists',
#   'Return from Eternity - Short Mix',
#   '2022-11-26',
#   'trance',
#   'track'),
#  (996,
#   'Various Artists',
#   'The Day You Faded Away - Extended Mix',
#   '2022-08-19',
#   'trance',
#   'track'),
#  (997,
#   'Rocket Base',
#   'Future Cooperation - The Future Club Mix',
#   '2022-02-14',
#   'trance',
#   'track'),
#  (998, 'DoctorSpook', 'Mind Therapy', '2022-11-11', 'trance', 'track'),
#  (999,
#   'DoctorSpook',
#   'Perplexed (Remix) - Mixed',
#   '2022-08-13',
#   'trance',
#   'track'),
#  ...]

# %%
values = list(df_values.itertuples(index=False, name=None))

# %%
import mysql.connector
from mysql.connector import errorcode

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='MusicTrends')


mycursor = cnx.cursor()
sql = "INSERT INTO Spotify (nombre_artista, nombre_cancion, año_lanzamiento, género_musical, tipo) VALUES (%s, %s, %s, %s,%s)"
val = values

try: 
    mycursor.executemany(sql, val)
    cnx.commit()
    print(mycursor.rowcount, "registro/s insertado/s.")

except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
# Out:
# Failed executing the operation; Not all parameters were used in the SQL statement
# Error Code: -1
# SQLSTATE None
# Message Failed executing the operation; Not all parameters were used in the SQL statement
